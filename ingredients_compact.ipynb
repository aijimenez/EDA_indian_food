# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd
pd.set_option('display.max_rows', 1138)
indian_food = pd.read_csv("indian_food.csv")

# %%
#Number of ingredients
#indian_food['num_ingr'] = indian_food['ingredients'].apply(lambda x: len(x.split(',')))
#indian_food

# %%
indian_food['ingredients']
# Out:
# 0                        Maida flour, yogurt, oil, sugar
# 1                                Gram flour, ghee, sugar
# 2           Carrots, milk, sugar, ghee, cashews, raisins
# 3      Flour, ghee, kewra, milk, clarified butter, su...
# 4      Milk powder, plain flour, baking powder, ghee,...
# 5                              Sugar syrup, lentil flour
# 6      Maida, corn flour, baking soda, vinegar, curd,...
# 7                         Cashews, ghee, cardamom, sugar
# 8                            Milk, cottage cheese, sugar
# 9                        Milk, rice, sugar, dried fruits
# 10                               Gram flour, ghee, sugar
# 11                             Yogurt, milk, nuts, sugar
# 12     Refined flour, besan, ghee, powdered sugar, yo...
# 13     Firm white pumpkin, sugar, kitchen lime, alum ...
# 14                                     Rice, sugar, nuts
# 15                   Condensed milk, sugar, spices, nuts
# 16                            Semolina, ghee, nuts, milk
# 17                              Khoa, coconut, molu leaf
# 18                          Corn flour, ghee, dry fruits
# 19               Gram flour, ghee, sugar, milk, cardamom
# 20                                   Chhena, sugar, ghee
# 21                                   Chhena, sugar, milk
# 22                                  Sugar, chenna cheese
# 23     Flour, cream, sugar, saffron, lemon juice, coc...
# 24      Chenna, condensed milk, sugar, saffron, cardamom
# 25                                   Chhena, sugar, ghee
# 26                  Flour, fried milk power, sugar syrup
# 27            Yoghurt, refined flour, ghee, fennel seeds
# 28                              Besan flour, sugar, ghee
# 29                                         Milk, jaggery
# 30                            Chhena, sugar, ghee, flour
# 31                               Rice flour, wheat flour
# 32                                Chenna, sweetened milk
# 33                       Chhena, reduced milk, pistachio
# 34                               Chhena, sugar, cardamom
# 35                        Milk, sugar, saffron, cardamom
# 36      Rice flour, jaggery, ghee, vegetable oil, elachi
# 37                             Rice flour, jaggery, ghee
# 38     Besan, jaggery, cardamom powder, ghee, cashews...
# 39                                      Peanuts, jaggery
# 40                    Milk, Sugar, Dharwadi buffalo milk
# 41                                      Loaf bread, milk
# 42               Rice flour, sugar, salt, ghee, semolina
# 43                                    Wheat flour, sugar
# 44                                   Black lentils, rice
# 45     Besan flour, semolina, mung bean, jaggery, coc...
# 46     Maida flour, turmeric, coconut, chickpeas, jag...
# 47                                      Rice flour, milk
# 48                                    Chana dal, jaggery
# 49                          Rice, jaggery, cashews, ghee
# 50                      Rice flour, powdered sugar, ghee
# 51                                 Apricots, sugar syrup
# 52                              Vermicelli pudding, milk
# 53                  Rice flour, banana, jaggery, coconut
# 54                          Rice flour, jaggery, coconut
# 55                  Rice flour, jaggery, khus-khus seeds
# 56                                     Sugar, milk, nuts
# 57                                        Cucumber, rava
# 58                         Milk, rice, sugar, dry fruits
# 59                                       Semolina, sugar
# 60                         Rice flour, coconut, jaggery
# 61                    Sugar, ghee, maida flour, semolina
# 62                        Curd, sugar, saffron, cardamom
# 63                                    Maida, sugar, ghee
# 64         Fish, potol, tomato, chillies, ginger, garlic
# 65      Boiled pork, onions, chillies, ginger and garlic
# 66                           Rice, milk, sugar, cardamom
# 67              Rice, axone, salt, water, chillies, pork
# 68     Cauliflower, potato, garam masala, turmeric, c...
# 69     Rice flour, potato, bread crumbs, garam masala...
# 70     Potato, peas, chillies, ginger, garam masala, ...
# 71         Potato, fenugreek leaves, chillies, salt, oil
# 72     Potato, shimla mirch, garam masala, amchur pow...
# 73         Chole, rava, yogurt, plain flour, baking soda
# 74     Ladies finger, garam masala, kasuri methi, tom...
# 75     Chicken thighs, basmati rice, star anise, swee...
# 76     Chicken, greek yogurt, cream, garam masala pow...
# 77     Chickpeas, tomato paste, garam masala, ginger,...
# 78     Whole wheat flour, olive oil, hot water, all p...
# 79     Chicken, dahi, sesame seeds, garam masala powd...
# 80     Naan bread, tomato sauce, skinless chicken bre...
# 81     Chicken, whole wheat bread, rice flour, garam ...
# 82     Chole, bhatura, garam masala, bay leaf, cinnam...
# 83     Moong dal, masoor dal, chana dal, wheat flour,...
# 84     Moong dal, garam masala powder, garlic, green ...
# 85     Red kidney beans, urad dal, cream, garam masal...
# 86     Pigeon peas, garam masala, ginger, red onion, ...
# 87     Baby potatoes, garam masala, cashew nuts, kasu...
# 88     Beaten rice flakes, potato, curry leaves, gree...
# 89     Chana dal, whole wheat flour, arhar dal, white...
# 90     Moong dal, rava, garam masala, dough, fennel s...
# 91     Cottage cheese, bell peppers, gravy, garam mas...
# 92     Besan, garam masala powder, gram flour, ginger...
# 93     Bitter gourd, fennel, garam masala powder, chi...
# 94     Moong dal, green peas, ginger, tomato, green c...
# 95       Paneer, potato, cream, corn flour, garam masala
# 96     Rose syrup, falooda sev, mixed nuts, saffron, ...
# 97     Bottle gourd, garam masala powder, gram flour,...
# 98     Bottle gourd, coconut oil, garam masala, ginge...
# 99     Wheat flour, roasted gram flour, tomato, nigel...
# 100    Palak, makki atta, mustard green, garam masala...
# 101     Whole wheat flour, chickpea flour, green chilies
# 102      Mushroom, malai, garam masala, ginger, capsicum
# 103    Canned coconut milk, frozen green peas, wild m...
# 104             Whole wheat flour, honey, butter, garlic
# 105    Green beans, potatoes, khus khus, low fat, gar...
# 106    Cottage cheese, palak, cream, garam masala, bu...
# 107    Paneer, whipping cream, garam masala, cashew n...
# 108    Paneer, greek yogurt, tandoori masala, cream, ...
# 109        Kala chana, mashed potato, boondi, sev, lemon
# 110    Whole wheat flour, musk melon seeds, poppy see...
# 111         Urad dal, sev, lemon juice, chopped tomatoes
# 112               Wheat flour, butter, potato, coriander
# 113    Arbi ke patte, sesame seeds, gur, bengal gram ...
# 114     Fennel, tea bags, tomato, kasuri methi, cinnamon
# 115    Red kidney beans, garam masala powder, ginger,...
# 116    Garam masala powder, tomato, kasuri methi, cin...
# 117    Potatoes, green peas, garam masala, ginger, dough
# 118             Sattu, atta, dough, filling, mustard oil
# 119    Cottage cheese, malai, garam masala, ginger, t...
# 120    Rose water, milk, white bread slices, saffron,...
# 121    Baby corn, french beans, garam masala, ginger,...
# 122    Greek yogurt, garam masala, kasuri methi, mari...
# 123    Chickpea flour, biryani masala powder, yogurt,...
# 124    Whole wheat flour, arhar dal, ginger, kala jee...
# 125    Raw banana, elephant foot yam, long beans, tin...
# 126    Split pigeon peas, chana dal, urad dal, green ...
# 127    Chana dal, urad dal, fresh coconut, sesame see...
# 128    Chana dal, urad dal, whole urad dal, blend ric...
# 129                Rice flour, hot water, grated coconut
# 130    Split urad dal, urad dal, idli rice, thick poh...
# 131       Carrot, yellow mustard, red chilli, black salt
# 132    Sesame oil, drumstick, tamarind paste, sambar ...
# 133    Moong dal, chana dal, spinach, urad dal, cocon...
# 134    Urad dal, curry leaves, sugar, mustard seeds, ...
# 135       Greens, tomato, mustard seeds, fenugreek seeds
# 136    Amaranth leaves, split urad dal, mustard seeds...
# 137    Beef, coconut, garam masala, curry leaves, gre...
# 138             Chana dal, urad dal, potato, beans, peas
# 139    Moong dal, chana dal, cabbage, tamarind, curry...
# 140    Moong dal, cucumber, curry leaves, green chili...
# 141    Chana dal, urad dal, gooseberry, raw rice, cur...
# 142        Sesame oil, raw rice, jaggery, grated coconut
# 143    Pearl onions, urad dal, drumsticks, tomato, cu...
# 144    Chana dal, urad dal, potatoes, idli rice, thic...
# 145    Coconut oil, cucumber, curd, curry leaves, mus...
# 146    Yogurt, ginger, curry leaves, baking soda, gre...
# 147                 Lentils, black pepper, vegetable oil
# 148                             Raw rice,  jaggery, milk
# 149              Rice, cashew nuts, milk, raisins, sugar
# 150    Arhar dal, sambar powder, tomato, curry leaves...
# 151                        Green moong beans, rice flour
# 152         Chana dal, urad dal, beans, coconut, mustard
# 153    Urad dal, lemon, tamarind, cooked rice, curry ...
# 154    Tomato, curry leaves, garlic, mustard seeds, h...
# 155              Brown rice flour, sugar, grated coconut
# 156    Pigeon peas, eggplant, drumsticks, sambar powd...
# 157    Thin rice flakes, black sesame seeds, curry le...
# 158                       Sevai, parboiled rice, steamer
# 159    Urad dal, curd, sesame oil, ginger, curry leav...
# 160    Coconut, whole red beans, masala, sesame oil, ...
# 161      Chana dal, urad dal, thick poha, tomato, butter
# 162    Urad dal, ginger, curry leaves, green chilies,...
# 163    Meat curry powder, chicken chunks, ginger, tom...
# 164     Chana dal, urad dal, ginger, curry leaves, sugar
# 165    Kala masala, arhar dal, curry leaves, mustard ...
# 166    Gram flour, mustard, garlic, turmeric, red chilli
# 167    Baingan, fish, coconut oil, fresh coconut, ginger
# 168               Urad dal, potatoes, wheat flour, sooji
# 169           Wheat flour, pearl millet flour, hot water
# 170    Condensed milk, mawa, desiccated coconut, almo...
# 171                            Jowar flour, sesame seeds
# 172    Bombay duck, malvani masala, rice flour, bomba...
# 173    Rice flour, sesame, plain flour, turmeric, red...
# 174         Citric acid, fry, raisins, sugar, chana daal
# 175    Urad dal, bengal gram flour, dried mango, baki...
# 176    Condensed milk, nestle cream, coconut ice, red...
# 177    Whole wheat flour, dal, kokum, gur, bengal gra...
# 178           Pav, aloo, peanut, pomegranate, star anise
# 179    Urad dal, bhuna chana, garam masala, dates, ta...
# 180    Arhar dal, coconut oil, curry leaves, mustard ...
# 181           Rava, coconut, gram flour, mustard, sesame
# 182    Bottle gourd, green, raisins, sugar, clarified...
# 183    Yogurt, besan, sauce, garam masala powder, gra...
# 184    Wheat flour, jaggery, clarified butter, sliced...
# 185              Dry fruits, semolina, all purpose flour
# 186    Bottle gourd, chana dal, cabbage, urad dal, to...
# 187    Whole wheat rava, chia seed, lemon, edible gum...
# 188    Green chilies, lemon juice, chili powder, boil...
# 189                   Wheat flour, cashews, rapeseed oil
# 190                                         Mango, sugar
# 191        Whole wheat flour, low fat, bengal gram flour
# 192    Green chili paste, white sesame seeds, gram fl...
# 193    Rice flour, urad dal, wheat flour, gram flour,...
# 194     Cinnamon, jaggery, clarified butter, dry roasted
# 195                 Cucumber, carrot, tomatoes, cilantro
# 196    Rava, gram flour, lemon juice, turmeric, fenug...
# 197    Rose water, pistachio, badam, bengal gram flou...
# 198    Bottle gourd, whole wheat flour, rava, sesame ...
# 199    Arbi ke patte, sesame seeds, gur, bengal gram ...
# 200    Pav bhaji masala, gobi, potatoes, green peas, ...
# 201        Aloo, urad dal, mustard, ginger, curry leaves
# 202    Raw peanuts, sabudana, lemon, avocado oil, cur...
# 203     Khaman, pomegranate, sev, powdered sugar, garlic
# 204                           Sev, ginger, tomato, sugar
# 205    Wheat flour, baking soda, all purpose flour, b...
# 206             Whole wheat flour, gur, clarified butter
# 207    Rice flakes, yogurt, raw rice, jaggery, grated...
# 208    Whole wheat flour, rice flour, pearl millet fl...
# 209    Sweet potato, surti papdi, baby potatoes, valo...
# 210              Gobi, potato, beans, khus khus, coconut
# 211    Chicken, coconut oil, wine vinegar, ginger, gr...
# 212    Green garlic chutney, fresh green peas, ginger...
# 213        Moong beans, jaggery, red chillies, oil, salt
# 214    Rice flour, sesame seeds, baking soda, peanut oil
# 215    Chickpea flour, methi leaves, jowar flour, whe...
# 216    Semolina, clarified butter, oil, white flour, ...
# 217    Yogurt, fresh coconut, sesame seeds, semolina,...
# 218    Ridge gourd, baking soda, sugar, grated coconu...
# 219    Whole wheat flour, khus khus, sesame seeds, dr...
# 220                                    Rice, mango, curd
# 221        Sticky rice, rice flour, jaggery, orange rind
# 222    Raw papaya, panch phoran masala, nigella seeds...
# 223                         Rice, eggs, carrot, beetroot
# 224                                 Maida, vegetable oil
# 225          Potatoes, mustard oil, fish, green chillies
# 226      Ridge gourd, fish, lemon, tomatoes, mustard oil
# 227       Brinjal, onions, salt, sesame seeds, coriander
# 228    Potatoes, garam masala, tomatoes, mustard oil,...
# 229    Forbidden black rice, chicken, olive oil, sliv...
# 230    Biryani masala, mixed vegetables, yellow moong...
# 231                     Brown rice, soy sauce, olive oil
# 232    Coconut milk, lobster, fresh green chilli, gin...
# 233    Baking soda, clarified butter, oil, all purpos...
# 234                                     Jaggery, raisins
# 235    Lamb, garam masala powder, curd, turmeric, bay...
# 236     Coconut, prawns, curd, mustard seed, green chili
# 237              Fish fillet, besan, lemon, mint, ginger
# 238    Fermented bamboo shoot, potato, ginger, green,...
# 239    Banana flower, chicken, green chili, mustard o...
# 240    Aloo, tomatoes, mustard oil, bay leaf, cinnamo...
# 241    Rice flour, mutton, banana, gram flour, olive ...
# 242    Fish roe, pumpkin flowers, mustard oil, turmer...
# 243    Chana dal, fresh coconut, ginger, cinnamon, ra...
# 244          Curd, cooked rice, curry leaves, dry chilli
# 245    Tea leaves, white sesame seeds, dry coconut, s...
# 246    Basmati rice, rose water, sugar, clarified but...
# 247        Coconut milk, prawns, garlic, turmeric, sugar
# 248    Red pepper, red onion, butter, watercress, oli...
# 249    Green beans, bitter gourd, ridge gourd, banana...
# 250              Glutinous rice, black sesame seeds, gur
# 251    Coconut milk, egg yolks, clarified butter, all...
# 252    Cottage cheese, dry dates, dried rose petals, ...
# 253    Milk powder, dry fruits, arrowroot powder, all...
# 254    Brown rice, fennel seeds, grated coconut, blac...
# Name: ingredients, dtype: object

# %%
ingredients_lists = []
for i in indian_food['ingredients']:
    ingredients_lists.append(i.split(','))
ingredients_lists
# Out:
# [['Maida flour', ' yogurt', ' oil', ' sugar'],
#  ['Gram flour', ' ghee', ' sugar'],
#  ['Carrots', ' milk', ' sugar', ' ghee', ' cashews', ' raisins'],
#  ['Flour',
#   ' ghee',
#   ' kewra',
#   ' milk',
#   ' clarified butter',
#   ' sugar',
#   ' almonds',
#   ' pistachio',
#   ' saffron',
#   ' green cardamom'],
#  ['Milk powder',
#   ' plain flour',
#   ' baking powder',
#   ' ghee',
#   ' milk',
#   ' sugar',
#   ' water',
#   ' rose water'],
#  ['Sugar syrup', ' lentil flour'],
#  ['Maida',
#   ' corn flour',
#   ' baking soda',
#   ' vinegar',
#   ' curd',
#   ' water',
#   ' turmeric',
#   ' saffron',
#   ' cardamom'],
#  ['Cashews', ' ghee', ' cardamom', ' sugar'],
#  ['Milk', ' cottage cheese', ' sugar'],
#  ['Milk', ' rice', ' sugar', ' dried fruits'],
#  ['Gram flour', ' ghee', ' sugar'],
#  ['Yogurt', ' milk', ' nuts', ' sugar'],
#  ['Refined flour',
#   ' besan',
#   ' ghee',
#   ' powdered sugar',
#   ' yoghurt',
#   ' green cardamom'],
#  ['Firm white pumpkin', ' sugar', ' kitchen lime', ' alum powder'],
#  ['Rice', ' sugar', ' nuts'],
#  ['Condensed milk', ' sugar', ' spices', ' nuts'],
#  ['Semolina', ' ghee', ' nuts', ' milk'],
#  ['Khoa', ' coconut', ' molu leaf'],
#  ['Corn flour', ' ghee', ' dry fruits'],
#  ['Gram flour', ' ghee', ' sugar', ' milk', ' cardamom'],
#  ['Chhena', ' sugar', ' ghee'],
#  ['Chhena', ' sugar', ' milk'],
#  ['Sugar', ' chenna cheese'],
#  ['Flour', ' cream', ' sugar', ' saffron', ' lemon juice', ' coconut flakes'],
#  ['Chenna', ' condensed milk', ' sugar', ' saffron', ' cardamom'],
#  ['Chhena', ' sugar', ' ghee'],
#  ['Flour', ' fried milk power', ' sugar syrup'],
#  ['Yoghurt', ' refined flour', ' ghee', ' fennel seeds'],
#  ['Besan flour', ' sugar', ' ghee'],
#  ['Milk', ' jaggery'],
#  ['Chhena', ' sugar', ' ghee', ' flour'],
#  ['Rice flour', ' wheat flour'],
#  ['Chenna', ' sweetened milk'],
#  ['Chhena', ' reduced milk', ' pistachio'],
#  ['Chhena', ' sugar', ' cardamom'],
#  ['Milk', ' sugar', ' saffron', ' cardamom'],
#  ['Rice flour', ' jaggery', ' ghee', ' vegetable oil', ' elachi'],
#  ['Rice flour', ' jaggery', ' ghee'],
#  ['Besan',
#   ' jaggery',
#   ' cardamom powder',
#   ' ghee',
#   ' cashews and raisins',
#   ' jaggery syrup',
#   ' sugar'],
#  ['Peanuts', ' jaggery'],
#  ['Milk', ' Sugar', ' Dharwadi buffalo milk'],
#  ['Loaf bread', ' milk'],
#  ['Rice flour', ' sugar', ' salt', ' ghee', ' semolina'],
#  ['Wheat flour', ' sugar'],
#  ['Black lentils', ' rice'],
#  ['Besan flour',
#   ' semolina',
#   ' mung bean',
#   ' jaggery',
#   ' coconut',
#   ' skimmed milk powder',
#   ' sugar',
#   ' ghee'],
#  ['Maida flour',
#   ' turmeric',
#   ' coconut',
#   ' chickpeas',
#   ' jaggery',
#   ' ghee',
#   ' cardamom'],
#  ['Rice flour', ' milk'],
#  ['Chana dal', ' jaggery'],
#  ['Rice', ' jaggery', ' cashews', ' ghee'],
#  ['Rice flour', ' powdered sugar', ' ghee'],
#  ['Apricots', ' sugar syrup'],
#  ['Vermicelli pudding', ' milk'],
#  ['Rice flour', ' banana', ' jaggery', ' coconut'],
#  ['Rice flour', ' jaggery', ' coconut'],
#  ['Rice flour', ' jaggery', ' khus-khus seeds'],
#  ['Sugar', ' milk', ' nuts'],
#  ['Cucumber', ' rava'],
#  ['Milk', ' rice', ' sugar', ' dry fruits'],
#  ['Semolina', ' sugar'],
#  ['Rice flour', ' coconut', ' jaggery '],
#  ['Sugar', ' ghee', ' maida flour', ' semolina'],
#  ['Curd', ' sugar', ' saffron', ' cardamom'],
#  ['Maida', ' sugar', ' ghee'],
#  ['Fish', ' potol', ' tomato', ' chillies', ' ginger', ' garlic'],
#  ['Boiled pork', ' onions', ' chillies', ' ginger and garlic'],
#  ['Rice', ' milk', ' sugar', ' cardamom'],
#  ['Rice', ' axone', ' salt', ' water', ' chillies', ' pork'],
#  ['Cauliflower', ' potato', ' garam masala', ' turmeric', ' curry leaves'],
#  ['Rice flour', ' potato', ' bread crumbs', ' garam masala', ' salt'],
#  ['Potato', ' peas', ' chillies', ' ginger', ' garam masala', ' garlic'],
#  ['Potato', ' fenugreek leaves', ' chillies', ' salt', ' oil'],
#  ['Potato', ' shimla mirch', ' garam masala', ' amchur powder', ' salt'],
#  ['Chole', ' rava', ' yogurt', ' plain flour', ' baking soda'],
#  ['Ladies finger',
#   ' garam masala',
#   ' kasuri methi',
#   ' tomatoes',
#   ' chili powder'],
#  ['Chicken thighs',
#   ' basmati rice',
#   ' star anise',
#   ' sweet',
#   ' green chillies'],
#  ['Chicken',
#   ' greek yogurt',
#   ' cream',
#   ' garam masala powder',
#   ' cashew nuts',
#   ' butter'],
#  ['Chickpeas',
#   ' tomato paste',
#   ' garam masala',
#   ' ginger',
#   ' red onion',
#   ' avocado oil'],
#  ['Whole wheat flour', ' olive oil', ' hot water', ' all purpose flour'],
#  ['Chicken',
#   ' dahi',
#   ' sesame seeds',
#   ' garam masala powder',
#   ' cashew nuts',
#   ' saffron'],
#  ['Naan bread',
#   ' tomato sauce',
#   ' skinless chicken breasts',
#   ' heavy cream',
#   ' garam masala'],
#  ['Chicken',
#   ' whole wheat bread',
#   ' rice flour',
#   ' garam masala powder',
#   ' whole egg'],
#  ['Chole', ' bhatura', ' garam masala', ' bay leaf', ' cinnamon stick'],
#  ['Moong dal', ' masoor dal', ' chana dal', ' wheat flour', ' almond'],
#  ['Moong dal',
#   ' garam masala powder',
#   ' garlic',
#   ' green chilli',
#   ' all purpose flour'],
#  ['Red kidney beans', ' urad dal', ' cream', ' garam masala', ' chili powder'],
#  ['Pigeon peas', ' garam masala', ' ginger', ' red onion', ' kasuri methi'],
#  ['Baby potatoes',
#   ' garam masala',
#   ' cashew nuts',
#   ' kasuri methi',
#   ' tomatoes'],
#  ['Beaten rice flakes',
#   ' potato',
#   ' curry leaves',
#   ' green chilies',
#   ' lemon juice'],
#  ['Chana dal',
#   ' whole wheat flour',
#   ' arhar dal',
#   ' white urad dal',
#   ' garam masala powder'],
#  ['Moong dal', ' rava', ' garam masala', ' dough', ' fennel seeds'],
#  ['Cottage cheese',
#   ' bell peppers',
#   ' gravy',
#   ' garam masala',
#   ' cashew nuts'],
#  ['Besan', ' garam masala powder', ' gram flour', ' ginger', ' curry leaves'],
#  ['Bitter gourd',
#   ' fennel',
#   ' garam masala powder',
#   ' chili powder',
#   ' amchur powder'],
#  ['Moong dal', ' green peas', ' ginger', ' tomato', ' green chili'],
#  ['Paneer', ' potato', ' cream', ' corn flour', ' garam masala'],
#  ['Rose syrup', ' falooda sev', ' mixed nuts', ' saffron', ' sugar'],
#  ['Bottle gourd',
#   ' garam masala powder',
#   ' gram flour',
#   ' ginger',
#   ' chillies'],
#  ['Bottle gourd',
#   ' coconut oil',
#   ' garam masala',
#   ' ginger',
#   ' green chillies'],
#  ['Wheat flour',
#   ' roasted gram flour',
#   ' tomato',
#   ' nigella seeds',
#   ' chilli'],
#  ['Palak', ' makki atta', ' mustard green', ' garam masala', ' ginger'],
#  ['Whole wheat flour', ' chickpea flour', ' green chilies'],
#  ['Mushroom', ' malai', ' garam masala', ' ginger', ' capsicum'],
#  ['Canned coconut milk',
#   ' frozen green peas',
#   ' wild mushrooms',
#   ' garam masala',
#   ' tomatoes'],
#  ['Whole wheat flour', ' honey', ' butter', ' garlic'],
#  ['Green beans',
#   ' potatoes',
#   ' khus khus',
#   ' low fat',
#   ' garam masala powder'],
#  ['Cottage cheese', ' palak', ' cream', ' garam masala', ' butter'],
#  ['Paneer', ' whipping cream', ' garam masala', ' cashew nuts', ' butter'],
#  ['Paneer', ' greek yogurt', ' tandoori masala', ' cream', ' bell pepper'],
#  ['Kala chana', ' mashed potato', ' boondi', ' sev', ' lemon'],
#  ['Whole wheat flour',
#   ' musk melon seeds',
#   ' poppy seeds',
#   ' edible gum',
#   ' semolina'],
#  ['Urad dal', ' sev', ' lemon juice', ' chopped tomatoes'],
#  ['Wheat flour', ' butter', ' potato', ' coriander'],
#  ['Arbi ke patte', ' sesame seeds', ' gur', ' bengal gram flour', ' imli'],
#  ['Fennel', ' tea bags', ' tomato', ' kasuri methi', ' cinnamon'],
#  ['Red kidney beans',
#   ' garam masala powder',
#   ' ginger',
#   ' tomato',
#   ' mustard oil'],
#  ['Garam masala powder',
#   ' tomato',
#   ' kasuri methi',
#   ' cinnamon',
#   ' mustard oil'],
#  ['Potatoes', ' green peas', ' garam masala', ' ginger', ' dough'],
#  ['Sattu', ' atta', ' dough', ' filling', ' mustard oil'],
#  ['Cottage cheese', ' malai', ' garam masala', ' ginger', ' tomato'],
#  ['Rose water', ' milk', ' white bread slices', ' saffron', ' almonds'],
#  ['Baby corn', ' french beans', ' garam masala', ' ginger', ' carrot'],
#  ['Greek yogurt',
#   ' garam masala',
#   ' kasuri methi',
#   ' marinade',
#   ' mustard oil'],
#  ['Chickpea flour',
#   ' biryani masala powder',
#   ' yogurt',
#   ' fish fillets',
#   ' green bell pepper'],
#  ['Whole wheat flour',
#   ' arhar dal',
#   ' ginger',
#   ' kala jeera',
#   ' green chilli'],
#  ['Raw banana', ' elephant foot yam', ' long beans', ' tindora', ' urad dal'],
#  ['Split pigeon peas',
#   ' chana dal',
#   ' urad dal',
#   ' green peas',
#   ' french beans'],
#  ['Chana dal',
#   ' urad dal',
#   ' fresh coconut',
#   ' sesame seeds',
#   ' curry leaves'],
#  ['Chana dal', ' urad dal', ' whole urad dal', ' blend rice', ' rock salt'],
#  ['Rice flour', ' hot water', ' grated coconut'],
#  ['Split urad dal', ' urad dal', ' idli rice', ' thick poha', ' rock salt'],
#  ['Carrot', ' yellow mustard', ' red chilli', ' black salt'],
#  ['Sesame oil', ' drumstick', ' tamarind paste', ' sambar powder', ' tomato'],
#  ['Moong dal', ' chana dal', ' spinach', ' urad dal', ' coconut oil'],
#  ['Urad dal', ' curry leaves', ' sugar', ' mustard seeds', ' spinach'],
#  ['Greens', ' tomato', ' mustard seeds', ' fenugreek seeds'],
#  ['Amaranth leaves',
#   ' split urad dal',
#   ' mustard seeds',
#   ' grated coconut',
#   ' red chili'],
#  ['Beef',
#   ' coconut',
#   ' garam masala',
#   ' curry leaves',
#   ' green chilies',
#   ' chili powder'],
#  ['Chana dal', ' urad dal', ' potato', ' beans', ' peas'],
#  ['Moong dal', ' chana dal', ' cabbage', ' tamarind', ' curry leaves'],
#  ['Moong dal', ' cucumber', ' curry leaves', ' green chili', ' lemon juice'],
#  ['Chana dal', ' urad dal', ' gooseberry', ' raw rice', ' curry leaves'],
#  ['Sesame oil', ' raw rice', ' jaggery', ' grated coconut'],
#  ['Pearl onions', ' urad dal', ' drumsticks', ' tomato', ' curry leaves'],
#  ['Chana dal', ' urad dal', ' potatoes', ' idli rice', ' thick poha'],
#  ['Coconut oil', ' cucumber', ' curd', ' curry leaves', ' mustard seeds'],
#  ['Yogurt', ' ginger', ' curry leaves', ' baking soda', ' green chilli'],
#  ['Lentils', ' black pepper', ' vegetable oil'],
#  ['Raw rice', '  jaggery', ' milk'],
#  ['Rice', ' cashew nuts', ' milk', ' raisins', ' sugar'],
#  ['Arhar dal', ' sambar powder', ' tomato', ' curry leaves', ' fennel seeds'],
#  ['Green moong beans', ' rice flour'],
#  ['Chana dal', ' urad dal', ' beans', ' coconut', ' mustard'],
#  ['Urad dal', ' lemon', ' tamarind', ' cooked rice', ' curry leaves'],
#  ['Tomato', ' curry leaves', ' garlic', ' mustard seeds', ' hot water'],
#  ['Brown rice flour', ' sugar', ' grated coconut'],
#  ['Pigeon peas', ' eggplant', ' drumsticks', ' sambar powder', ' tamarind'],
#  ['Thin rice flakes', ' black sesame seeds', ' curry leaves'],
#  ['Sevai', ' parboiled rice', ' steamer'],
#  ['Urad dal',
#   ' curd',
#   ' sesame oil',
#   ' ginger',
#   ' curry leaves',
#   ' mustard seeds'],
#  ['Coconut', ' whole red beans', ' masala', ' sesame oil', ' tamarind'],
#  ['Chana dal', ' urad dal', ' thick poha', ' tomato', ' butter'],
#  ['Urad dal', ' ginger', ' curry leaves', ' green chilies', ' black pepper'],
#  ['Meat curry powder', ' chicken chunks', ' ginger', ' tomato', ' cinnamon'],
#  ['Chana dal', ' urad dal', ' ginger', ' curry leaves', ' sugar'],
#  ['Kala masala',
#   ' arhar dal',
#   ' curry leaves',
#   ' mustard seeds',
#   ' hot water'],
#  ['Gram flour', ' mustard', ' garlic', ' turmeric', ' red chilli'],
#  ['Baingan', ' fish', ' coconut oil', ' fresh coconut', ' ginger'],
#  ['Urad dal', ' potatoes', ' wheat flour', ' sooji'],
#  ['Wheat flour', ' pearl millet flour', ' hot water'],
#  ['Condensed milk', ' mawa', ' desiccated coconut', ' almonds', ' cashews'],
#  ['Jowar flour', ' sesame seeds'],
#  ['Bombay duck',
#   ' malvani masala',
#   ' rice flour',
#   ' bombay rava',
#   ' green chilies'],
#  ['Rice flour', ' sesame', ' plain flour', ' turmeric', ' red chilli'],
#  ['Citric acid', ' fry', ' raisins', ' sugar', ' chana daal'],
#  ['Urad dal',
#   ' bengal gram flour',
#   ' dried mango',
#   ' baking soda',
#   ' black salt'],
#  ['Condensed milk',
#   ' nestle cream',
#   ' coconut ice',
#   ' red food coloring',
#   ' desiccated coconut'],
#  ['Whole wheat flour', ' dal', ' kokum', ' gur', ' bengal gram flour'],
#  ['Pav', ' aloo', ' peanut', ' pomegranate', ' star anise'],
#  ['Urad dal', ' bhuna chana', ' garam masala', ' dates', ' tamarind'],
#  ['Arhar dal',
#   ' coconut oil',
#   ' curry leaves',
#   ' mustard seeds',
#   ' red chilli'],
#  ['Rava', ' coconut', ' gram flour', ' mustard', ' sesame'],
#  ['Bottle gourd', ' green', ' raisins', ' sugar', ' clarified butter'],
#  ['Yogurt', ' besan', ' sauce', ' garam masala powder', ' gram flour'],
#  ['Wheat flour', ' jaggery', ' clarified butter', ' sliced almonds'],
#  ['Dry fruits', ' semolina', ' all purpose flour'],
#  ['Bottle gourd', ' chana dal', ' cabbage', ' urad dal', ' toor dal'],
#  ['Whole wheat rava', ' chia seed', ' lemon', ' edible gum', ' litre milk'],
#  ['Green chilies', ' lemon juice', ' chili powder', ' boiled potatoes'],
#  ['Wheat flour', ' cashews', ' rapeseed oil'],
#  ['Mango', ' sugar'],
#  ['Whole wheat flour', ' low fat', ' bengal gram flour'],
#  ['Green chili paste',
#   ' white sesame seeds',
#   ' gram flour',
#   ' curry leaves',
#   ' green chili'],
#  ['Rice flour', ' urad dal', ' wheat flour', ' gram flour', ' turmeric'],
#  ['Cinnamon', ' jaggery', ' clarified butter', ' dry roasted'],
#  ['Cucumber', ' carrot', ' tomatoes', ' cilantro'],
#  ['Rava', ' gram flour', ' lemon juice', ' turmeric', ' fenugreek leaves'],
#  ['Rose water', ' pistachio', ' badam', ' bengal gram flour', ' saffron'],
#  ['Bottle gourd',
#   ' whole wheat flour',
#   ' rava',
#   ' sesame seeds',
#   ' bengal gram flour'],
#  ['Arbi ke patte', ' sesame seeds', ' gur', ' bengal gram flour', ' imli'],
#  ['Pav bhaji masala', ' gobi', ' potatoes', ' green peas', ' dinner rolls'],
#  ['Aloo', ' urad dal', ' mustard', ' ginger', ' curry leaves'],
#  ['Raw peanuts',
#   ' sabudana',
#   ' lemon',
#   ' avocado oil',
#   ' curry leaves',
#   ' green chili'],
#  ['Khaman', ' pomegranate', ' sev', ' powdered sugar', ' garlic'],
#  ['Sev', ' ginger', ' tomato', ' sugar'],
#  ['Wheat flour',
#   ' baking soda',
#   ' all purpose flour',
#   ' black pepper',
#   ' sunflower oil'],
#  ['Whole wheat flour', ' gur', ' clarified butter'],
#  ['Rice flakes', ' yogurt', ' raw rice', ' jaggery', ' grated coconut'],
#  ['Whole wheat flour',
#   ' rice flour',
#   ' pearl millet flour',
#   ' sorghum flour',
#   ' sesame seeds'],
#  ['Sweet potato',
#   ' surti papdi',
#   ' baby potatoes',
#   ' valor papdi',
#   ' green peas'],
#  ['Gobi', ' potato', ' beans', ' khus khus', ' coconut'],
#  ['Chicken',
#   ' coconut oil',
#   ' wine vinegar',
#   ' ginger',
#   ' green',
#   ' cinnamon'],
#  ['Green garlic chutney',
#   ' fresh green peas',
#   ' ginger',
#   ' lemon juice',
#   ' plain flour'],
#  ['Moong beans', ' jaggery', ' red chillies', ' oil', ' salt'],
#  ['Rice flour', ' sesame seeds', ' baking soda', ' peanut oil'],
#  ['Chickpea flour', ' methi leaves', ' jowar flour', ' wheat flour'],
#  ['Semolina', ' clarified butter', ' oil', ' white flour', ' black pepper'],
#  ['Yogurt', ' fresh coconut', ' sesame seeds', ' semolina', ' gram flour'],
#  ['Ridge gourd', ' baking soda', ' sugar', ' grated coconut', ' peas'],
#  ['Whole wheat flour', ' khus khus', ' sesame seeds', ' dry coconut', ' gur'],
#  ['Rice', ' mango', ' curd'],
#  ['Sticky rice', ' rice flour', ' jaggery', ' orange rind'],
#  ['Raw papaya',
#   ' panch phoran masala',
#   ' nigella seeds',
#   ' mustard oil',
#   ' fennel seeds'],
#  ['Rice', ' eggs', ' carrot', ' beetroot'],
#  ['Maida', ' vegetable oil'],
#  ['Potatoes', ' mustard oil', ' fish', ' green chillies'],
#  ['Ridge gourd', ' fish', ' lemon', ' tomatoes', ' mustard oil'],
#  ['Brinjal', ' onions', ' salt', ' sesame seeds', ' coriander'],
#  ['Potatoes', ' garam masala', ' tomatoes', ' mustard oil', ' bay leaf'],
#  ['Forbidden black rice',
#   ' chicken',
#   ' olive oil',
#   ' slivered almonds',
#   ' garlic powder'],
#  ['Biryani masala',
#   ' mixed vegetables',
#   ' yellow moong daal',
#   ' whole red',
#   ' mustard seeds'],
#  ['Brown rice', ' soy sauce', ' olive oil'],
#  ['Coconut milk', ' lobster', ' fresh green chilli', ' ginger', ' red onion'],
#  ['Baking soda', ' clarified butter', ' oil', ' all purpose flour'],
#  ['Jaggery', ' raisins'],
#  ['Lamb', ' garam masala powder', ' curd', ' turmeric', ' bay leaf'],
#  ['Coconut', ' prawns', ' curd', ' mustard seed', ' green chili'],
#  ['Fish fillet', ' besan', ' lemon', ' mint', ' ginger'],
#  ['Fermented bamboo shoot', ' potato', ' ginger', ' green', ' mustard oil'],
#  ['Banana flower', ' chicken', ' green chili', ' mustard oil', ' lemon juice'],
#  ['Aloo', ' tomatoes', ' mustard oil', ' bay leaf', ' cinnamon stick'],
#  ['Rice flour',
#   ' mutton',
#   ' banana',
#   ' gram flour',
#   ' olive oil',
#   ' baking powder'],
#  ['Fish roe', ' pumpkin flowers', ' mustard oil', ' turmeric', ' tomato'],
#  ['Chana dal', ' fresh coconut', ' ginger', ' cinnamon', ' raisins'],
#  ['Curd', ' cooked rice', ' curry leaves', ' dry chilli'],
#  ['Tea leaves', ' white sesame seeds', ' dry coconut', ' soaked rice'],
#  ['Basmati rice',
#   ' rose water',
#   ' sugar',
#   ' clarified butter',
#   ' cardamom pods'],
#  ['Coconut milk', ' prawns', ' garlic', ' turmeric', ' sugar'],
#  ['Red pepper', ' red onion', ' butter', ' watercress', ' olive oil'],
#  ['Green beans', ' bitter gourd', ' ridge gourd', ' banana', ' brinjal'],
#  ['Glutinous rice', ' black sesame seeds', ' gur'],
#  ['Coconut milk', ' egg yolks', ' clarified butter', ' all purpose flour'],
#  ['Cottage cheese',
#   ' dry dates',
#   ' dried rose petals',
#   ' pistachio',
#   ' badam'],
#  ['Milk powder', ' dry fruits', ' arrowroot powder', ' all purpose flour'],
#  ['Brown rice',
#   ' fennel seeds',
#   ' grated coconut',
#   ' black pepper',
#   ' ginger powder']]

# %%
ingredients = []
for list in ingredients_lists:
    for ingredient in list:
        ingredients.append(ingredient)

# %%
#indian_food['num_ingr'].sum()

# %%
len(ingredients)
# Out:
# 1136

# %%
ingredients.append('cashew nuts')
len(ingredients)
# Out:
# 1137

# %%
ingredients.append('garlic')
len(ingredients)
# Out:
# 1138

# %%
ingredients
# Out:
# ['Maida flour',
#  ' yogurt',
#  ' oil',
#  ' sugar',
#  'Gram flour',
#  ' ghee',
#  ' sugar',
#  'Carrots',
#  ' milk',
#  ' sugar',
#  ' ghee',
#  ' cashews',
#  ' raisins',
#  'Flour',
#  ' ghee',
#  ' kewra',
#  ' milk',
#  ' clarified butter',
#  ' sugar',
#  ' almonds',
#  ' pistachio',
#  ' saffron',
#  ' green cardamom',
#  'Milk powder',
#  ' plain flour',
#  ' baking powder',
#  ' ghee',
#  ' milk',
#  ' sugar',
#  ' water',
#  ' rose water',
#  'Sugar syrup',
#  ' lentil flour',
#  'Maida',
#  ' corn flour',
#  ' baking soda',
#  ' vinegar',
#  ' curd',
#  ' water',
#  ' turmeric',
#  ' saffron',
#  ' cardamom',
#  'Cashews',
#  ' ghee',
#  ' cardamom',
#  ' sugar',
#  'Milk',
#  ' cottage cheese',
#  ' sugar',
#  'Milk',
#  ' rice',
#  ' sugar',
#  ' dried fruits',
#  'Gram flour',
#  ' ghee',
#  ' sugar',
#  'Yogurt',
#  ' milk',
#  ' nuts',
#  ' sugar',
#  'Refined flour',
#  ' besan',
#  ' ghee',
#  ' powdered sugar',
#  ' yoghurt',
#  ' green cardamom',
#  'Firm white pumpkin',
#  ' sugar',
#  ' kitchen lime',
#  ' alum powder',
#  'Rice',
#  ' sugar',
#  ' nuts',
#  'Condensed milk',
#  ' sugar',
#  ' spices',
#  ' nuts',
#  'Semolina',
#  ' ghee',
#  ' nuts',
#  ' milk',
#  'Khoa',
#  ' coconut',
#  ' molu leaf',
#  'Corn flour',
#  ' ghee',
#  ' dry fruits',
#  'Gram flour',
#  ' ghee',
#  ' sugar',
#  ' milk',
#  ' cardamom',
#  'Chhena',
#  ' sugar',
#  ' ghee',
#  'Chhena',
#  ' sugar',
#  ' milk',
#  'Sugar',
#  ' chenna cheese',
#  'Flour',
#  ' cream',
#  ' sugar',
#  ' saffron',
#  ' lemon juice',
#  ' coconut flakes',
#  'Chenna',
#  ' condensed milk',
#  ' sugar',
#  ' saffron',
#  ' cardamom',
#  'Chhena',
#  ' sugar',
#  ' ghee',
#  'Flour',
#  ' fried milk power',
#  ' sugar syrup',
#  'Yoghurt',
#  ' refined flour',
#  ' ghee',
#  ' fennel seeds',
#  'Besan flour',
#  ' sugar',
#  ' ghee',
#  'Milk',
#  ' jaggery',
#  'Chhena',
#  ' sugar',
#  ' ghee',
#  ' flour',
#  'Rice flour',
#  ' wheat flour',
#  'Chenna',
#  ' sweetened milk',
#  'Chhena',
#  ' reduced milk',
#  ' pistachio',
#  'Chhena',
#  ' sugar',
#  ' cardamom',
#  'Milk',
#  ' sugar',
#  ' saffron',
#  ' cardamom',
#  'Rice flour',
#  ' jaggery',
#  ' ghee',
#  ' vegetable oil',
#  ' elachi',
#  'Rice flour',
#  ' jaggery',
#  ' ghee',
#  'Besan',
#  ' jaggery',
#  ' cardamom powder',
#  ' ghee',
#  ' cashews and raisins',
#  ' jaggery syrup',
#  ' sugar',
#  'Peanuts',
#  ' jaggery',
#  'Milk',
#  ' Sugar',
#  ' Dharwadi buffalo milk',
#  'Loaf bread',
#  ' milk',
#  'Rice flour',
#  ' sugar',
#  ' salt',
#  ' ghee',
#  ' semolina',
#  'Wheat flour',
#  ' sugar',
#  'Black lentils',
#  ' rice',
#  'Besan flour',
#  ' semolina',
#  ' mung bean',
#  ' jaggery',
#  ' coconut',
#  ' skimmed milk powder',
#  ' sugar',
#  ' ghee',
#  'Maida flour',
#  ' turmeric',
#  ' coconut',
#  ' chickpeas',
#  ' jaggery',
#  ' ghee',
#  ' cardamom',
#  'Rice flour',
#  ' milk',
#  'Chana dal',
#  ' jaggery',
#  'Rice',
#  ' jaggery',
#  ' cashews',
#  ' ghee',
#  'Rice flour',
#  ' powdered sugar',
#  ' ghee',
#  'Apricots',
#  ' sugar syrup',
#  'Vermicelli pudding',
#  ' milk',
#  'Rice flour',
#  ' banana',
#  ' jaggery',
#  ' coconut',
#  'Rice flour',
#  ' jaggery',
#  ' coconut',
#  'Rice flour',
#  ' jaggery',
#  ' khus-khus seeds',
#  'Sugar',
#  ' milk',
#  ' nuts',
#  'Cucumber',
#  ' rava',
#  'Milk',
#  ' rice',
#  ' sugar',
#  ' dry fruits',
#  'Semolina',
#  ' sugar',
#  'Rice flour',
#  ' coconut',
#  ' jaggery ',
#  'Sugar',
#  ' ghee',
#  ' maida flour',
#  ' semolina',
#  'Curd',
#  ' sugar',
#  ' saffron',
#  ' cardamom',
#  'Maida',
#  ' sugar',
#  ' ghee',
#  'Fish',
#  ' potol',
#  ' tomato',
#  ' chillies',
#  ' ginger',
#  ' garlic',
#  'Boiled pork',
#  ' onions',
#  ' chillies',
#  ' ginger and garlic',
#  'Rice',
#  ' milk',
#  ' sugar',
#  ' cardamom',
#  'Rice',
#  ' axone',
#  ' salt',
#  ' water',
#  ' chillies',
#  ' pork',
#  'Cauliflower',
#  ' potato',
#  ' garam masala',
#  ' turmeric',
#  ' curry leaves',
#  'Rice flour',
#  ' potato',
#  ' bread crumbs',
#  ' garam masala',
#  ' salt',
#  'Potato',
#  ' peas',
#  ' chillies',
#  ' ginger',
#  ' garam masala',
#  ' garlic',
#  'Potato',
#  ' fenugreek leaves',
#  ' chillies',
#  ' salt',
#  ' oil',
#  'Potato',
#  ' shimla mirch',
#  ' garam masala',
#  ' amchur powder',
#  ' salt',
#  'Chole',
#  ' rava',
#  ' yogurt',
#  ' plain flour',
#  ' baking soda',
#  'Ladies finger',
#  ' garam masala',
#  ' kasuri methi',
#  ' tomatoes',
#  ' chili powder',
#  'Chicken thighs',
#  ' basmati rice',
#  ' star anise',
#  ' sweet',
#  ' green chillies',
#  'Chicken',
#  ' greek yogurt',
#  ' cream',
#  ' garam masala powder',
#  ' cashew nuts',
#  ' butter',
#  'Chickpeas',
#  ' tomato paste',
#  ' garam masala',
#  ' ginger',
#  ' red onion',
#  ' avocado oil',
#  'Whole wheat flour',
#  ' olive oil',
#  ' hot water',
#  ' all purpose flour',
#  'Chicken',
#  ' dahi',
#  ' sesame seeds',
#  ' garam masala powder',
#  ' cashew nuts',
#  ' saffron',
#  'Naan bread',
#  ' tomato sauce',
#  ' skinless chicken breasts',
#  ' heavy cream',
#  ' garam masala',
#  'Chicken',
#  ' whole wheat bread',
#  ' rice flour',
#  ' garam masala powder',
#  ' whole egg',
#  'Chole',
#  ' bhatura',
#  ' garam masala',
#  ' bay leaf',
#  ' cinnamon stick',
#  'Moong dal',
#  ' masoor dal',
#  ' chana dal',
#  ' wheat flour',
#  ' almond',
#  'Moong dal',
#  ' garam masala powder',
#  ' garlic',
#  ' green chilli',
#  ' all purpose flour',
#  'Red kidney beans',
#  ' urad dal',
#  ' cream',
#  ' garam masala',
#  ' chili powder',
#  'Pigeon peas',
#  ' garam masala',
#  ' ginger',
#  ' red onion',
#  ' kasuri methi',
#  'Baby potatoes',
#  ' garam masala',
#  ' cashew nuts',
#  ' kasuri methi',
#  ' tomatoes',
#  'Beaten rice flakes',
#  ' potato',
#  ' curry leaves',
#  ' green chilies',
#  ' lemon juice',
#  'Chana dal',
#  ' whole wheat flour',
#  ' arhar dal',
#  ' white urad dal',
#  ' garam masala powder',
#  'Moong dal',
#  ' rava',
#  ' garam masala',
#  ' dough',
#  ' fennel seeds',
#  'Cottage cheese',
#  ' bell peppers',
#  ' gravy',
#  ' garam masala',
#  ' cashew nuts',
#  'Besan',
#  ' garam masala powder',
#  ' gram flour',
#  ' ginger',
#  ' curry leaves',
#  'Bitter gourd',
#  ' fennel',
#  ' garam masala powder',
#  ' chili powder',
#  ' amchur powder',
#  'Moong dal',
#  ' green peas',
#  ' ginger',
#  ' tomato',
#  ' green chili',
#  'Paneer',
#  ' potato',
#  ' cream',
#  ' corn flour',
#  ' garam masala',
#  'Rose syrup',
#  ' falooda sev',
#  ' mixed nuts',
#  ' saffron',
#  ' sugar',
#  'Bottle gourd',
#  ' garam masala powder',
#  ' gram flour',
#  ' ginger',
#  ' chillies',
#  'Bottle gourd',
#  ' coconut oil',
#  ' garam masala',
#  ' ginger',
#  ' green chillies',
#  'Wheat flour',
#  ' roasted gram flour',
#  ' tomato',
#  ' nigella seeds',
#  ' chilli',
#  'Palak',
#  ' makki atta',
#  ' mustard green',
#  ' garam masala',
#  ' ginger',
#  'Whole wheat flour',
#  ' chickpea flour',
#  ' green chilies',
#  'Mushroom',
#  ' malai',
#  ' garam masala',
#  ' ginger',
#  ' capsicum',
#  'Canned coconut milk',
#  ' frozen green peas',
#  ' wild mushrooms',
#  ' garam masala',
#  ' tomatoes',
#  'Whole wheat flour',
#  ' honey',
#  ' butter',
#  ' garlic',
#  'Green beans',
#  ' potatoes',
#  ' khus khus',
#  ' low fat',
#  ' garam masala powder',
#  'Cottage cheese',
#  ' palak',
#  ' cream',
#  ' garam masala',
#  ' butter',
#  'Paneer',
#  ' whipping cream',
#  ' garam masala',
#  ' cashew nuts',
#  ' butter',
#  'Paneer',
#  ' greek yogurt',
#  ' tandoori masala',
#  ' cream',
#  ' bell pepper',
#  'Kala chana',
#  ' mashed potato',
#  ' boondi',
#  ' sev',
#  ' lemon',
#  'Whole wheat flour',
#  ' musk melon seeds',
#  ' poppy seeds',
#  ' edible gum',
#  ' semolina',
#  'Urad dal',
#  ' sev',
#  ' lemon juice',
#  ' chopped tomatoes',
#  'Wheat flour',
#  ' butter',
#  ' potato',
#  ' coriander',
#  'Arbi ke patte',
#  ' sesame seeds',
#  ' gur',
#  ' bengal gram flour',
#  ' imli',
#  'Fennel',
#  ' tea bags',
#  ' tomato',
#  ' kasuri methi',
#  ' cinnamon',
#  'Red kidney beans',
#  ' garam masala powder',
#  ' ginger',
#  ' tomato',
#  ' mustard oil',
#  'Garam masala powder',
#  ' tomato',
#  ' kasuri methi',
#  ' cinnamon',
#  ' mustard oil',
#  'Potatoes',
#  ' green peas',
#  ' garam masala',
#  ' ginger',
#  ' dough',
#  'Sattu',
#  ' atta',
#  ' dough',
#  ' filling',
#  ' mustard oil',
#  'Cottage cheese',
#  ' malai',
#  ' garam masala',
#  ' ginger',
#  ' tomato',
#  'Rose water',
#  ' milk',
#  ' white bread slices',
#  ' saffron',
#  ' almonds',
#  'Baby corn',
#  ' french beans',
#  ' garam masala',
#  ' ginger',
#  ' carrot',
#  'Greek yogurt',
#  ' garam masala',
#  ' kasuri methi',
#  ' marinade',
#  ' mustard oil',
#  'Chickpea flour',
#  ' biryani masala powder',
#  ' yogurt',
#  ' fish fillets',
#  ' green bell pepper',
#  'Whole wheat flour',
#  ' arhar dal',
#  ' ginger',
#  ' kala jeera',
#  ' green chilli',
#  'Raw banana',
#  ' elephant foot yam',
#  ' long beans',
#  ' tindora',
#  ' urad dal',
#  'Split pigeon peas',
#  ' chana dal',
#  ' urad dal',
#  ' green peas',
#  ' french beans',
#  'Chana dal',
#  ' urad dal',
#  ' fresh coconut',
#  ' sesame seeds',
#  ' curry leaves',
#  'Chana dal',
#  ' urad dal',
#  ' whole urad dal',
#  ' blend rice',
#  ' rock salt',
#  'Rice flour',
#  ' hot water',
#  ' grated coconut',
#  'Split urad dal',
#  ' urad dal',
#  ' idli rice',
#  ' thick poha',
#  ' rock salt',
#  'Carrot',
#  ' yellow mustard',
#  ' red chilli',
#  ' black salt',
#  'Sesame oil',
#  ' drumstick',
#  ' tamarind paste',
#  ' sambar powder',
#  ' tomato',
#  'Moong dal',
#  ' chana dal',
#  ' spinach',
#  ' urad dal',
#  ' coconut oil',
#  'Urad dal',
#  ' curry leaves',
#  ' sugar',
#  ' mustard seeds',
#  ' spinach',
#  'Greens',
#  ' tomato',
#  ' mustard seeds',
#  ' fenugreek seeds',
#  'Amaranth leaves',
#  ' split urad dal',
#  ' mustard seeds',
#  ' grated coconut',
#  ' red chili',
#  'Beef',
#  ' coconut',
#  ' garam masala',
#  ' curry leaves',
#  ' green chilies',
#  ' chili powder',
#  'Chana dal',
#  ' urad dal',
#  ' potato',
#  ' beans',
#  ' peas',
#  'Moong dal',
#  ' chana dal',
#  ' cabbage',
#  ' tamarind',
#  ' curry leaves',
#  'Moong dal',
#  ' cucumber',
#  ' curry leaves',
#  ' green chili',
#  ' lemon juice',
#  'Chana dal',
#  ' urad dal',
#  ' gooseberry',
#  ' raw rice',
#  ' curry leaves',
#  'Sesame oil',
#  ' raw rice',
#  ' jaggery',
#  ' grated coconut',
#  'Pearl onions',
#  ' urad dal',
#  ' drumsticks',
#  ' tomato',
#  ' curry leaves',
#  'Chana dal',
#  ' urad dal',
#  ' potatoes',
#  ' idli rice',
#  ' thick poha',
#  'Coconut oil',
#  ' cucumber',
#  ' curd',
#  ' curry leaves',
#  ' mustard seeds',
#  'Yogurt',
#  ' ginger',
#  ' curry leaves',
#  ' baking soda',
#  ' green chilli',
#  'Lentils',
#  ' black pepper',
#  ' vegetable oil',
#  'Raw rice',
#  '  jaggery',
#  ' milk',
#  'Rice',
#  ' cashew nuts',
#  ' milk',
#  ' raisins',
#  ' sugar',
#  'Arhar dal',
#  ' sambar powder',
#  ' tomato',
#  ' curry leaves',
#  ' fennel seeds',
#  'Green moong beans',
#  ' rice flour',
#  'Chana dal',
#  ' urad dal',
#  ' beans',
#  ' coconut',
#  ' mustard',
#  'Urad dal',
#  ' lemon',
#  ' tamarind',
#  ' cooked rice',
#  ' curry leaves',
#  'Tomato',
#  ' curry leaves',
#  ' garlic',
#  ' mustard seeds',
#  ' hot water',
#  'Brown rice flour',
#  ' sugar',
#  ' grated coconut',
#  'Pigeon peas',
#  ' eggplant',
#  ' drumsticks',
#  ' sambar powder',
#  ' tamarind',
#  'Thin rice flakes',
#  ' black sesame seeds',
#  ' curry leaves',
#  'Sevai',
#  ' parboiled rice',
#  ' steamer',
#  'Urad dal',
#  ' curd',
#  ' sesame oil',
#  ' ginger',
#  ' curry leaves',
#  ' mustard seeds',
#  'Coconut',
#  ' whole red beans',
#  ' masala',
#  ' sesame oil',
#  ' tamarind',
#  'Chana dal',
#  ' urad dal',
#  ' thick poha',
#  ' tomato',
#  ' butter',
#  'Urad dal',
#  ' ginger',
#  ' curry leaves',
#  ' green chilies',
#  ' black pepper',
#  'Meat curry powder',
#  ' chicken chunks',
#  ' ginger',
#  ' tomato',
#  ' cinnamon',
#  'Chana dal',
#  ' urad dal',
#  ' ginger',
#  ' curry leaves',
#  ' sugar',
#  'Kala masala',
#  ' arhar dal',
#  ' curry leaves',
#  ' mustard seeds',
#  ' hot water',
#  'Gram flour',
#  ' mustard',
#  ' garlic',
#  ' turmeric',
#  ' red chilli',
#  'Baingan',
#  ' fish',
#  ' coconut oil',
#  ' fresh coconut',
#  ' ginger',
#  'Urad dal',
#  ' potatoes',
#  ' wheat flour',
#  ' sooji',
#  'Wheat flour',
#  ' pearl millet flour',
#  ' hot water',
#  'Condensed milk',
#  ' mawa',
#  ' desiccated coconut',
#  ' almonds',
#  ' cashews',
#  'Jowar flour',
#  ' sesame seeds',
#  'Bombay duck',
#  ' malvani masala',
#  ' rice flour',
#  ' bombay rava',
#  ' green chilies',
#  'Rice flour',
#  ' sesame',
#  ' plain flour',
#  ' turmeric',
#  ' red chilli',
#  'Citric acid',
#  ' fry',
#  ' raisins',
#  ' sugar',
#  ' chana daal',
#  'Urad dal',
#  ' bengal gram flour',
#  ' dried mango',
#  ' baking soda',
#  ' black salt',
#  'Condensed milk',
#  ' nestle cream',
#  ' coconut ice',
#  ' red food coloring',
#  ' desiccated coconut',
#  'Whole wheat flour',
#  ' dal',
#  ' kokum',
#  ' gur',
#  ' bengal gram flour',
#  'Pav',
#  ' aloo',
#  ' peanut',
#  ' pomegranate',
#  ' star anise',
#  'Urad dal',
#  ' bhuna chana',
#  ' garam masala',
#  ' dates',
#  ' tamarind',
#  'Arhar dal',
#  ' coconut oil',
#  ' curry leaves',
#  ' mustard seeds',
#  ' red chilli',
#  'Rava',
#  ' coconut',
#  ' gram flour',
#  ' mustard',
#  ' sesame',
#  'Bottle gourd',
#  ' green',
#  ' raisins',
#  ' sugar',
#  ' clarified butter',
#  'Yogurt',
#  ' besan',
#  ' sauce',
#  ' garam masala powder',
#  ' gram flour',
#  'Wheat flour',
#  ' jaggery',
#  ' clarified butter',
#  ' sliced almonds',
#  'Dry fruits',
#  ' semolina',
#  ' all purpose flour',
#  'Bottle gourd',
#  ' chana dal',
#  ' cabbage',
#  ' urad dal',
#  ' toor dal',
#  'Whole wheat rava',
#  ' chia seed',
#  ' lemon',
#  ' edible gum',
#  ' litre milk',
#  'Green chilies',
#  ' lemon juice',
#  ' chili powder',
#  ' boiled potatoes',
#  'Wheat flour',
#  ' cashews',
#  ' rapeseed oil',
#  'Mango',
#  ' sugar',
#  'Whole wheat flour',
#  ' low fat',
#  ' bengal gram flour',
#  'Green chili paste',
#  ' white sesame seeds',
#  ' gram flour',
#  ' curry leaves',
#  ' green chili',
#  'Rice flour',
#  ' urad dal',
#  ' wheat flour',
#  ' gram flour',
#  ' turmeric',
#  'Cinnamon',
#  ' jaggery',
#  ' clarified butter',
#  ' dry roasted',
#  'Cucumber',
#  ' carrot',
#  ' tomatoes',
#  ' cilantro',
#  'Rava',
#  ' gram flour',
#  ' lemon juice',
#  ' turmeric',
#  ' fenugreek leaves',
#  'Rose water',
#  ' pistachio',
#  ' badam',
#  ' bengal gram flour',
#  ' saffron',
#  'Bottle gourd',
#  ' whole wheat flour',
#  ' rava',
#  ' sesame seeds',
#  ' bengal gram flour',
#  'Arbi ke patte',
#  ' sesame seeds',
#  ' gur',
#  ' bengal gram flour',
#  ' imli',
#  'Pav bhaji masala',
#  ' gobi',
#  ' potatoes',
#  ' green peas',
#  ' dinner rolls',
#  'Aloo',
#  ' urad dal',
#  ' mustard',
#  ' ginger',
#  ' curry leaves',
#  'Raw peanuts',
#  ' sabudana',
#  ' lemon',
#  ' avocado oil',
#  ' curry leaves',
#  ' green chili',
#  'Khaman',
#  ' pomegranate',
#  ' sev',
#  ' powdered sugar',
#  ' garlic',
#  'Sev',
#  ' ginger',
#  ' tomato',
#  ' sugar',
#  'Wheat flour',
#  ' baking soda',
#  ' all purpose flour',
#  ' black pepper',
#  ' sunflower oil',
#  'Whole wheat flour',
#  ' gur',
#  ' clarified butter',
#  'Rice flakes',
#  ' yogurt',
#  ' raw rice',
#  ' jaggery',
#  ' grated coconut',
#  'Whole wheat flour',
#  ' rice flour',
#  ' pearl millet flour',
#  ' sorghum flour',
#  ' sesame seeds',
#  'Sweet potato',
#  ' surti papdi',
#  ' baby potatoes',
#  ' valor papdi',
#  ' green peas',
#  'Gobi',
#  ' potato',
#  ' beans',
#  ' khus khus',
#  ' coconut',
#  'Chicken',
#  ' coconut oil',
#  ' wine vinegar',
#  ' ginger',
#  ' green',
#  ' cinnamon',
#  'Green garlic chutney',
#  ' fresh green peas',
#  ' ginger',
#  ' lemon juice',
#  ' plain flour',
#  'Moong beans',
#  ' jaggery',
#  ' red chillies',
#  ' oil',
#  ' salt',
#  'Rice flour',
#  ' sesame seeds',
#  ' baking soda',
#  ' peanut oil',
#  'Chickpea flour',
#  ' methi leaves',
#  ' jowar flour',
#  ' wheat flour',
#  'Semolina',
#  ' clarified butter',
#  ' oil',
#  ' white flour',
#  ' black pepper',
#  'Yogurt',
#  ' fresh coconut',
#  ' sesame seeds',
#  ' semolina',
#  ' gram flour',
#  'Ridge gourd',
#  ' baking soda',
#  ' sugar',
#  ' grated coconut',
#  ' peas',
#  'Whole wheat flour',
#  ' khus khus',
#  ' sesame seeds',
#  ' dry coconut',
#  ' gur',
#  'Rice',
#  ' mango',
#  ' curd',
#  'Sticky rice',
#  ' rice flour',
#  ' jaggery',
#  ' orange rind',
#  'Raw papaya',
#  ' panch phoran masala',
#  ' nigella seeds',
#  ' mustard oil',
#  ' fennel seeds',
#  'Rice',
#  ' eggs',
#  ' carrot',
#  ' beetroot',
#  'Maida',
#  ' vegetable oil',
#  'Potatoes',
#  ' mustard oil',
#  ...]

# %%
type(ingredients)
# Out:
# list

# %%
new = pd.DataFrame(ingredients, columns=['ingredients'])
new.head()
# Out:
#    ingredients
# 0  Maida flour
# 1       yogurt
# 2          oil
# 3        sugar
# 4   Gram flour

# %%
new['ingredients'] = new['ingredients'].apply(lambda x: x.lower())
new['ingredients'] = new['ingredients'].apply(lambda x: x.strip())

# %%
new.head()
# Out:
#    ingredients
# 0  maida flour
# 1       yogurt
# 2          oil
# 3        sugar
# 4   gram flour

# %%
def find_word(word):
    """
    Displays the list of words containing the given letters
    
    Parameters
    ----------    
    word : str
        Letters to be used
        'tom'
    """
    filt= new['ingredients'].str.contains(word, na=False)
    print(new.loc[filt,'ingredients'])
    
def change_word(list_words, new_word, word):
    """
    Replace the words given in the list by the new word
    and call the function find_word
    
    Parameters
    ----------
    list_words : list
        Word to be replaced
        ['tomatoes', 'tomato paste', 'tomato sauce', 'chopped tomatoes']
    new_word : str
        Word to be used
        'tomato'
    word : str
        Letters to be used
        'tom'
    """
    
    pattern = '|'.join(list_words)
    new['ingredients'] = new['ingredients'].str.replace(pattern, new_word, regex=True)
    find_word(word)
    #filt= new['ingredients'].str.contains('jag', na=False)
    #new.loc[filt,'ingredients']

# %%
change_word(['tomatoes', 'tomato paste', 'tomato sauce', 'chopped tomatoes'], 'tomato', 'tom')
# Out:
# 242     tomato
# 294     tomato
# 308     tomato
# 324     tomato
# 362     tomato
# 396     tomato
# 420     tomato
# 440     tomato
# 478     tomato
# 490     tomato
# 496     tomato
# 499     tomato
# 517     tomato
# 579     tomato
# 591     tomato
# 632     tomato
# 662     tomato
# 677     tomato
# 710     tomato
# 720     tomato
# 861     tomato
# 906     tomato
# 1005    tomato
# 1014    tomato
# 1067    tomato
# 1081    tomato
# Name: ingredients, dtype: object

# %%
change_word(['yogurt', 'greek yogurt'], 'yoghurt', 'yog')
# Out:
# 1      yoghurt
# 56     yoghurt
# 64     yoghurt
# 117    yoghurt
# 288    yoghurt
# 302    yoghurt
# 461    yoghurt
# 528    yoghurt
# 535    yoghurt
# 644    yoghurt
# 811    yoghurt
# 917    yoghurt
# 965    yoghurt
# Name: ingredients, dtype: object

# %%
change_word(['jaggery syrup'], 'jaggery', 'jag')
# Out:
# 125     jaggery
# 145     jaggery
# 150     jaggery
# 153     jaggery
# 157     jaggery
# 160     jaggery
# 178     jaggery
# 187     jaggery
# 193     jaggery
# 195     jaggery
# 207     jaggery
# 210     jaggery
# 213     jaggery
# 228     jaggery
# 627     jaggery
# 653     jaggery
# 817     jaggery
# 856     jaggery
# 919     jaggery
# 948     jaggery
# 985     jaggery
# 1039    jaggery
# Name: ingredients, dtype: object

# %%
change_word(['milk powder', 'fried milk power', 'reduced milk', 
             'dharwadi buffalo milk', 'skimmed milk powder',
             'litre milk', 'milk powder'], 'milk', 'milk')
# Out:
# 8                      milk
# 16                     milk
# 23                     milk
# 27                     milk
# 46                     milk
# 49                     milk
# 57                     milk
# 73           condensed milk
# 80                     milk
# 90                     milk
# 97                     milk
# 107          condensed milk
# 115                    milk
# 124                    milk
# 133          sweetened milk
# 135                    milk
# 140                    milk
# 161                    milk
# 163                    milk
# 165                    milk
# 180                    milk
# 191                    milk
# 204                    milk
# 216                    milk
# 220                    milk
# 251                    milk
# 436     canned coconut milk
# 519                    milk
# 654                    milk
# 657                    milk
# 749          condensed milk
# 776          condensed milk
# 832                    milk
# 1030           coconut milk
# 1100           coconut milk
# 1118           coconut milk
# 1127                   milk
# Name: ingredients, dtype: object

# %%
change_word(['canned coconut milk'], 'coconut milk', 'milk')
# Out:
# 8                 milk
# 16                milk
# 23                milk
# 27                milk
# 46                milk
# 49                milk
# 57                milk
# 73      condensed milk
# 80                milk
# 90                milk
# 97                milk
# 107     condensed milk
# 115               milk
# 124               milk
# 133     sweetened milk
# 135               milk
# 140               milk
# 161               milk
# 163               milk
# 165               milk
# 180               milk
# 191               milk
# 204               milk
# 216               milk
# 220               milk
# 251               milk
# 436       coconut milk
# 519               milk
# 654               milk
# 657               milk
# 749     condensed milk
# 776     condensed milk
# 832               milk
# 1030      coconut milk
# 1100      coconut milk
# 1118      coconut milk
# 1127              milk
# Name: ingredients, dtype: object

# %%
change_word(['sweetened milk'], 'condensed milk', 'milk')
# Out:
# 8                 milk
# 16                milk
# 23                milk
# 27                milk
# 46                milk
# 49                milk
# 57                milk
# 73      condensed milk
# 80                milk
# 90                milk
# 97                milk
# 107     condensed milk
# 115               milk
# 124               milk
# 133     condensed milk
# 135               milk
# 140               milk
# 161               milk
# 163               milk
# 165               milk
# 180               milk
# 191               milk
# 204               milk
# 216               milk
# 220               milk
# 251               milk
# 436       coconut milk
# 519               milk
# 654               milk
# 657               milk
# 749     condensed milk
# 776     condensed milk
# 832               milk
# 1030      coconut milk
# 1100      coconut milk
# 1118      coconut milk
# 1127              milk
# Name: ingredients, dtype: object

# %%
change_word(['powdered sugar', 'sugar syrup', 'sweet'], 'sugar', 'sug')
# Out:
# 3              sugar
# 6              sugar
# 9              sugar
# 18             sugar
# 28             sugar
# 31             sugar
# 45             sugar
# 48             sugar
# 51             sugar
# 55             sugar
# 59             sugar
# 63             sugar
# 67             sugar
# 71             sugar
# 74             sugar
# 89             sugar
# 93             sugar
# 96             sugar
# 98             sugar
# 102            sugar
# 108            sugar
# 112            sugar
# 116            sugar
# 122            sugar
# 127            sugar
# 138            sugar
# 141            sugar
# 158            sugar
# 162            sugar
# 167            sugar
# 172            sugar
# 181            sugar
# 199            sugar
# 202            sugar
# 215            sugar
# 222            sugar
# 225            sugar
# 229            sugar
# 234            sugar
# 238            sugar
# 252            sugar
# 299            sugar
# 407            sugar
# 587            sugar
# 659            sugar
# 683            sugar
# 726            sugar
# 769            sugar
# 809            sugar
# 841            sugar
# 902            sugar
# 907            sugar
# 926     sugar potato
# 972            sugar
# 1097           sugar
# 1104           sugar
# Name: ingredients, dtype: object

# %%
change_word(['plain flour', 'all purpose flour', 'white flour'], 'flour', 'flo')
# Out:
# 0              maida flour
# 4               gram flour
# 13                   flour
# 24                   flour
# 32            lentil flour
# 34              corn flour
# 53              gram flour
# 60           refined flour
# 84              corn flour
# 87              gram flour
# 100                  flour
# 114                  flour
# 118          refined flour
# 121            besan flour
# 129                  flour
# 130             rice flour
# 131            wheat flour
# 144             rice flour
# 149             rice flour
# 166             rice flour
# 171            wheat flour
# 175            besan flour
# 183            maida flour
# 190             rice flour
# 198             rice flour
# 205             rice flour
# 209             rice flour
# 212             rice flour
# 226             rice flour
# 231            maida flour
# 260            cauliflower
# 265             rice flour
# 289                  flour
# 313      whole wheat flour
# 316                  flour
# 330             rice flour
# 341            wheat flour
# 347                  flour
# 369      whole wheat flour
# 385             gram flour
# 401             corn flour
# 410             gram flour
# 418            wheat flour
# 419     roasted gram flour
# 428      whole wheat flour
# 429         chickpea flour
# 441      whole wheat flour
# 470      whole wheat flour
# 479            wheat flour
# 486      bengal gram flour
# 533         chickpea flour
# 538      whole wheat flour
# 563             rice flour
# 666             rice flour
# 682       brown rice flour
# 732             gram flour
# 744            wheat flour
# 746            wheat flour
# 747     pearl millet flour
# 754            jowar flour
# 758             rice flour
# 761             rice flour
# 763                  flour
# 772      bengal gram flour
# 781      whole wheat flour
# 785      bengal gram flour
# 803             gram flour
# 815             gram flour
# 816            wheat flour
# 822                  flour
# 837            wheat flour
# 842      whole wheat flour
# 844      bengal gram flour
# 847             gram flour
# 850             rice flour
# 852            wheat flour
# 853             gram flour
# 864             gram flour
# 871      bengal gram flour
# 874      whole wheat flour
# 877      bengal gram flour
# 881      bengal gram flour
# 908            wheat flour
# 910                  flour
# 912          sunflower oil
# 913      whole wheat flour
# 921      whole wheat flour
# 922             rice flour
# 923     pearl millet flour
# 924          sorghum flour
# 946                  flour
# 952             rice flour
# 956         chickpea flour
# 958            jowar flour
# 959            wheat flour
# 963                  flour
# 969             gram flour
# 975      whole wheat flour
# 984             rice flour
# 1038                 flour
# 1061         banana flower
# 1071            rice flour
# 1074            gram flour
# 1078       pumpkin flowers
# 1121                 flour
# 1130                 flour
# Name: ingredients, dtype: object

# %%
change_word(['whole wheat flour'], 'wheat flour', 'flo')
# Out:
# 0              maida flour
# 4               gram flour
# 13                   flour
# 24                   flour
# 32            lentil flour
# 34              corn flour
# 53              gram flour
# 60           refined flour
# 84              corn flour
# 87              gram flour
# 100                  flour
# 114                  flour
# 118          refined flour
# 121            besan flour
# 129                  flour
# 130             rice flour
# 131            wheat flour
# 144             rice flour
# 149             rice flour
# 166             rice flour
# 171            wheat flour
# 175            besan flour
# 183            maida flour
# 190             rice flour
# 198             rice flour
# 205             rice flour
# 209             rice flour
# 212             rice flour
# 226             rice flour
# 231            maida flour
# 260            cauliflower
# 265             rice flour
# 289                  flour
# 313            wheat flour
# 316                  flour
# 330             rice flour
# 341            wheat flour
# 347                  flour
# 369            wheat flour
# 385             gram flour
# 401             corn flour
# 410             gram flour
# 418            wheat flour
# 419     roasted gram flour
# 428            wheat flour
# 429         chickpea flour
# 441            wheat flour
# 470            wheat flour
# 479            wheat flour
# 486      bengal gram flour
# 533         chickpea flour
# 538            wheat flour
# 563             rice flour
# 666             rice flour
# 682       brown rice flour
# 732             gram flour
# 744            wheat flour
# 746            wheat flour
# 747     pearl millet flour
# 754            jowar flour
# 758             rice flour
# 761             rice flour
# 763                  flour
# 772      bengal gram flour
# 781            wheat flour
# 785      bengal gram flour
# 803             gram flour
# 815             gram flour
# 816            wheat flour
# 822                  flour
# 837            wheat flour
# 842            wheat flour
# 844      bengal gram flour
# 847             gram flour
# 850             rice flour
# 852            wheat flour
# 853             gram flour
# 864             gram flour
# 871      bengal gram flour
# 874            wheat flour
# 877      bengal gram flour
# 881      bengal gram flour
# 908            wheat flour
# 910                  flour
# 912          sunflower oil
# 913            wheat flour
# 921            wheat flour
# 922             rice flour
# 923     pearl millet flour
# 924          sorghum flour
# 946                  flour
# 952             rice flour
# 956         chickpea flour
# 958            jowar flour
# 959            wheat flour
# 963                  flour
# 969             gram flour
# 975            wheat flour
# 984             rice flour
# 1038                 flour
# 1061         banana flower
# 1071            rice flour
# 1074            gram flour
# 1078       pumpkin flowers
# 1121                 flour
# 1130                 flour
# Name: ingredients, dtype: object

# %%
change_word(['gram flour', 'bengal gram flour', 'roasted gram flour', 'besan flour', 'besan', 'sattu'], 'chickpea flour', 'flo')
# Out:
# 0              maida flour
# 4           chickpea flour
# 13                   flour
# 24                   flour
# 32            lentil flour
# 34              corn flour
# 53          chickpea flour
# 60           refined flour
# 61          chickpea flour
# 84              corn flour
# 87          chickpea flour
# 100                  flour
# 114                  flour
# 118          refined flour
# 121         chickpea flour
# 129                  flour
# 130             rice flour
# 131            wheat flour
# 144             rice flour
# 149             rice flour
# 152         chickpea flour
# 166             rice flour
# 171            wheat flour
# 175         chickpea flour
# 183            maida flour
# 190             rice flour
# 198             rice flour
# 205             rice flour
# 209             rice flour
# 212             rice flour
# 226             rice flour
# 231            maida flour
# 260            cauliflower
# 265             rice flour
# 289                  flour
# 313            wheat flour
# 316                  flour
# 330             rice flour
# 341            wheat flour
# 347                  flour
# 369            wheat flour
# 383         chickpea flour
# 385         chickpea flour
# 401             corn flour
# 410         chickpea flour
# 418            wheat flour
# 419         chickpea flour
# 428            wheat flour
# 429         chickpea flour
# 441            wheat flour
# 470            wheat flour
# 479            wheat flour
# 486         chickpea flour
# 508         chickpea flour
# 533         chickpea flour
# 538            wheat flour
# 563             rice flour
# 666             rice flour
# 682       brown rice flour
# 732         chickpea flour
# 744            wheat flour
# 746            wheat flour
# 747     pearl millet flour
# 754            jowar flour
# 758             rice flour
# 761             rice flour
# 763                  flour
# 772         chickpea flour
# 781            wheat flour
# 785         chickpea flour
# 803         chickpea flour
# 812         chickpea flour
# 815         chickpea flour
# 816            wheat flour
# 822                  flour
# 837            wheat flour
# 842            wheat flour
# 844         chickpea flour
# 847         chickpea flour
# 850             rice flour
# 852            wheat flour
# 853         chickpea flour
# 864         chickpea flour
# 871         chickpea flour
# 874            wheat flour
# 877         chickpea flour
# 881         chickpea flour
# 908            wheat flour
# 910                  flour
# 912          sunflower oil
# 913            wheat flour
# 921            wheat flour
# 922             rice flour
# 923     pearl millet flour
# 924          sorghum flour
# 946                  flour
# 952             rice flour
# 956         chickpea flour
# 958            jowar flour
# 959            wheat flour
# 963                  flour
# 969         chickpea flour
# 975            wheat flour
# 984             rice flour
# 1038                 flour
# 1052        chickpea flour
# 1061         banana flower
# 1071            rice flour
# 1074        chickpea flour
# 1078       pumpkin flowers
# 1121                 flour
# 1130                 flour
# Name: ingredients, dtype: object

# %%
change_word(['brown rice flour'], 'rice flour', 'flo')
# Out:
# 0              maida flour
# 4           chickpea flour
# 13                   flour
# 24                   flour
# 32            lentil flour
# 34              corn flour
# 53          chickpea flour
# 60           refined flour
# 61          chickpea flour
# 84              corn flour
# 87          chickpea flour
# 100                  flour
# 114                  flour
# 118          refined flour
# 121         chickpea flour
# 129                  flour
# 130             rice flour
# 131            wheat flour
# 144             rice flour
# 149             rice flour
# 152         chickpea flour
# 166             rice flour
# 171            wheat flour
# 175         chickpea flour
# 183            maida flour
# 190             rice flour
# 198             rice flour
# 205             rice flour
# 209             rice flour
# 212             rice flour
# 226             rice flour
# 231            maida flour
# 260            cauliflower
# 265             rice flour
# 289                  flour
# 313            wheat flour
# 316                  flour
# 330             rice flour
# 341            wheat flour
# 347                  flour
# 369            wheat flour
# 383         chickpea flour
# 385         chickpea flour
# 401             corn flour
# 410         chickpea flour
# 418            wheat flour
# 419         chickpea flour
# 428            wheat flour
# 429         chickpea flour
# 441            wheat flour
# 470            wheat flour
# 479            wheat flour
# 486         chickpea flour
# 508         chickpea flour
# 533         chickpea flour
# 538            wheat flour
# 563             rice flour
# 666             rice flour
# 682             rice flour
# 732         chickpea flour
# 744            wheat flour
# 746            wheat flour
# 747     pearl millet flour
# 754            jowar flour
# 758             rice flour
# 761             rice flour
# 763                  flour
# 772         chickpea flour
# 781            wheat flour
# 785         chickpea flour
# 803         chickpea flour
# 812         chickpea flour
# 815         chickpea flour
# 816            wheat flour
# 822                  flour
# 837            wheat flour
# 842            wheat flour
# 844         chickpea flour
# 847         chickpea flour
# 850             rice flour
# 852            wheat flour
# 853         chickpea flour
# 864         chickpea flour
# 871         chickpea flour
# 874            wheat flour
# 877         chickpea flour
# 881         chickpea flour
# 908            wheat flour
# 910                  flour
# 912          sunflower oil
# 913            wheat flour
# 921            wheat flour
# 922             rice flour
# 923     pearl millet flour
# 924          sorghum flour
# 946                  flour
# 952             rice flour
# 956         chickpea flour
# 958            jowar flour
# 959            wheat flour
# 963                  flour
# 969         chickpea flour
# 975            wheat flour
# 984             rice flour
# 1038                 flour
# 1052        chickpea flour
# 1061         banana flower
# 1071            rice flour
# 1074        chickpea flour
# 1078       pumpkin flowers
# 1121                 flour
# 1130                 flour
# Name: ingredients, dtype: object

# %%
change_word(['sorghum flour'], 'jowar flour', 'flo')
# Out:
# 0              maida flour
# 4           chickpea flour
# 13                   flour
# 24                   flour
# 32            lentil flour
# 34              corn flour
# 53          chickpea flour
# 60           refined flour
# 61          chickpea flour
# 84              corn flour
# 87          chickpea flour
# 100                  flour
# 114                  flour
# 118          refined flour
# 121         chickpea flour
# 129                  flour
# 130             rice flour
# 131            wheat flour
# 144             rice flour
# 149             rice flour
# 152         chickpea flour
# 166             rice flour
# 171            wheat flour
# 175         chickpea flour
# 183            maida flour
# 190             rice flour
# 198             rice flour
# 205             rice flour
# 209             rice flour
# 212             rice flour
# 226             rice flour
# 231            maida flour
# 260            cauliflower
# 265             rice flour
# 289                  flour
# 313            wheat flour
# 316                  flour
# 330             rice flour
# 341            wheat flour
# 347                  flour
# 369            wheat flour
# 383         chickpea flour
# 385         chickpea flour
# 401             corn flour
# 410         chickpea flour
# 418            wheat flour
# 419         chickpea flour
# 428            wheat flour
# 429         chickpea flour
# 441            wheat flour
# 470            wheat flour
# 479            wheat flour
# 486         chickpea flour
# 508         chickpea flour
# 533         chickpea flour
# 538            wheat flour
# 563             rice flour
# 666             rice flour
# 682             rice flour
# 732         chickpea flour
# 744            wheat flour
# 746            wheat flour
# 747     pearl millet flour
# 754            jowar flour
# 758             rice flour
# 761             rice flour
# 763                  flour
# 772         chickpea flour
# 781            wheat flour
# 785         chickpea flour
# 803         chickpea flour
# 812         chickpea flour
# 815         chickpea flour
# 816            wheat flour
# 822                  flour
# 837            wheat flour
# 842            wheat flour
# 844         chickpea flour
# 847         chickpea flour
# 850             rice flour
# 852            wheat flour
# 853         chickpea flour
# 864         chickpea flour
# 871         chickpea flour
# 874            wheat flour
# 877         chickpea flour
# 881         chickpea flour
# 908            wheat flour
# 910                  flour
# 912          sunflower oil
# 913            wheat flour
# 921            wheat flour
# 922             rice flour
# 923     pearl millet flour
# 924            jowar flour
# 946                  flour
# 952             rice flour
# 956         chickpea flour
# 958            jowar flour
# 959            wheat flour
# 963                  flour
# 969         chickpea flour
# 975            wheat flour
# 984             rice flour
# 1038                 flour
# 1052        chickpea flour
# 1061         banana flower
# 1071            rice flour
# 1074        chickpea flour
# 1078       pumpkin flowers
# 1121                 flour
# 1130                 flour
# Name: ingredients, dtype: object

# %%
change_word(['almonds', 'sliced almonds', 'slivered almonds', 'badam'], 'almond', 'alm')
# Out:
# 19      almond
# 342     almond
# 522     almond
# 752     almond
# 819     almond
# 870     almond
# 1020    almond
# 1126    almond
# Name: ingredients, dtype: object

# %%
change_word(['aloo', 'baby potatoes', 'mashed potato', 
             'potatoes', 'boiled potatoes'], 'potato', 'pota')
# Out:
# 261            potato
# 266            potato
# 270            potato
# 276            potato
# 281            potato
# 358            potato
# 364            potato
# 399            potato
# 404     fpotatoda sev
# 446            potato
# 466            potato
# 481            potato
# 503            potato
# 607            potato
# 636            potato
# 743            potato
# 787            potato
# 836            potato
# 885            potato
# 888            potato
# 926      sugar potato
# 928            potato
# 932            potato
# 998            potato
# 1012           potato
# 1057           potato
# 1066           potato
# Name: ingredients, dtype: object

# %%
change_word(['atta', 'makki atta'], 'corn flour', 'att')
# Out:
# 483    arbi ke patte
# 878    arbi ke patte
# Name: ingredients, dtype: object

# %%
change_word(['  baking soda'], 'baking soda', 'baki')
# Out:
# 25      baking powder
# 35        baking soda
# 290       baking soda
# 647       baking soda
# 774       baking soda
# 909       baking soda
# 954       baking soda
# 971       baking soda
# 1035      baking soda
# 1076    baking powder
# Name: ingredients, dtype: object

# %%
change_word(['raw banana'], 'banana', 'ban')
# Out:
# 206            banana
# 543            banana
# 1061    banana flower
# 1073           banana
# 1113           banana
# Name: ingredients, dtype: object

# %%
change_word(['brown rice', 'glutinous rice', 'basmati rice', 
             'soaked rice', 'cooked rice', 'forbidden black rice', 
             'sticky rice', 'raw rice', 'parboiled rice', 'idli rice', 'blend rice'], 'rice', 'ric')
# Out:
# 39                turmeric
# 50                    rice
# 70                    rice
# 130             rice flour
# 144             rice flour
# 149             rice flour
# 166             rice flour
# 174                   rice
# 184               turmeric
# 190             rice flour
# 194                   rice
# 198             rice flour
# 201               apricots
# 205             rice flour
# 209             rice flour
# 212             rice flour
# 221                   rice
# 226             rice flour
# 250                   rice
# 254                   rice
# 263               turmeric
# 265             rice flour
# 297                   rice
# 330             rice flour
# 363     beaten rice flakes
# 561                   rice
# 563             rice flour
# 568                   rice
# 623                   rice
# 626                   rice
# 637                   rice
# 652                   rice
# 655                   rice
# 666             rice flour
# 675                   rice
# 682             rice flour
# 690       thin rice flakes
# 694                   rice
# 735               turmeric
# 758             rice flour
# 761             rice flour
# 764               turmeric
# 766            citric acid
# 850             rice flour
# 854               turmeric
# 866               turmeric
# 916            rice flakes
# 918                   rice
# 922             rice flour
# 952             rice flour
# 980                   rice
# 983                   rice
# 984             rice flour
# 992                   rice
# 1017                  rice
# 1027                  rice
# 1044              turmeric
# 1071            rice flour
# 1080              turmeric
# 1088                  rice
# 1094                  rice
# 1095                  rice
# 1103              turmeric
# 1115                  rice
# 1131                  rice
# Name: ingredients, dtype: object

# %%
change_word(['thin rice flakes', 'beaten rice flakes'], 'rice flakes', 'rice fla')
# Out:
# 363    rice flakes
# 690    rice flakes
# 916    rice flakes
# Name: ingredients, dtype: object

# %%
change_word(['whole red beans', 'red kidney beans'], 'beans', 'bea')
# Out:
# 177             mung bean
# 348                 beans
# 445           green beans
# 493                 beans
# 524          french beans
# 545            long beans
# 552          french beans
# 608                 beans
# 665     green moong beans
# 669                 beans
# 703                 beans
# 933                 beans
# 947           moong beans
# 1110          green beans
# Name: ingredients, dtype: object

# %%
change_word(['mung bean', 'moong beans', 'green moong beans'], 'moong beans', 'bea')
# Out:
# 177      moong beans
# 348            beans
# 445      green beans
# 493            beans
# 524     french beans
# 545       long beans
# 552     french beans
# 608            beans
# 665      moong beans
# 669            beans
# 703            beans
# 933            beans
# 947      moong beans
# 1110     green beans
# Name: ingredients, dtype: object

# %%
change_word(['bell peppers', 'green bell pepper', 'shimla mirch', 'capsicum'], 'bell pepper', 'bell')
# Out:
# 282    bell pepper
# 379    bell pepper
# 435    bell pepper
# 464    bell pepper
# 537    bell pepper
# Name: ingredients, dtype: object

# %%
change_word(['green cardamom', 'cardamom pods', 'elachi', 'cardamom powder'], 'cardamom', 'carda')
# Out:
# 22      cardamom
# 41      cardamom
# 44      cardamom
# 65      cardamom
# 91      cardamom
# 110     cardamom
# 139     cardamom
# 143     cardamom
# 148     cardamom
# 154     cardamom
# 189     cardamom
# 236     cardamom
# 253     cardamom
# 1099    cardamom
# Name: ingredients, dtype: object

# %%
change_word(['carrots'], 'carrot', 'carr')
# Out:
# 7      carrot
# 527    carrot
# 571    carrot
# 860    carrot
# 994    carrot
# Name: ingredients, dtype: object

# %%
change_word(['cashews'], 'cashew nuts', 'cash')
# Out:
# 11                  cashew nuts
# 42                  cashew nuts
# 156     cashew nuts and raisins
# 196                 cashew nuts
# 305                 cashew nuts
# 321                 cashew nuts
# 360                 cashew nuts
# 382                 cashew nuts
# 458                 cashew nuts
# 656                 cashew nuts
# 753                 cashew nuts
# 838                 cashew nuts
# 1136                cashew nuts
# Name: ingredients, dtype: object

# %%
change_word(['grated coconut', 'dry coconut', 'fresh coconut', 'desiccated coconut', 'coconut flakes'], 'coconut', 'nut')
# Out:
# 11                  cashew nuts
# 42                  cashew nuts
# 58                         nuts
# 72                         nuts
# 76                         nuts
# 79                         nuts
# 82                      coconut
# 105                     coconut
# 156     cashew nuts and raisins
# 159                     peanuts
# 179                     coconut
# 185                     coconut
# 196                 cashew nuts
# 208                     coconut
# 211                     coconut
# 217                        nuts
# 227                     coconut
# 305                 cashew nuts
# 321                 cashew nuts
# 360                 cashew nuts
# 382                 cashew nuts
# 405                  mixed nuts
# 414                 coconut oil
# 436                coconut milk
# 458                 cashew nuts
# 555                     coconut
# 565                     coconut
# 584                 coconut oil
# 597                     coconut
# 600                     coconut
# 628                     coconut
# 639                 coconut oil
# 656                 cashew nuts
# 670                     coconut
# 684                     coconut
# 702                     coconut
# 739                 coconut oil
# 740                     coconut
# 751                     coconut
# 753                 cashew nuts
# 778                 coconut ice
# 780                     coconut
# 788                      peanut
# 797                 coconut oil
# 802                     coconut
# 838                 cashew nuts
# 893                 raw peanuts
# 920                     coconut
# 935                     coconut
# 937                 coconut oil
# 955                  peanut oil
# 966                     coconut
# 973                     coconut
# 978                     coconut
# 1030               coconut milk
# 1046                    coconut
# 1083                    coconut
# 1093                    coconut
# 1100               coconut milk
# 1118               coconut milk
# 1133                    coconut
# 1136                cashew nuts
# Name: ingredients, dtype: object

# %%
change_word(['raw peanuts'], 'peanut', 'nut')
# Out:
# 11                  cashew nuts
# 42                  cashew nuts
# 58                         nuts
# 72                         nuts
# 76                         nuts
# 79                         nuts
# 82                      coconut
# 105                     coconut
# 156     cashew nuts and raisins
# 159                     peanuts
# 179                     coconut
# 185                     coconut
# 196                 cashew nuts
# 208                     coconut
# 211                     coconut
# 217                        nuts
# 227                     coconut
# 305                 cashew nuts
# 321                 cashew nuts
# 360                 cashew nuts
# 382                 cashew nuts
# 405                  mixed nuts
# 414                 coconut oil
# 436                coconut milk
# 458                 cashew nuts
# 555                     coconut
# 565                     coconut
# 584                 coconut oil
# 597                     coconut
# 600                     coconut
# 628                     coconut
# 639                 coconut oil
# 656                 cashew nuts
# 670                     coconut
# 684                     coconut
# 702                     coconut
# 739                 coconut oil
# 740                     coconut
# 751                     coconut
# 753                 cashew nuts
# 778                 coconut ice
# 780                     coconut
# 788                      peanut
# 797                 coconut oil
# 802                     coconut
# 838                 cashew nuts
# 893                      peanut
# 920                     coconut
# 935                     coconut
# 937                 coconut oil
# 955                  peanut oil
# 966                     coconut
# 973                     coconut
# 978                     coconut
# 1030               coconut milk
# 1046                    coconut
# 1083                    coconut
# 1093                    coconut
# 1100               coconut milk
# 1118               coconut milk
# 1133                    coconut
# 1136                cashew nuts
# Name: ingredients, dtype: object

# %%
change_word(['mixed nuts'], 'nuts', 'nut')
# Out:
# 11                  cashew nuts
# 42                  cashew nuts
# 58                         nuts
# 72                         nuts
# 76                         nuts
# 79                         nuts
# 82                      coconut
# 105                     coconut
# 156     cashew nuts and raisins
# 159                     peanuts
# 179                     coconut
# 185                     coconut
# 196                 cashew nuts
# 208                     coconut
# 211                     coconut
# 217                        nuts
# 227                     coconut
# 305                 cashew nuts
# 321                 cashew nuts
# 360                 cashew nuts
# 382                 cashew nuts
# 405                        nuts
# 414                 coconut oil
# 436                coconut milk
# 458                 cashew nuts
# 555                     coconut
# 565                     coconut
# 584                 coconut oil
# 597                     coconut
# 600                     coconut
# 628                     coconut
# 639                 coconut oil
# 656                 cashew nuts
# 670                     coconut
# 684                     coconut
# 702                     coconut
# 739                 coconut oil
# 740                     coconut
# 751                     coconut
# 753                 cashew nuts
# 778                 coconut ice
# 780                     coconut
# 788                      peanut
# 797                 coconut oil
# 802                     coconut
# 838                 cashew nuts
# 893                      peanut
# 920                     coconut
# 935                     coconut
# 937                 coconut oil
# 955                  peanut oil
# 966                     coconut
# 973                     coconut
# 978                     coconut
# 1030               coconut milk
# 1046                    coconut
# 1083                    coconut
# 1093                    coconut
# 1100               coconut milk
# 1118               coconut milk
# 1133                    coconut
# 1136                cashew nuts
# Name: ingredients, dtype: object

# %%
change_word(['cashew nuts and raisins'], 'raisins', 'nut')
# Out:
# 11       cashew nuts
# 42       cashew nuts
# 58              nuts
# 72              nuts
# 76              nuts
# 79              nuts
# 82           coconut
# 105          coconut
# 159          peanuts
# 179          coconut
# 185          coconut
# 196      cashew nuts
# 208          coconut
# 211          coconut
# 217             nuts
# 227          coconut
# 305      cashew nuts
# 321      cashew nuts
# 360      cashew nuts
# 382      cashew nuts
# 405             nuts
# 414      coconut oil
# 436     coconut milk
# 458      cashew nuts
# 555          coconut
# 565          coconut
# 584      coconut oil
# 597          coconut
# 600          coconut
# 628          coconut
# 639      coconut oil
# 656      cashew nuts
# 670          coconut
# 684          coconut
# 702          coconut
# 739      coconut oil
# 740          coconut
# 751          coconut
# 753      cashew nuts
# 778      coconut ice
# 780          coconut
# 788           peanut
# 797      coconut oil
# 802          coconut
# 838      cashew nuts
# 893           peanut
# 920          coconut
# 935          coconut
# 937      coconut oil
# 955       peanut oil
# 966          coconut
# 973          coconut
# 978          coconut
# 1030    coconut milk
# 1046         coconut
# 1083         coconut
# 1093         coconut
# 1100    coconut milk
# 1118    coconut milk
# 1133         coconut
# 1136     cashew nuts
# Name: ingredients, dtype: object

# %%
change_word(['clarified butter'], 'ghee', 'but')
# Out:
# 306     butter
# 443     butter
# 454     butter
# 459     butter
# 480     butter
# 711     butter
# 1107    butter
# Name: ingredients, dtype: object

# %%
change_word(['hot water'], 'water', 'wat')
# Out:
# 29           water
# 30      rose water
# 38           water
# 257          water
# 315          water
# 518     rose water
# 564          water
# 681          water
# 731          water
# 748          water
# 868     rose water
# 1096    rose water
# 1108    watercress
# Name: ingredients, dtype: object

# %%
change_word(['heavy cream', 'whipping cream', 'nestle cream'], 'cream', 'cr')
# Out:
# 101            cream
# 267     bread crumbs
# 303            cream
# 326            cream
# 350            cream
# 400            cream
# 452            cream
# 456            cream
# 463            cream
# 777            cream
# 1108      watercress
# Name: ingredients, dtype: object

# %%
change_word(['black lentils'], 'lentils', 'len')
# Out:
# 32     lentil flour
# 173         lentils
# 649         lentils
# Name: ingredients, dtype: object

# %%
change_word(['chenna cheese'], 'chenna', 'che')
# Out:
# 47      cottage cheese
# 68        kitchen lime
# 99              chenna
# 106             chenna
# 132             chenna
# 378     cottage cheese
# 450     cottage cheese
# 513     cottage cheese
# 1122    cottage cheese
# Name: ingredients, dtype: object

# %%
change_word(['chenna'], 'chenna cheese', 'che')
# Out:
# 47      cottage cheese
# 68        kitchen lime
# 99       chenna cheese
# 106      chenna cheese
# 132      chenna cheese
# 378     cottage cheese
# 450     cottage cheese
# 513     cottage cheese
# 1122    cottage cheese
# Name: ingredients, dtype: object

# %%
change_word(['khus-khus seeds'], 'khus khus', 'khus khus')
# Out:
# 214    khus khus
# 447    khus khus
# 934    khus khus
# 976    khus khus
# Name: ingredients, dtype: object

# %%
change_word(['leaf'], 'leaves', 'lea')
# Out:
# 83           molu leaves
# 264         curry leaves
# 277     fenugreek leaves
# 336           bay leaves
# 365         curry leaves
# 387         curry leaves
# 557         curry leaves
# 586         curry leaves
# 594      amaranth leaves
# 602         curry leaves
# 614         curry leaves
# 617         curry leaves
# 624         curry leaves
# 633         curry leaves
# 642         curry leaves
# 646         curry leaves
# 663         curry leaves
# 676         curry leaves
# 678         curry leaves
# 692         curry leaves
# 700         curry leaves
# 714         curry leaves
# 725         curry leaves
# 729         curry leaves
# 798         curry leaves
# 848         curry leaves
# 867     fenugreek leaves
# 892         curry leaves
# 897         curry leaves
# 957         methi leaves
# 1016          bay leaves
# 1045          bay leaves
# 1069          bay leaves
# 1089        curry leaves
# 1091          tea leaves
# Name: ingredients, dtype: object

# %%
change_word(['chenna cheese', 'chhena'], 'curd', 'che')
# Out:
# 47      cottage cheese
# 68        kitchen lime
# 378     cottage cheese
# 450     cottage cheese
# 513     cottage cheese
# 1122    cottage cheese
# Name: ingredients, dtype: object

# %%
change_word(['lemon juice'], 'lemon', 'lem')
# Out:
# 104     lemon
# 367     lemon
# 469     lemon
# 477     lemon
# 619     lemon
# 673     lemon
# 830     lemon
# 834     lemon
# 865     lemon
# 895     lemon
# 945     lemon
# 1004    lemon
# 1053    lemon
# 1065    lemon
# Name: ingredients, dtype: object

# %%
change_word(['seeds'], 'seed', 'seed')
# Out:
# 120           fennel seed
# 319           sesame seed
# 377           fennel seed
# 421          nigella seed
# 471       musk melon seed
# 472            poppy seed
# 484           sesame seed
# 556           sesame seed
# 588          mustard seed
# 592          mustard seed
# 593        fenugreek seed
# 596          mustard seed
# 643          mustard seed
# 664           fennel seed
# 680          mustard seed
# 691     black sesame seed
# 701          mustard seed
# 730          mustard seed
# 755           sesame seed
# 799          mustard seed
# 829             chia seed
# 839          rapeseed oil
# 846     white sesame seed
# 876           sesame seed
# 879           sesame seed
# 925           sesame seed
# 953           sesame seed
# 967           sesame seed
# 977           sesame seed
# 989          nigella seed
# 991           fennel seed
# 1010          sesame seed
# 1026         mustard seed
# 1049         mustard seed
# 1092    white sesame seed
# 1116    black sesame seed
# 1132          fennel seed
# Name: ingredients, dtype: object

# %%
change_word(['seed'], 'seeds', 'seed')
# Out:
# 120           fennel seeds
# 319           sesame seeds
# 377           fennel seeds
# 421          nigella seeds
# 471       musk melon seeds
# 472            poppy seeds
# 484           sesame seeds
# 556           sesame seeds
# 588          mustard seeds
# 592          mustard seeds
# 593        fenugreek seeds
# 596          mustard seeds
# 643          mustard seeds
# 664           fennel seeds
# 680          mustard seeds
# 691     black sesame seeds
# 701          mustard seeds
# 730          mustard seeds
# 755           sesame seeds
# 799          mustard seeds
# 829             chia seeds
# 839          rapeseeds oil
# 846     white sesame seeds
# 876           sesame seeds
# 879           sesame seeds
# 925           sesame seeds
# 953           sesame seeds
# 967           sesame seeds
# 977           sesame seeds
# 989          nigella seeds
# 991           fennel seeds
# 1010          sesame seeds
# 1026         mustard seeds
# 1049         mustard seeds
# 1092    white sesame seeds
# 1116    black sesame seeds
# 1132          fennel seeds
# Name: ingredients, dtype: object

# %%
change_word(['black sesame seeds', 'white sesame seeds'], 'sesame seeds', 'seed')
# Out:
# 120         fennel seeds
# 319         sesame seeds
# 377         fennel seeds
# 421        nigella seeds
# 471     musk melon seeds
# 472          poppy seeds
# 484         sesame seeds
# 556         sesame seeds
# 588        mustard seeds
# 592        mustard seeds
# 593      fenugreek seeds
# 596        mustard seeds
# 643        mustard seeds
# 664         fennel seeds
# 680        mustard seeds
# 691         sesame seeds
# 701        mustard seeds
# 730        mustard seeds
# 755         sesame seeds
# 799        mustard seeds
# 829           chia seeds
# 839        rapeseeds oil
# 846         sesame seeds
# 876         sesame seeds
# 879         sesame seeds
# 925         sesame seeds
# 953         sesame seeds
# 967         sesame seeds
# 977         sesame seeds
# 989        nigella seeds
# 991         fennel seeds
# 1010        sesame seeds
# 1026       mustard seeds
# 1049       mustard seeds
# 1092        sesame seeds
# 1116        sesame seeds
# 1132        fennel seeds
# Name: ingredients, dtype: object

# %%
change_word(['loaf bread', 'bread crumbs', 'white bread slices'], 'bread', 'bread')
# Out:
# 164                bread
# 267                bread
# 323           naan bread
# 329    whole wheat bread
# 520                bread
# Name: ingredients, dtype: object

# %%
change_word(['garam masala powder'], 'garam masala', 'masala')
# Out:
# 262              garam masala
# 268              garam masala
# 274              garam masala
# 283              garam masala
# 292              garam masala
# 304              garam masala
# 309              garam masala
# 320              garam masala
# 327              garam masala
# 331              garam masala
# 335              garam masala
# 344              garam masala
# 351              garam masala
# 354              garam masala
# 359              garam masala
# 372              garam masala
# 375              garam masala
# 381              garam masala
# 384              garam masala
# 390              garam masala
# 402              garam masala
# 409              garam masala
# 415              garam masala
# 426              garam masala
# 433              garam masala
# 439              garam masala
# 449              garam masala
# 453              garam masala
# 457              garam masala
# 462           tandoori masala
# 494              garam masala
# 498              garam masala
# 505              garam masala
# 515              garam masala
# 525              garam masala
# 529              garam masala
# 534     biryani masala powder
# 601              garam masala
# 704                    masala
# 727               kala masala
# 757            malvani masala
# 793              garam masala
# 814              garam masala
# 883          pav bhaji masala
# 988       panch phoran masala
# 1013             garam masala
# 1022           biryani masala
# 1042             garam masala
# Name: ingredients, dtype: object

# %%
change_word(['biryani masala powder'], 'biryani masala', 'masala')
# Out:
# 262            garam masala
# 268            garam masala
# 274            garam masala
# 283            garam masala
# 292            garam masala
# 304            garam masala
# 309            garam masala
# 320            garam masala
# 327            garam masala
# 331            garam masala
# 335            garam masala
# 344            garam masala
# 351            garam masala
# 354            garam masala
# 359            garam masala
# 372            garam masala
# 375            garam masala
# 381            garam masala
# 384            garam masala
# 390            garam masala
# 402            garam masala
# 409            garam masala
# 415            garam masala
# 426            garam masala
# 433            garam masala
# 439            garam masala
# 449            garam masala
# 453            garam masala
# 457            garam masala
# 462         tandoori masala
# 494            garam masala
# 498            garam masala
# 505            garam masala
# 515            garam masala
# 525            garam masala
# 529            garam masala
# 534          biryani masala
# 601            garam masala
# 704                  masala
# 727             kala masala
# 757          malvani masala
# 793            garam masala
# 814            garam masala
# 883        pav bhaji masala
# 988     panch phoran masala
# 1013           garam masala
# 1022         biryani masala
# 1042           garam masala
# Name: ingredients, dtype: object

# %%
change_word(['spices'], 'masala', 'masala')
# Out:
# 75                   masala
# 262            garam masala
# 268            garam masala
# 274            garam masala
# 283            garam masala
# 292            garam masala
# 304            garam masala
# 309            garam masala
# 320            garam masala
# 327            garam masala
# 331            garam masala
# 335            garam masala
# 344            garam masala
# 351            garam masala
# 354            garam masala
# 359            garam masala
# 372            garam masala
# 375            garam masala
# 381            garam masala
# 384            garam masala
# 390            garam masala
# 402            garam masala
# 409            garam masala
# 415            garam masala
# 426            garam masala
# 433            garam masala
# 439            garam masala
# 449            garam masala
# 453            garam masala
# 457            garam masala
# 462         tandoori masala
# 494            garam masala
# 498            garam masala
# 505            garam masala
# 515            garam masala
# 525            garam masala
# 529            garam masala
# 534          biryani masala
# 601            garam masala
# 704                  masala
# 727             kala masala
# 757          malvani masala
# 793            garam masala
# 814            garam masala
# 883        pav bhaji masala
# 988     panch phoran masala
# 1013           garam masala
# 1022         biryani masala
# 1042           garam masala
# Name: ingredients, dtype: object

# %%
change_word(['rock salt', 'black salt'], 'salt', 'salt')
# Out:
# 168     salt
# 256     salt
# 269     salt
# 279     salt
# 285     salt
# 562     salt
# 570     salt
# 574     salt
# 775     salt
# 951     salt
# 1009    salt
# Name: ingredients, dtype: object

# %%
change_word(['chana dal', 'bhuna chana', 'chana daal', 'kala chana'], 'chickpeas', 'chickpe')
# Out:
# 4       chickpea flour
# 53      chickpea flour
# 61      chickpea flour
# 87      chickpea flour
# 121     chickpea flour
# 152     chickpea flour
# 175     chickpea flour
# 186          chickpeas
# 192          chickpeas
# 307          chickpeas
# 340          chickpeas
# 368          chickpeas
# 383     chickpea flour
# 385     chickpea flour
# 410     chickpea flour
# 419     chickpea flour
# 429     chickpea flour
# 465          chickpeas
# 486     chickpea flour
# 508     chickpea flour
# 533     chickpea flour
# 549          chickpeas
# 553          chickpeas
# 558          chickpeas
# 581          chickpeas
# 605          chickpeas
# 611          chickpeas
# 620          chickpeas
# 634          chickpeas
# 667          chickpeas
# 707          chickpeas
# 722          chickpeas
# 732     chickpea flour
# 770          chickpeas
# 772     chickpea flour
# 785     chickpea flour
# 792          chickpeas
# 803     chickpea flour
# 812     chickpea flour
# 815     chickpea flour
# 824          chickpeas
# 844     chickpea flour
# 847     chickpea flour
# 853     chickpea flour
# 864     chickpea flour
# 871     chickpea flour
# 877     chickpea flour
# 881     chickpea flour
# 956     chickpea flour
# 969     chickpea flour
# 1052    chickpea flour
# 1074    chickpea flour
# 1082         chickpeas
# Name: ingredients, dtype: object

# %%
change_word(['bombay rava', 'whole wheat rava', 'rava', 'sooji'], 'semolina', 'sem')
# Out:
# 77     semolina
# 170    semolina
# 176    semolina
# 219    semolina
# 224    semolina
# 232    semolina
# 287    semolina
# 374    semolina
# 474    semolina
# 745    semolina
# 759    semolina
# 801    semolina
# 821    semolina
# 828    semolina
# 863    semolina
# 875    semolina
# 960    semolina
# 968    semolina
# Name: ingredients, dtype: object

# %%
change_word(['fish fillets', 'fish fillet', 'bombay duck'], 'fish', 'fish')
# Out:
# 240         fish
# 536         fish
# 738         fish
# 756         fish
# 1000        fish
# 1003        fish
# 1051        fish
# 1077    fish roe
# Name: ingredients, dtype: object

# %%
find_word('chil')
# Out:
# 243               chillies
# 248               chillies
# 258               chillies
# 272               chillies
# 278               chillies
# 295           chili powder
# 300         green chillies
# 346           green chilli
# 352           chili powder
# 366          green chilies
# 391           chili powder
# 397            green chili
# 412               chillies
# 417         green chillies
# 422                 chilli
# 430          green chilies
# 542           green chilli
# 573             red chilli
# 598              red chili
# 603          green chilies
# 604           chili powder
# 618            green chili
# 648           green chilli
# 715          green chilies
# 736             red chilli
# 760          green chilies
# 765             red chilli
# 800             red chilli
# 833          green chilies
# 835           chili powder
# 845      green chili paste
# 849            green chili
# 898            green chili
# 949           red chillies
# 1001        green chillies
# 1032    fresh green chilli
# 1050           green chili
# 1063           green chili
# 1090            dry chilli
# Name: ingredients, dtype: object

# %%
change_word(['chillies', 'chilies', 'chili powder', 'dry chilli', 'chili'], 'chilli', 'chil')
# Out:
# 243                 chilli
# 248                 chilli
# 258                 chilli
# 272                 chilli
# 278                 chilli
# 295                 chilli
# 300           green chilli
# 346           green chilli
# 352                 chilli
# 366           green chilli
# 391                 chilli
# 397           green chilli
# 412                 chilli
# 417           green chilli
# 422                 chilli
# 430           green chilli
# 542           green chilli
# 573             red chilli
# 598             red chilli
# 603           green chilli
# 604                 chilli
# 618           green chilli
# 648           green chilli
# 715           green chilli
# 736             red chilli
# 760           green chilli
# 765             red chilli
# 800             red chilli
# 833           green chilli
# 835                 chilli
# 845     green chilli paste
# 849           green chilli
# 898           green chilli
# 949             red chilli
# 1001          green chilli
# 1032    fresh green chilli
# 1050          green chilli
# 1063          green chilli
# 1090                chilli
# Name: ingredients, dtype: object

# %%
change_word(['green chilli paste', 'fresh green chilli'], 'green chilli', 'chilli')
# Out:
# 243           chilli
# 248           chilli
# 258           chilli
# 272           chilli
# 278           chilli
# 295           chilli
# 300     green chilli
# 346     green chilli
# 352           chilli
# 366     green chilli
# 391           chilli
# 397     green chilli
# 412           chilli
# 417     green chilli
# 422           chilli
# 430     green chilli
# 542     green chilli
# 573       red chilli
# 598       red chilli
# 603     green chilli
# 604           chilli
# 618     green chilli
# 648     green chilli
# 715     green chilli
# 736       red chilli
# 760     green chilli
# 765       red chilli
# 800       red chilli
# 833     green chilli
# 835           chilli
# 845     green chilli
# 849     green chilli
# 898     green chilli
# 949       red chilli
# 1001    green chilli
# 1032    green chilli
# 1050    green chilli
# 1063    green chilli
# 1090          chilli
# Name: ingredients, dtype: object

# %%
find_word('garlic')
# Out:
# 245                   garlic
# 249        ginger and garlic
# 275                   garlic
# 345                   garlic
# 444                   garlic
# 679                   garlic
# 734                   garlic
# 903                   garlic
# 942     green garlic chutney
# 1021           garlic powder
# 1102                  garlic
# 1137                  garlic
# Name: ingredients, dtype: object

# %%
change_word(['garlic powder'], 'garlic', 'garli')
# Out:
# 245                   garlic
# 249        ginger and garlic
# 275                   garlic
# 345                   garlic
# 444                   garlic
# 679                   garlic
# 734                   garlic
# 903                   garlic
# 942     green garlic chutney
# 1021                  garlic
# 1102                  garlic
# 1137                  garlic
# Name: ingredients, dtype: object

# %%
change_word(['ginger powder', 'ginger and garlic'], 'ginger', 'gin')
# Out:
# 244     ginger
# 249     ginger
# 273     ginger
# 310     ginger
# 355     ginger
# 386     ginger
# 395     ginger
# 411     ginger
# 416     ginger
# 427     ginger
# 434     ginger
# 495     ginger
# 506     ginger
# 516     ginger
# 526     ginger
# 540     ginger
# 645     ginger
# 699     ginger
# 713     ginger
# 719     ginger
# 724     ginger
# 741     ginger
# 891     ginger
# 905     ginger
# 939     ginger
# 944     ginger
# 1033    ginger
# 1055    ginger
# 1058    ginger
# 1084    ginger
# 1135    ginger
# Name: ingredients, dtype: object

# %%
change_word(['white urad dal', 'whole urad dal', 'split urad dal'], 'urad dal', 'dal')
# Out:
# 338     moong dal
# 339    masoor dal
# 343     moong dal
# 349      urad dal
# 370     arhar dal
# 371      urad dal
# 373     moong dal
# 393     moong dal
# 475      urad dal
# 539     arhar dal
# 547      urad dal
# 550      urad dal
# 554      urad dal
# 559      urad dal
# 560      urad dal
# 566      urad dal
# 567      urad dal
# 580     moong dal
# 583      urad dal
# 585      urad dal
# 595      urad dal
# 606      urad dal
# 610     moong dal
# 615     moong dal
# 621      urad dal
# 630      urad dal
# 635      urad dal
# 660     arhar dal
# 668      urad dal
# 672      urad dal
# 696      urad dal
# 708      urad dal
# 712      urad dal
# 723      urad dal
# 728     arhar dal
# 742      urad dal
# 771      urad dal
# 782           dal
# 791      urad dal
# 796     arhar dal
# 826      urad dal
# 827      toor dal
# 851      urad dal
# 889      urad dal
# Name: ingredients, dtype: object

# %%
change_word(['boiled pork'], 'pork', 'pork')
# Out:
# 246    pork
# 259    pork
# Name: ingredients, dtype: object

# %%
change_word(['red onion', 'pearl onions'], 'onions', 'oni')
# Out:
# 247     onions
# 311     onions
# 356     onions
# 629     onions
# 1008    onions
# 1034    onions
# 1106    onions
# Name: ingredients, dtype: object

# %%
change_word(['green peas', 'frozen green peas', 'fresh peas'], 'peas', 'peas')
# Out:
# 186             chickpeas
# 192             chickpeas
# 271                  peas
# 307             chickpeas
# 340             chickpeas
# 353           pigeon peas
# 368             chickpeas
# 394                  peas
# 437                  peas
# 465             chickpeas
# 504                  peas
# 548     split pigeon peas
# 549             chickpeas
# 551                  peas
# 553             chickpeas
# 558             chickpeas
# 581             chickpeas
# 605             chickpeas
# 609                  peas
# 611             chickpeas
# 620             chickpeas
# 634             chickpeas
# 667             chickpeas
# 685           pigeon peas
# 707             chickpeas
# 722             chickpeas
# 770             chickpeas
# 792             chickpeas
# 824             chickpeas
# 886                  peas
# 930                  peas
# 943            fresh peas
# 974                  peas
# 1082            chickpeas
# Name: ingredients, dtype: object

# %%
change_word(['split pigeon peas'], 'pigeon peas', 'peas')
# Out:
# 186       chickpeas
# 192       chickpeas
# 271            peas
# 307       chickpeas
# 340       chickpeas
# 353     pigeon peas
# 368       chickpeas
# 394            peas
# 437            peas
# 465       chickpeas
# 504            peas
# 548     pigeon peas
# 549       chickpeas
# 551            peas
# 553       chickpeas
# 558       chickpeas
# 581       chickpeas
# 605       chickpeas
# 609            peas
# 611       chickpeas
# 620       chickpeas
# 634       chickpeas
# 667       chickpeas
# 685     pigeon peas
# 707       chickpeas
# 722       chickpeas
# 770       chickpeas
# 792       chickpeas
# 824       chickpeas
# 886            peas
# 930            peas
# 943      fresh peas
# 974            peas
# 1082      chickpeas
# Name: ingredients, dtype: object

# %%
change_word(['kasuri methi'], 'fenugreek leaves', 'kasu')
# Out:
# Series([], Name: ingredients, dtype: object)

# %%
change_word(['chicken thighs', 'skinless chicken breasts', 'chicken chunks'], 'chicken', 'chicken')
# Out:
# 296     chicken
# 301     chicken
# 317     chicken
# 325     chicken
# 328     chicken
# 718     chicken
# 936     chicken
# 1018    chicken
# 1062    chicken
# Name: ingredients, dtype: object

# %%
change_word(['dahi'], 'curd', 'dahi')
# Out:
# Series([], Name: ingredients, dtype: object)

# %%
change_word(['whole egg', 'egg yolks'], 'eggs', 'egg')
# Out:
# 332         eggs
# 686     eggplant
# 993         eggs
# 1119        eggs
# Name: ingredients, dtype: object

# %%
change_word(['chole'], 'chole masala', 'chole')
# Out:
# 286    chole masala
# 333    chole masala
# Name: ingredients, dtype: object

# %%
change_word(['cinnamon stick'], 'cinnamon', 'cinn')
# Out:
# 337     cinnamon
# 492     cinnamon
# 501     cinnamon
# 721     cinnamon
# 855     cinnamon
# 941     cinnamon
# 1070    cinnamon
# 1085    cinnamon
# Name: ingredients, dtype: object

# %%
change_word(['tamarind paste'], 'tamarind', 'tam')
# Out:
# 577    tamarind
# 613    tamarind
# 674    tamarind
# 689    tamarind
# 706    tamarind
# 795    tamarind
# Name: ingredients, dtype: object

# %%
change_word(['baingan', 'brinjal'], 'eggplant', 'eggplant')
# Out:
# 686     eggplant
# 737     eggplant
# 1007    eggplant
# 1114    eggplant
# Name: ingredients, dtype: object

# %%
change_word(['bitter gourd', 'bottle gourd', 'ridge gourd'], 'bitter gourd', 'gourd')
# Out:
# 388     bitter gourd
# 408     bitter gourd
# 413     bitter gourd
# 806     bitter gourd
# 823     bitter gourd
# 873     bitter gourd
# 970     bitter gourd
# 1002    bitter gourd
# 1111    bitter gourd
# 1112    bitter gourd
# Name: ingredients, dtype: object

# %%
change_word(['cilantro'], 'coriander', 'cor')
# Out:
# 34      corn flour
# 84      corn flour
# 401     corn flour
# 424     corn flour
# 482      coriander
# 509     corn flour
# 523      baby corn
# 862      coriander
# 1011     coriander
# Name: ingredients, dtype: object

# %%
change_word(['drumsticks'], 'drumstick', 'drumstick')
# Out:
# 576    drumstick
# 631    drumstick
# 687    drumstick
# Name: ingredients, dtype: object

# %%
change_word(['dried fruits'], 'dry fruits', 'fruits')
# Out:
# 52      dry fruits
# 86      dry fruits
# 223     dry fruits
# 820     dry fruits
# 1128    dry fruits
# Name: ingredients, dtype: object

# %%
change_word(['gobi'], 'cauliflower', 'cau')
# Out:
# 260    cauliflower
# 884    cauliflower
# 931    cauliflower
# Name: ingredients, dtype: object

# %%
change_word(['greens'], 'green', 'green')
# Out:
# 300             green chilli
# 346             green chilli
# 366             green chilli
# 397             green chilli
# 417             green chilli
# 425            mustard green
# 430             green chilli
# 445              green beans
# 542             green chilli
# 590                    green
# 603             green chilli
# 618             green chilli
# 648             green chilli
# 715             green chilli
# 760             green chilli
# 807                    green
# 833             green chilli
# 845             green chilli
# 849             green chilli
# 898             green chilli
# 940                    green
# 942     green garlic chutney
# 1001            green chilli
# 1032            green chilli
# 1050            green chilli
# 1059                   green
# 1063            green chilli
# 1110             green beans
# Name: ingredients, dtype: object

# %%
change_word(['gur'], 'jaggery', 'jaggery')
# Out:
# 125     jaggery
# 145     jaggery
# 150     jaggery
# 153     jaggery
# 157     jaggery
# 160     jaggery
# 178     jaggery
# 187     jaggery
# 193     jaggery
# 195     jaggery
# 207     jaggery
# 210     jaggery
# 213     jaggery
# 228     jaggery
# 485     jaggery
# 627     jaggery
# 653     jaggery
# 784     jaggery
# 817     jaggery
# 856     jaggery
# 880     jaggery
# 914     jaggery
# 919     jaggery
# 948     jaggery
# 979     jaggery
# 985     jaggery
# 1039    jaggery
# 1117    jaggery
# Name: ingredients, dtype: object

# %%
change_word(['imli'], 'tamarind', 'tamarind')
# Out:
# 487    tamarind
# 577    tamarind
# 613    tamarind
# 674    tamarind
# 689    tamarind
# 706    tamarind
# 795    tamarind
# 882    tamarind
# Name: ingredients, dtype: object

# %%
change_word(['kewra'], 'kewra oil', 'kewra')
# Out:
# 15    kewra oil
# Name: ingredients, dtype: object

# %%
change_word(['maida flour'], 'maida', 'maida')
# Out:
# 0      maida
# 33     maida
# 183    maida
# 231    maida
# 237    maida
# 996    maida
# Name: ingredients, dtype: object

# %%
change_word(['maida'], 'maida flour', 'maida')
# Out:
# 0      maida flour
# 33     maida flour
# 183    maida flour
# 231    maida flour
# 237    maida flour
# 996    maida flour
# Name: ingredients, dtype: object

# %%
change_word(['dried mango'], 'mango', 'mango')
# Out:
# 773    mango
# 840    mango
# 981    mango
# Name: ingredients, dtype: object

# %%
change_word(['palak'], 'spinach', 'spinach')
# Out:
# 423    spinach
# 451    spinach
# 582    spinach
# 589    spinach
# Name: ingredients, dtype: object

# %%
change_word(['paneer'], 'cottage cheese', 'cheese')
# Out:
# 47      cottage cheese
# 378     cottage cheese
# 398     cottage cheese
# 450     cottage cheese
# 455     cottage cheese
# 460     cottage cheese
# 513     cottage cheese
# 1122    cottage cheese
# Name: ingredients, dtype: object

# %%
find_word('pean')
# Out:
# 159       peanuts
# 788        peanut
# 893        peanut
# 955    peanut oil
# Name: ingredients, dtype: object

# %%
change_word(['peanuts'], 'peanut', 'peanu')
# Out:
# 159        peanut
# 788        peanut
# 893        peanut
# 955    peanut oil
# Name: ingredients, dtype: object

# %%
change_word(['sambar powder'], 'sambar masala', 'samb')
# Out:
# 578    sambar masala
# 661    sambar masala
# 688    sambar masala
# Name: ingredients, dtype: object

# %%
change_word(['thick poha'], 'rice flakes', 'flak')
# Out:
# 363    rice flakes
# 569    rice flakes
# 638    rice flakes
# 690    rice flakes
# 709    rice flakes
# 916    rice flakes
# Name: ingredients, dtype: object

# %%
change_word(['mushroom', 'wild mushrooms'], 'mushrooms', 'mushro')
# Out:
# 431    mushrooms
# 438    mushrooms
# Name: ingredients, dtype: object

# %%
find_word('mawa')
# Out:
# 750    mawa
# Name: ingredients, dtype: object

# %%
find_word('flour')
# Out:
# 0              maida flour
# 4           chickpea flour
# 13                   flour
# 24                   flour
# 32            lentil flour
# 33             maida flour
# 34              corn flour
# 53          chickpea flour
# 60           refined flour
# 61          chickpea flour
# 84              corn flour
# 87          chickpea flour
# 100                  flour
# 114                  flour
# 118          refined flour
# 121         chickpea flour
# 129                  flour
# 130             rice flour
# 131            wheat flour
# 144             rice flour
# 149             rice flour
# 152         chickpea flour
# 166             rice flour
# 171            wheat flour
# 175         chickpea flour
# 183            maida flour
# 190             rice flour
# 198             rice flour
# 205             rice flour
# 209             rice flour
# 212             rice flour
# 226             rice flour
# 231            maida flour
# 237            maida flour
# 265             rice flour
# 289                  flour
# 313            wheat flour
# 316                  flour
# 330             rice flour
# 341            wheat flour
# 347                  flour
# 369            wheat flour
# 383         chickpea flour
# 385         chickpea flour
# 401             corn flour
# 410         chickpea flour
# 418            wheat flour
# 419         chickpea flour
# 424             corn flour
# 428            wheat flour
# 429         chickpea flour
# 441            wheat flour
# 470            wheat flour
# 479            wheat flour
# 486         chickpea flour
# 508         chickpea flour
# 509             corn flour
# 533         chickpea flour
# 538            wheat flour
# 563             rice flour
# 666             rice flour
# 682             rice flour
# 732         chickpea flour
# 744            wheat flour
# 746            wheat flour
# 747     pearl millet flour
# 754            jowar flour
# 758             rice flour
# 761             rice flour
# 763                  flour
# 772         chickpea flour
# 781            wheat flour
# 785         chickpea flour
# 803         chickpea flour
# 812         chickpea flour
# 815         chickpea flour
# 816            wheat flour
# 822                  flour
# 837            wheat flour
# 842            wheat flour
# 844         chickpea flour
# 847         chickpea flour
# 850             rice flour
# 852            wheat flour
# 853         chickpea flour
# 864         chickpea flour
# 871         chickpea flour
# 874            wheat flour
# 877         chickpea flour
# 881         chickpea flour
# 908            wheat flour
# 910                  flour
# 913            wheat flour
# 921            wheat flour
# 922             rice flour
# 923     pearl millet flour
# 924            jowar flour
# 946                  flour
# 952             rice flour
# 956         chickpea flour
# 958            jowar flour
# 959            wheat flour
# 963                  flour
# 969         chickpea flour
# 975            wheat flour
# 984             rice flour
# 996            maida flour
# 1038                 flour
# 1052        chickpea flour
# 1071            rice flour
# 1074        chickpea flour
# 1121                 flour
# 1130                 flour
# Name: ingredients, dtype: object

# %%
ingredients = new.pivot_table(index = ['ingredients'], aggfunc ='size')
ingredients = ingredients.to_frame()
ingredients.reset_index(inplace=True)
ingredients = ingredients.rename(columns = {0:'n_ingredients', 'ingr':'ingredient'})
ingredients

# %%
new.sort_values('ingredients')
# Out:
#                  ingredients
# 522                   almond
# 870                   almond
# 752                   almond
# 19                    almond
# 819                   almond
# 1126                  almond
# 1020                  almond
# 342                   almond
# 69               alum powder
# 594          amaranth leaves
# 284            amchur powder
# 392            amchur powder
# 201                 apricots
# 483            arbi ke patte
# 878            arbi ke patte
# 370                arhar dal
# 796                arhar dal
# 728                arhar dal
# 660                arhar dal
# 539                arhar dal
# 1129        arrowroot powder
# 896              avocado oil
# 312              avocado oil
# 255                    axone
# 523                baby corn
# 1076           baking powder
# 25             baking powder
# 774              baking soda
# 909              baking soda
# 1035             baking soda
# 290              baking soda
# 35               baking soda
# 971              baking soda
# 647              baking soda
# 954              baking soda
# 543                   banana
# 1113                  banana
# 1073                  banana
# 206                   banana
# 1061           banana flower
# 336               bay leaves
# 1016              bay leaves
# 1045              bay leaves
# 1069              bay leaves
# 703                    beans
# 493                    beans
# 608                    beans
# 669                    beans
# 348                    beans
# 933                    beans
# 599                     beef
# 995                 beetroot
# 379              bell pepper
# 435              bell pepper
# 537              bell pepper
# 282              bell pepper
# 464              bell pepper
# 334                  bhatura
# 1022          biryani masala
# 534           biryani masala
# 873             bitter gourd
# 1111            bitter gourd
# 1112            bitter gourd
# 823             bitter gourd
# 1002            bitter gourd
# 388             bitter gourd
# 970             bitter gourd
# 806             bitter gourd
# 413             bitter gourd
# 408             bitter gourd
# 964             black pepper
# 1134            black pepper
# 911             black pepper
# 650             black pepper
# 716             black pepper
# 467                   boondi
# 164                    bread
# 520                    bread
# 267                    bread
# 459                   butter
# 1107                  butter
# 306                   butter
# 711                   butter
# 480                   butter
# 443                   butter
# 454                   butter
# 825                  cabbage
# 612                  cabbage
# 148                 cardamom
# 139                 cardamom
# 154                 cardamom
# 253                 cardamom
# 236                 cardamom
# 189                 cardamom
# 143                 cardamom
# 110                 cardamom
# 91                  cardamom
# 65                  cardamom
# 22                  cardamom
# 1099                cardamom
# 41                  cardamom
# 44                  cardamom
# 527                   carrot
# 7                     carrot
# 571                   carrot
# 860                   carrot
# 994                   carrot
# 838              cashew nuts
# 753              cashew nuts
# 382              cashew nuts
# 321              cashew nuts
# 656              cashew nuts
# 1136             cashew nuts
# 11               cashew nuts
# 196              cashew nuts
# 42               cashew nuts
# 458              cashew nuts
# 305              cashew nuts
# 360              cashew nuts
# 260              cauliflower
# 884              cauliflower
# 931              cauliflower
# 829               chia seeds
# 1062                 chicken
# 718                  chicken
# 1018                 chicken
# 296                  chicken
# 936                  chicken
# 301                  chicken
# 328                  chicken
# 325                  chicken
# 317                  chicken
# 803           chickpea flour
# 785           chickpea flour
# 152           chickpea flour
# 969           chickpea flour
# 4             chickpea flour
# 881           chickpea flour
# 533           chickpea flour
# 385           chickpea flour
# 175           chickpea flour
# 815           chickpea flour
# 87            chickpea flour
# 812           chickpea flour
# 956           chickpea flour
# 1052          chickpea flour
# 410           chickpea flour
# 877           chickpea flour
# 871           chickpea flour
# 121           chickpea flour
# 772           chickpea flour
# 844           chickpea flour
# 1074          chickpea flour
# 847           chickpea flour
# 853           chickpea flour
# 61            chickpea flour
# 53            chickpea flour
# 486           chickpea flour
# 419           chickpea flour
# 383           chickpea flour
# 864           chickpea flour
# 508           chickpea flour
# 429           chickpea flour
# 732           chickpea flour
# 605                chickpeas
# 192                chickpeas
# 770                chickpeas
# 722                chickpeas
# 620                chickpeas
# 634                chickpeas
# 465                chickpeas
# 581                chickpeas
# 824                chickpeas
# 186                chickpeas
# 707                chickpeas
# 792                chickpeas
# 340                chickpeas
# 667                chickpeas
# 558                chickpeas
# 553                chickpeas
# 549                chickpeas
# 307                chickpeas
# 368                chickpeas
# 611                chickpeas
# 1082               chickpeas
# 1090                  chilli
# 412                   chilli
# 243                   chilli
# 352                   chilli
# 295                   chilli
# 248                   chilli
# 835                   chilli
# 391                   chilli
# 604                   chilli
# 278                   chilli
# 258                   chilli
# 422                   chilli
# 272                   chilli
# 286             chole masala
# 333             chole masala
# 337                 cinnamon
# 941                 cinnamon
# 501                 cinnamon
# 1085                cinnamon
# 721                 cinnamon
# 1070                cinnamon
# 855                 cinnamon
# 492                 cinnamon
# 766              citric acid
# 1093                 coconut
# 751                  coconut
# 670                  coconut
# 227                  coconut
# 565                  coconut
# 82                   coconut
# 555                  coconut
# 684                  coconut
# 702                  coconut
# 920                  coconut
# 935                  coconut
# 780                  coconut
# 179                  coconut
# 600                  coconut
# 978                  coconut
# 973                  coconut
# 1133                 coconut
# 597                  coconut
# 628                  coconut
# 740                  coconut
# 105                  coconut
# 1046                 coconut
# 208                  coconut
# 1083                 coconut
# 211                  coconut
# 966                  coconut
# 185                  coconut
# 802                  coconut
# 778              coconut ice
# 1030            coconut milk
# 436             coconut milk
# 1100            coconut milk
# 1118            coconut milk
# 414              coconut oil
# 937              coconut oil
# 739              coconut oil
# 797              coconut oil
# 639              coconut oil
# 584              coconut oil
# 107           condensed milk
# 749           condensed milk
# 73            condensed milk
# 133           condensed milk
# 776           condensed milk
# 482                coriander
# 862                coriander
# 1011               coriander
# 509               corn flour
# 401               corn flour
# 34                corn flour
# 84                corn flour
# 424               corn flour
# 513           cottage cheese
# 398           cottage cheese
# 460           cottage cheese
# 47            cottage cheese
# 378           cottage cheese
# 450           cottage cheese
# 1122          cottage cheese
# 455           cottage cheese
# 463                    cream
# 326                    cream
# 452                    cream
# 303                    cream
# 101                    cream
# 777                    cream
# 350                    cream
# 400                    cream
# 456                    cream
# 859                 cucumber
# 616                 cucumber
# 218                 cucumber
# 640                 cucumber
# 134                     curd
# 132                     curd
# 1043                    curd
# 233                     curd
# 37                      curd
# 126                     curd
# 982                     curd
# 111                     curd
# 1048                    curd
# 99                      curd
# 641                     curd
# 697                     curd
# 92                      curd
# 318                     curd
# 95                      curd
# 106                     curd
# 137                     curd
# 1087                    curd
# 663             curry leaves
# 633             curry leaves
# 714             curry leaves
# 798             curry leaves
# 586             curry leaves
# 642             curry leaves
# 725             curry leaves
# 646             curry leaves
# 624             curry leaves
# 264             curry leaves
# 700             curry leaves
# 692             curry leaves
# 614             curry leaves
# 602             curry leaves
# 848             curry leaves
# 365             curry leaves
# 617             curry leaves
# 1089            curry leaves
# 892             curry leaves
# 678             curry leaves
# 387             curry leaves
# 897             curry leaves
# 676             curry leaves
# 729             curry leaves
# 557             curry leaves
# 782                      dal
# 794                    dates
# 887             dinner rolls
# 376                    dough
# 510                    dough
# 507                    dough
# 1124       dried rose petals
# 576                drumstick
# 687                drumstick
# 631                drumstick
# 1123               dry dates
# 52                dry fruits
# 1128              dry fruits
# 223               dry fruits
# 86                dry fruits
# 820               dry fruits
# 858              dry roasted
# 831               edible gum
# 473               edible gum
# 686                 eggplant
# 1114                eggplant
# 1007                eggplant
# 737                 eggplant
# 993                     eggs
# 1119                    eggs
# 332                     eggs
# 544        elephant foot yam
# 389                   fennel
# 488                   fennel
# 1132            fennel seeds
# 377             fennel seeds
# 991             fennel seeds
# 664             fennel seeds
# 120             fennel seeds
# 357         fenugreek leaves
# 867         fenugreek leaves
# 361         fenugreek leaves
# 293         fenugreek leaves
# 530         fenugreek leaves
# 491         fenugreek leaves
# 277         fenugreek leaves
# 500         fenugreek leaves
# 593          fenugreek seeds
# 1056  fermented bamboo shoot
# 511                  filling
# 66        firm white pumpkin
# 738                     fish
# 756                     fish
# 536                     fish
# 1000                    fish
# 240                     fish
# 1051                    fish
# 1003                    fish
# 1077                fish roe
# 963                    flour
# 100                    flour
# 1130                   flour
# 946                    flour
# 13                     flour
# 910                    flour
# 1121                   flour
# 24                     flour
# 289                    flour
# 763                    flour
# 316                    flour
# 1038                   flour
# 114                    flour
# 129                    flour
# 822                    flour
# 347                    flour
# 404            fpotatoda sev
# 524             french beans
# 552             french beans
# 943               fresh peas
# 767                      fry
# 1013            garam masala
# 274             garam masala
# 529             garam masala
# 268             garam masala
# 262             garam masala
# 426             garam masala
# 457             garam masala
# 1042            garam masala
# 283             garam masala
# 384             garam masala
# 433             garam masala
# 453             garam masala
# 372             garam masala
# 381             garam masala
# 449             garam masala
# 439             garam masala
# 601             garam masala
# 359             garam masala
# 814             garam masala
# 525             garam masala
# 415             garam masala
# 494             garam masala
# 344             garam masala
# 335             garam masala
# 390             garam masala
# 331             garam masala
# 498             garam masala
# 327             garam masala
# 320             garam masala
# 402             garam masala
# 354             garam masala
# 505             garam masala
# 351             garam masala
# 309             garam masala
# 409             garam masala
# 515             garam masala
# 375             garam masala
# 304             garam masala
# 292             garam masala
# 793             garam masala
# 734                   garlic
# 679                   garlic
# 1102                  garlic
# 444                   garlic
# 1137                  garlic
# 275                   garlic
# 345                   garlic
# 903                   garlic
# 245                   garlic
# 1021                  garlic
# 43                      ghee
# 810                     ghee
# 14                      ghee
# 17                      ghee
# 230                     ghee
# 818                     ghee
# 239                     ghee
# 857                     ghee
# 54                      ghee
# 146                     ghee
# 113                     ghee
# 169                     ghee
# 119                     ghee
# 26                      ghee
# 123                     ghee
# 1098                    ghee
# 1120                    ghee
# 155                     ghee
# 128                     ghee
# 151                     ghee
# 1036                    ghee
# 94                      ghee
# 915                     ghee
# 200                     ghee
# 182                     ghee
# 188                     ghee
# 961                     ghee
# 78                      ghee
# 197                     ghee
# 5                       ghee
# 62                      ghee
# 88                      ghee
# 85                      ghee
# 10                      ghee
# 719                   ginger
# 1033                  ginger
# 506                   ginger
# 249                   ginger
# 434                   ginger
# 395                   ginger
# 1058                  ginger
# 741                   ginger
# 516                   ginger
# 713                   ginger
# 540                   ginger
# 699                   ginger
# 1135                  ginger
# 526                   ginger
# 891                   ginger
# 310                   ginger
# 427                   ginger
# 939                   ginger
# 1084                  ginger
# 1055                  ginger
# 645                   ginger
# 273                   ginger
# 355                   ginger
# 411                   ginger
# 905                   ginger
# 416                   ginger
# 495                   ginger
# 724                   ginger
# 386                   ginger
# 244                   ginger
# 944                   ginger
# 622               gooseberry
# 380                    gravy
# 1059                   green
# 807                    green
# 590                    green
# 940                    green
# 445              green beans
# 1110             green beans
# 618             green chilli
# 603             green chilli
# 1001            green chilli
# 898             green chilli
# 648             green chilli
# 542             green chilli
# 397             green chilli
# 417             green chilli
# 833             green chilli
# 1032            green chilli
# 760             green chilli
# 430             green chilli
# 845             green chilli
# 1063            green chilli
# 715             green chilli
# 1050            green chilli
# 300             green chilli
# 366             green chilli
# 346             green chilli
# 849             green chilli
# 942     green garlic chutney
# 442                    honey
# 914                  jaggery
# 817                  jaggery
# 485                  jaggery
# 627                  jaggery
# 919                  jaggery
# 979                  jaggery
# 213                  jaggery
# 948                  jaggery
# 207                  jaggery
# 784                  jaggery
# 210                  jaggery
# 985                  jaggery
# 228                  jaggery
# 653                  jaggery
# 145                  jaggery
# 153                  jaggery
# 150                  jaggery
# 187                  jaggery
# 157                  jaggery
# 1117                 jaggery
# 178                  jaggery
# 125                  jaggery
# 193                  jaggery
# 195                  jaggery
# 1039                 jaggery
# 856                  jaggery
# 160                  jaggery
# 880                  jaggery
# 958              jowar flour
# 924              jowar flour
# 754              jowar flour
# 541               kala jeera
# 727              kala masala
# 15                 kewra oil
# 899                   khaman
# 81                      khoa
# 214                khus khus
# 934                khus khus
# 447                khus khus
# 976                khus khus
# 68              kitchen lime
# 783                    kokum
# 291            ladies finger
# 1041                    lamb
# 619                    lemon
# 1065                   lemon
# 865                    lemon
# 469                    lemon
# 1004                   lemon
# 895                    lemon
# 945                    lemon
# 830                    lemon
# 673                    lemon
# 834                    lemon
# 104                    lemon
# 367                    lemon
# 477                    lemon
# 1053                   lemon
# 32              lentil flour
# 173                  lentils
# 649                  lentils
# 1031                 lobster
# 545               long beans
# 843                  low fat
# 448                  low fat
# 996              maida flour
# 0                maida flour
# 33               maida flour
# 231              maida flour
# 237              maida flour
# 183              maida flour
# 514                    malai
# 432                    malai
# 757           malvani masala
# 981                    mango
# 773                    mango
# 840                    mango
# 531                 marinade
# 704                   masala
# 75                    masala
# 339               masoor dal
# 750                     mawa
# 717        meat curry powder
# 957             methi leaves
# 657                     milk
# 163                     milk
# 654                     milk
# 80                      milk
# 90                      milk
# 124                     milk
# 115                     milk
# 220                     milk
# 251                     milk
# 216                     milk
# 135                     milk
# 140                     milk
# 519                     milk
# 161                     milk
# 97                      milk
# 57                      milk
# 165                     milk
# 191                     milk
# 180                     milk
# 204                     milk
# 27                      milk
# 832                     milk
# 8                       milk
# 1127                    milk
# 46                      milk
# 49                      milk
# 16                      milk
# 23                      milk
# 1054                    mint
# 1023        mixed vegetables
# 83               molu leaves
# 665              moong beans
# 947              moong beans
# 177              moong beans
# 338                moong dal
# 393                moong dal
# 615                moong dal
# 343                moong dal
# 610                moong dal
# 373                moong dal
# 580                moong dal
# 438                mushrooms
# 431                mushrooms
# 471         musk melon seeds
# 890                  mustard
# 804                  mustard
# 733                  mustard
# 671                  mustard
# 425            mustard green
# 999              mustard oil
# 1079             mustard oil
# 990              mustard oil
# 532              mustard oil
# 1006             mustard oil
# 1015             mustard oil
# 512              mustard oil
# 1068             mustard oil
# 1064             mustard oil
# 497              mustard oil
# 1060             mustard oil
# 502              mustard oil
# 680            mustard seeds
# 643            mustard seeds
# 1049           mustard seeds
# 701            mustard seeds
# 596            mustard seeds
# 730            mustard seeds
# 799            mustard seeds
# 588            mustard seeds
# 1026           mustard seeds
# 592            mustard seeds
# 1072                  mutton
# 323               naan bread
# 989            nigella seeds
# 421            nigella seeds
# 76                      nuts
# 79                      nuts
# 72                      nuts
# 58                      nuts
# 405                     nuts
# 217                     nuts
# 962                      oil
# 950                      oil
# 1037                     oil
# 2                        oil
# 280                      oil
# 1019               olive oil
# 1029               olive oil
# 314                olive oil
# 1109               olive oil
# 1075               olive oil
# 1008                  onions
# 356                   onions
# 1034                  onions
# 1106                  onions
# 629                   onions
# 311                   onions
# 247                   onions
# 986              orange rind
# 988      panch phoran masala
# 786                      pav
# 883         pav bhaji masala
# 159                   peanut
# 788                   peanut
# 893                   peanut
# 955               peanut oil
# 747       pearl millet flour
# 923       pearl millet flour
# 394                     peas
# 886                     peas
# 437                     peas
# 930                     peas
# 271                     peas
# 609                     peas
# 551                     peas
# 974                     peas
# 504                     peas
# 685              pigeon peas
# 353              pigeon peas
# 548              pigeon peas
# 136                pistachio
# 1125               pistachio
# 20                 pistachio
# 869                pistachio
# 789              pomegranate
# 900              pomegranate
# 472              poppy seeds
# 246                     pork
# 259                     pork
# 885                   potato
# 1057                  potato
# 787                   potato
# 1066                  potato
# 743                   potato
# 266                   potato
# 270                   potato
# 636                   potato
# 276                   potato
# 281                   potato
# 364                   potato
# 836                   potato
# 358                   potato
# 607                   potato
# 261                   potato
# 399                   potato
# 888                   potato
# 503                   potato
# 932                   potato
# 928                   potato
# 998                   potato
# 481                   potato
# 446                   potato
# 1012                  potato
# 466                   potato
# 241                    potol
# 1047                  prawns
# 1101                  prawns
# 1078         pumpkin flowers
# 808                  raisins
# 1040                 raisins
# 1086                 raisins
# 12                   raisins
# 768                  raisins
# 658                  raisins
# 156                  raisins
# 839            rapeseeds oil
# 987               raw papaya
# 573               red chilli
# 598               red chilli
# 736               red chilli
# 765               red chilli
# 800               red chilli
# 949               red chilli
# 779        red food coloring
# 1105              red pepper
# 118            refined flour
# 60             refined flour
# 1095                    rice
# 250                     rice
# 1131                    rice
# 254                     rice
# 194                     rice
# 1017                    rice
# 70                      rice
# 918                     rice
# 174                     rice
# 980                     rice
# 983                     rice
# 1115                    rice
# 297                     rice
# 992                     rice
# 1088                    rice
# 1027                    rice
# 1094                    rice
# 221                     rice
# 50                      rice
# 568                     rice
# 694                     rice
# 655                     rice
# 637                     rice
# 652                     rice
# 623                     rice
# 626                     rice
# 675                     rice
# 561                     rice
# 569              rice flakes
# 690              rice flakes
# 709              rice flakes
# 363              rice flakes
# 916              rice flakes
# 638              rice flakes
# 952               rice flour
# 198               rice flour
# 190               rice flour
# 205               rice flour
# 209               rice flour
# 212               rice flour
# 758               rice flour
# 922               rice flour
# 226               rice flour
# 761               rice flour
# 265               rice flour
# 666               rice flour
# 166               rice flour
# 984               rice flour
# 130               rice flour
# 563               rice flour
# 330               rice flour
# 850               rice flour
# 682               rice flour
# 149               rice flour
# 1071              rice flour
# 144               rice flour
# 403               rose syrup
# 518               rose water
# 868               rose water
# 30                rose water
# 1096              rose water
# 894                 sabudana
# 142                  saffron
# 406                  saffron
# 235                  saffron
# 40                   saffron
# 21                   saffron
# 103                  saffron
# 872                  saffron
# 322                  saffron
# 521                  saffron
# 109                  saffron
# 1009                    salt
# 168                     salt
# 256                     salt
# 570                     salt
# 775                     salt
# 951                     salt
# 574                     salt
# 562                     salt
# 279                     salt
# 269                     salt
# 285                     salt
# 661            sambar masala
# 688            sambar masala
# 578            sambar masala
# 813                    sauce
# 863                 semolina
# 821                 semolina
# 759                 semolina
# 224                 semolina
# 219                 semolina
# 801                 semolina
# 374                 semolina
# 745                 semolina
# 77                  semolina
# 875                 semolina
# 232                 semolina
# 960                 semolina
# 287                 semolina
# 968                 semolina
# 828                 semolina
# 176                 semolina
# 170                 semolina
# 474                 semolina
# 805                   sesame
# 762                   sesame
# 625               sesame oil
# 705               sesame oil
# 575               sesame oil
# 698               sesame oil
# 967             sesame seeds
# 953             sesame seeds
# 691             sesame seeds
# 556             sesame seeds
# 755             sesame seeds
# 879             sesame seeds
# 876             sesame seeds
# 319             sesame seeds
# 484             sesame seeds
# 977             sesame seeds
# 925             sesame seeds
# 1116            sesame seeds
# 1010            sesame seeds
# 846             sesame seeds
# 1092            sesame seeds
# 476                      sev
# 901                      sev
# 468                      sev
# 904                      sev
# 693                    sevai
# 1028               soy sauce
# 451                  spinach
# 582                  spinach
# 589                  spinach
# 423                  spinach
# 298               star anise
# 790               star anise
# 695                  steamer
# 6                      sugar
# 972                    sugar
# 172                    sugar
# 51                     sugar
# 407                    sugar
# 89                     sugar
# 108                    sugar
# 31                     sugar
# 726                    sugar
# 252                    sugar
# 587                    sugar
# 67                     sugar
# 138                    sugar
# 59                     sugar
# 18                     sugar
# 141                    sugar
# 162                    sugar
# 299                    sugar
# 841                    sugar
# 9                      sugar
# 158                    sugar
# 55                     sugar
# 167                    sugar
# 93                     sugar
# 181                    sugar
# 229                    sugar
# 102                    sugar
# 234                    sugar
# 225                    sugar
# 112                    sugar
# 1104                   sugar
# 74                     sugar
# 222                    sugar
# 116                    sugar
# 45                     sugar
# 659                    sugar
# 907                    sugar
# 769                    sugar
# 98                     sugar
# 3                      sugar
# 215                    sugar
# 48                     sugar
# 71                     sugar
# 96                     sugar
# 127                    sugar
# 683                    sugar
# 902                    sugar
# 238                    sugar
# 122                    sugar
# 809                    sugar
# 1097                   sugar
# 199                    sugar
# 202                    sugar
# 63                     sugar
# 28                     sugar
# 926             sugar potato
# 912            sunflower oil
# 927              surti papdi
# 613                 tamarind
# 689                 tamarind
# 674                 tamarind
# 487                 tamarind
# 795                 tamarind
# 706                 tamarind
# 577                 tamarind
# 882                 tamarind
# 462          tandoori masala
# 489                 tea bags
# 1091              tea leaves
# 546                  tindora
# 662                   tomato
# 478                   tomato
# 579                   tomato
# 1005                  tomato
# 1067                  tomato
# 677                   tomato
# 324                   tomato
# 632                   tomato
# 906                   tomato
# 242                   tomato
# 440                   tomato
# 420                   tomato
# 396                   tomato
# 861                   tomato
# 490                   tomato
# 362                   tomato
# 294                   tomato
# 591                   tomato
# 308                   tomato
# 1081                  tomato
# 710                   tomato
# 496                   tomato
# 499                   tomato
# 720                   tomato
# 1014                  tomato
# 517                   tomato
# 827                 toor dal
# 1080                turmeric
# 39                  turmeric
# 764                 turmeric
# 263                 turmeric
# 735                 turmeric
# 1044                turmeric
# 1103                turmeric
# 854                 turmeric
# 866                 turmeric
# 184                 turmeric
# 583                 urad dal
# 595                 urad dal
# 635                 urad dal
# 585                 urad dal
# 566                 urad dal
# 630                 urad dal
# 567                 urad dal
# 606                 urad dal
# 621                 urad dal
# 826                 urad dal
# 560                 urad dal
# 889                 urad dal
# 771                 urad dal
# 791                 urad dal
# 371                 urad dal
# 723                 urad dal
# 712                 urad dal
# 708                 urad dal
# 668                 urad dal
# 742                 urad dal
# 851                 urad dal
# 696                 urad dal
# 475                 urad dal
# 559                 urad dal
# 672                 urad dal
# 547                 urad dal
# 554                 urad dal
# 349                 urad dal
# 550                 urad dal
# 929              valor papdi
# 651            vegetable oil
# 147            vegetable oil
# 997            vegetable oil
# 203       vermicelli pudding
# 36                   vinegar
# 564                    water
# 681                    water
# 257                    water
# 29                     water
# 38                     water
# 731                    water
# 748                    water
# 315                    water
# 1108              watercress
# 781              wheat flour
# 418              wheat flour
# 908              wheat flour
# 852              wheat flour
# 313              wheat flour
# 842              wheat flour
# 837              wheat flour
# 441              wheat flour
# 816              wheat flour
# 428              wheat flour
# 369              wheat flour
# 746              wheat flour
# 874              wheat flour
# 131              wheat flour
# 913              wheat flour
# 341              wheat flour
# 171              wheat flour
# 538              wheat flour
# 479              wheat flour
# 975              wheat flour
# 744              wheat flour
# 470              wheat flour
# 921              wheat flour
# 959              wheat flour
# 1025               whole red
# 329        whole wheat bread
# 938             wine vinegar
# 1024       yellow moong daal
# 572           yellow mustard
# 117                  yoghurt
# 1                    yoghurt
# 64                   yoghurt
# 917                  yoghurt
# 302                  yoghurt
# 535                  yoghurt
# 528                  yoghurt
# 56                   yoghurt
# 644                  yoghurt
# 965                  yoghurt
# 461                  yoghurt
# 811                  yoghurt
# 288                  yoghurt

# %% [markdown]
# ### General classification of ingredients
#
# sugar: sugar, jaggery (brown sugar), sweet
# butter: ghee (clarified butter), butter, clarified butter
# oil: oil, vegetal, avocado, olive, coconut, mustard, sesame, rapeseeds, sunflower, peanut
# spices: masala, tandori, biryani, kala, malavi, garam, pav bhaji, panch phoran, sambar power
# flour: maida, chickpea, lentil, corn, refined, rice, wheat, jowar, pearl millet, semolina(wheat flour)
# dal: lentils, moong, masoor, urad, arhar, toor
# milk: condensed milk, coconut milk, mawa
# rice: rice flakes, brown rice, glutinous rice(sticky rice), basmati rice', forbidden black rice, parboiled rice, idli rice,       blend rice(mezcla),'soaked rice', 'cooked rice', 'sticky rice'(change to glutinous!!), 'raw rice'
# nuts: xx
# chilli: chilli, green, red

# %%
change_word(['jaggery'], 'sugar', 'jagg')
# Out:
# Series([], Name: ingredients, dtype: object)

# %%
change_word(['ghee'], 'butter', 'ghee')
# Out:
# Series([], Name: ingredients, dtype: object)

# %%
change_word(['kewra oil', 'vegetable oil', 'avocado oil', 'olive oil',
             'coconut oil', 'mustard oil', 'sesame oil', 'rapeseeds oil', 
             'sunflower oil', 'peanut oil'], 'oil', 'kewra')
# Out:
# Series([], Name: ingredients, dtype: object)

# %%
change_word(['garam masala', 'chole masala', 'tandoori masala', 'biryani masala',
             'sambar masala', 'kala masala', 'malvani masala', 'pav bhaji masala', 
             'panch phoran masala'], 'masala', 'garam')
# Out:
# Series([], Name: ingredients, dtype: object)

# %%
change_word(['maida flour', 'chickpea flour', 'lentil flour', 'corn flour',
             'refined flour', 'rice flour', 'wheat flour', 'pearl millet flour', 
             'jowar flour', 'semolina'], 'flour', 'maida')
# Out:
# Series([], Name: ingredients, dtype: object)

# %%
change_word(['moong dal', 'masoor dal', 'urad dal', 'arhar dal',
             'toor dal', 'dal'], 'lentils', 'urad')
# Out:
# Series([], Name: ingredients, dtype: object)

# %%
change_word(['rice flakes'], 'rice', 'flak')
# Out:
# Series([], Name: ingredients, dtype: object)

# %%
change_word(['green chilli', 'red chilli'], 'chilli', 'green')
# Out:
# 425            mustard green
# 445              green beans
# 590                    green
# 807                    green
# 940                    green
# 942     green garlic chutney
# 1059                   green
# 1110             green beans
# Name: ingredients, dtype: object

# %%
find_word('red chillii')
# Out:
# Series([], Name: ingredients, dtype: object)

# %%
ingredients = new.pivot_table(index = ['ingredients'], aggfunc ='size')
ingredients = ingredients.to_frame()
ingredients.reset_index(inplace=True)
ingredients = ingredients.rename(columns = {0:'n_ingredients', 'ingr':'ingredient'})
ingredients
# Out:
#                 ingredients  n_ingredients
# 0                    almond              8
# 1               alum powder              1
# 2           amaranth leaves              1
# 3             amchur powder              2
# 4                  apricots              1
# 5             arbi ke patte              2
# 6          arrowroot powder              1
# 7                     axone              1
# 8                 baby corn              1
# 9             baking powder              2
# 10              baking soda              8
# 11                   banana              4
# 12            banana flower              1
# 13               bay leaves              4
# 14                    beans              6
# 15                     beef              1
# 16                 beetroot              1
# 17              bell pepper              5
# 18                  bhatura              1
# 19             bitter gourd             10
# 20             black pepper              5
# 21                   boondi              1
# 22                    bread              3
# 23                   butter             41
# 24                  cabbage              2
# 25                 cardamom             14
# 26                   carrot              5
# 27              cashew nuts             12
# 28              cauliflower              3
# 29               chia seeds              1
# 30                  chicken              9
# 31                chickpeas             21
# 32                   chilli             39
# 33                 cinnamon              8
# 34              citric acid              1
# 35                  coconut             28
# 36              coconut ice              1
# 37             coconut milk              4
# 38           condensed milk              5
# 39                coriander              3
# 40           cottage cheese              8
# 41                    cream              9
# 42                 cucumber              4
# 43                     curd             18
# 44             curry leaves             25
# 45                    dates              1
# 46             dinner rolls              1
# 47                    dough              3
# 48        dried rose petals              1
# 49                drumstick              3
# 50                dry dates              1
# 51               dry fruits              5
# 52              dry roasted              1
# 53               edible gum              2
# 54                 eggplant              4
# 55                     eggs              3
# 56        elephant foot yam              1
# 57                   fennel              2
# 58             fennel seeds              5
# 59         fenugreek leaves              8
# 60          fenugreek seeds              1
# 61   fermented bamboo shoot              1
# 62                  filling              1
# 63       firm white pumpkin              1
# 64                     fish              7
# 65                 fish roe              1
# 66                    flour            131
# 67            fpotatoda sev              1
# 68             french beans              2
# 69               fresh peas              1
# 70                      fry              1
# 71                   garlic             10
# 72                   ginger             31
# 73               gooseberry              1
# 74                    gravy              1
# 75                    green              4
# 76              green beans              2
# 77     green garlic chutney              1
# 78                    honey              1
# 79               kala jeera              1
# 80                   khaman              1
# 81                     khoa              1
# 82                khus khus              4
# 83             kitchen lime              1
# 84                    kokum              1
# 85            ladies finger              1
# 86                     lamb              1
# 87                    lemon             14
# 88                  lentils             46
# 89                  lobster              1
# 90               long beans              1
# 91                  low fat              2
# 92                    malai              2
# 93                    mango              3
# 94                 marinade              1
# 95                   masala             54
# 96                     mawa              1
# 97        meat curry powder              1
# 98             methi leaves              1
# 99                     milk             28
# 100                    mint              1
# 101        mixed vegetables              1
# 102             molu leaves              1
# 103             moong beans              3
# 104               mushrooms              2
# 105        musk melon seeds              1
# 106                 mustard              4
# 107           mustard green              1
# 108           mustard seeds             10
# 109                  mutton              1
# 110              naan bread              1
# 111           nigella seeds              2
# 112                    nuts              6
# 113                     oil             41
# 114                  onions              7
# 115             orange rind              1
# 116                     pav              1
# 117                  peanut              3
# 118                    peas              9
# 119             pigeon peas              3
# 120               pistachio              4
# 121             pomegranate              2
# 122             poppy seeds              1
# 123                    pork              2
# 124                  potato             25
# 125                   potol              1
# 126                  prawns              2
# 127         pumpkin flowers              1
# 128                 raisins              7
# 129              raw papaya              1
# 130       red food coloring              1
# 131              red pepper              1
# 132                    rice             34
# 133              rose syrup              1
# 134              rose water              4
# 135                sabudana              1
# 136                 saffron             10
# 137                    salt             11
# 138                   sauce              1
# 139                  sesame              2
# 140            sesame seeds             15
# 141                     sev              4
# 142                   sevai              1
# 143               soy sauce              1
# 144                 spinach              4
# 145              star anise              2
# 146                 steamer              1
# 147                   sugar             83
# 148            sugar potato              1
# 149             surti papdi              1
# 150                tamarind              8
# 151                tea bags              1
# 152              tea leaves              1
# 153                 tindora              1
# 154                  tomato             26
# 155                turmeric             10
# 156             valor papdi              1
# 157      vermicelli pudding              1
# 158                 vinegar              1
# 159                   water              8
# 160              watercress              1
# 161               whole red              1
# 162       whole wheat bread              1
# 163            wine vinegar              1
# 164       yellow moong daal              1
# 165          yellow mustard              1
# 166                 yoghurt             13

# %%
most_used = ingredients.nlargest(15, ['n_ingredients'])
most_used
# Out:
#       ingredients  n_ingredients
# 66          flour            131
# 147         sugar             83
# 95         masala             54
# 88        lentils             46
# 23         butter             41
# 113           oil             41
# 32         chilli             39
# 132          rice             34
# 72         ginger             31
# 35        coconut             28
# 99           milk             28
# 154        tomato             26
# 44   curry leaves             25
# 124        potato             25
# 31      chickpeas             21

# %%
plt.figure()
sns.catplot(x='n_ingredients', y='ingredients', kind='bar', data=most_used)
plt.title('Most common ingredients in Indian food')
plt.xlabel('number of times')
plt.ylabel('ingredients')
plt.show()
