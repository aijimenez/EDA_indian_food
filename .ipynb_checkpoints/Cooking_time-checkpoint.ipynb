# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd
pd.set_option('display.max_rows', 426)
indian_food = pd.read_csv("indian_food.csv")

# %%
indian_food.tail(5)
# Out:
#           name                                        ingredients        diet  \
# 250  Til Pitha            Glutinous rice, black sesame seeds, gur  vegetarian
# 251    Bebinca  Coconut milk, egg yolks, clarified butter, all...  vegetarian
# 252     Shufta  Cottage cheese, dry dates, dried rose petals, ...  vegetarian
# 253  Mawa Bati  Milk powder, dry fruits, arrowroot powder, all...  vegetarian
# 254     Pinaca  Brown rice, fennel seeds, grated coconut, blac...  vegetarian
#
#      prep_time  cook_time flavor_profile   course            state      region
# 250          5         30          sweet  dessert            Assam  North East
# 251         20         60          sweet  dessert              Goa        West
# 252         -1         -1          sweet  dessert  Jammu & Kashmir       North
# 253         20         45          sweet  dessert   Madhya Pradesh     Central
# 254         -1         -1          sweet  dessert              Goa        West

# %%
plt.figure()
sns.histplot(indian_food, x="cook_time")
plt.show()

# %%
no_720 = (indian_food['cook_time'] == 720) | (indian_food['cook_time'] == -1) |\
         (indian_food['region'] == '-1')
cook_time = indian_food.loc[~no_720]
plt.figure()
sns.histplot(cook_time, x="cook_time", bins = 11)
plt.show()

# %%
# Using pandas methods and slicing to determine the order by decreasing median
new_order = cook_time.groupby(by=['region'])['cook_time'].median().iloc[::1].index
sns.boxplot(x='region', y='cook_time', data=cook_time, order=new_order)
plt.show()

# %%
filt= cook_time['region'] == 'West'
cook_time.loc[filt, 'cook_time'].median()
# Out:
# 30.0

# %%
# set a grey background (use sns.set_theme() if seaborn version 0.11.0 or above)
sns.set(style='darkgrid')
# Using pandas methods and slicing to determine the order by decreasing median
new_order = cook_time.groupby(by=['region'])['cook_time'].median().iloc[::1].index
# Specifying the 'order' parameter with my_order and plotting
sns.violinplot(x="region", y="cook_time", data=cook_time, order=new_order)
plt.show()

# %%
# set a grey background (use sns.set_theme() if seaborn version 0.11.0 or above)
sns.set(style='darkgrid')
# Using pandas methods and slicing to determine the order by decreasing median
new_order = cook_time.groupby(by=['region'])['cook_time'].median().iloc[::-1].index
# Specifying the 'order' parameter with my_order and plotting
sns.violinplot(x="cook_time", y="region", data=cook_time, order=new_order)
plt.show()

# %%
sns.violinplot(x="region", y="cook_time", data=cook_time)
# Out:
# <AxesSubplot:xlabel='region', ylabel='cook_time'>

# %%
sns.kdeplot(data=cook_time, x='cook_time', hue='region', \
            multiple='stack')
# Out:
# <AxesSubplot:xlabel='cook_time', ylabel='Density'>

# %%
filt_700 = (indian_food['cook_time'] > 700)
indian_food.loc[filt_700]
# Out:
#          name                     ingredients        diet  prep_time  \
# 62  Shrikhand  Curd, sugar, saffron, cardamom  vegetarian         10
#
#     cook_time flavor_profile   course        state region
# 62        720          sweet  dessert  Maharashtra   West

# %%
no_720 = (indian_food['cook_time'] == -1) |\
         (indian_food['region'] == '-1')
cook_time1 = indian_food.loc[~no_720]

# %%
fig, (ax1, ax2) = plt.subplots(1,2)
sns.histplot(cook_time, x='cook_time', hue='region', \
            multiple='stack', ax=ax1)
sns.kdeplot(data=cook_time, x='cook_time', hue='region', \
            multiple='stack', ax=ax2)
# Out:
# <AxesSubplot:xlabel='cook_time', ylabel='Density'>

# %%
sns.stripplot(x='region', y='cook_time', data=cook_time, size=3)
# Out:
# <AxesSubplot:xlabel='region', ylabel='cook_time'>

# %%
sns.swarmplot(x='region', y='cook_time', data=cook_time, size=3)
# Out:
# C:\Users\keelji\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 9.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\keelji\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 7.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='region', ylabel='cook_time'>

# %%
sns.catplot(x="region", y="cook_time", hue='diet', palette="pastel",
            kind="violin", inner="stick", split=True,
            data=cook_time)

# %%
sns.catplot(x="region", y="cook_time", palette="pastel",
            kind="violin", inner="stick", split=True,
            data=cook_time)

# %%
# Using pandas methods and slicing to determine the order by decreasing median
#new_order = cook_time.groupby(by=['region'])['cook_time'].median().iloc[::1].index
sns.boxplot(x='diet', y='cook_time', data=cook_time)#, order=new_order)
plt.show()

# %%
# Using pandas methods and slicing to determine the order by decreasing median
#new_order = cook_time.groupby(by=['region'])['cook_time'].median().iloc[::1].index
filt = (indian_food['prep_time'] >= 50)
prep_time = indian_food.loc[~filt]
sns.boxplot(x='diet', y='prep_time', data=prep_time)#, order=new_order)
plt.show()

# %%
# Using pandas methods and slicing to determine the order by decreasing median
#new_order = cook_time.groupby(by=['region'])['cook_time'].median().iloc[::1].index
filt = (indian_food['prep_time'] >= 50)
prep_time = indian_food.loc[~filt]
sns.boxplot(x='diet', y='prep_time', data=prep_time)#, order=new_order)
plt.show()
