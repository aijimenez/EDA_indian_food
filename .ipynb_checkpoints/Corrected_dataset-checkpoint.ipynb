# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd
import statistics # for variance
from scipy import stats # calculate trimmed mean

pd.set_option('display.max_rows', 426)

na_vals = ['-1', 1]
indian_food = pd.read_csv("indian_food.csv", na_values=na_vals)
indian_food['ingredients'] = indian_food['ingredients'].apply(lambda x: x.lower())

# %%
indian_food['num_ingr'] = indian_food['ingredients'].apply(lambda x: len(x.split(',')))

# %%
indian_food.head(2)
# Out:
#          name                      ingredients        diet  prep_time  \
# 0  Balu shahi  maida flour, yogurt, oil, sugar  vegetarian       45.0
# 1      Boondi          gram flour, ghee, sugar  vegetarian       80.0
#
#    cook_time flavor_profile   course        state region  num_ingr
# 0       25.0          sweet  dessert  West Bengal   East         4
# 1       30.0          sweet  dessert    Rajasthan   West         3

# %% [markdown]
# #### Correcting preparation times
#
# The correction is based on the webpages indicated by the author of the database. If the dish is not founded in any of them, the preparation time will be search on internet.
#
# https://www.kaggle.com/nehaprabhavalkar/indian-food-101
#
# https://hebbarskitchen.com/
# https://www.archanaskitchen.com/

# %%
outlier_prep = indian_food[(indian_food['prep_time'] > 45)]

# %%
outlier_prep.shape
# Out:
# (22, 10)

# %%
outlier_prep.sort_values('prep_time', ascending=False)
# Out:
#                     name                                        ingredients  \
# 114          Pindi chana   fennel, tea bags, tomato, kasuri methi, cinnamon
# 155                Puttu            brown rice flour, sugar, grated coconut
# 29             Misti doi                                      milk, jaggery
# 144          Masala Dosa  chana dal, urad dal, potatoes, idli rice, thic...
# 130                 Idli  split urad dal, urad dal, idli rice, thick poh...
# 128                 Dosa  chana dal, urad dal, whole urad dal, blend ric...
# 123  Tandoori Fish Tikka  chickpea flour, biryani masala powder, yogurt,...
# 122     Tandoori Chicken  greek yogurt, garam masala, kasuri methi, mari...
# 66        Chak Hao Kheer                        rice, milk, sugar, cardamom
# 48              Poornalu                                 chana dal, jaggery
# 46        Obbattu holige  maida flour, turmeric, coconut, chickpeas, jag...
# 33             Ras malai                    chhena, reduced milk, pistachio
# 124                 Attu  whole wheat flour, arhar dal, ginger, kala jee...
# 158                Sevai                     sevai, parboiled rice, steamer
# 157              Sandige  thin rice flakes, black sesame seeds, curry le...
# 81         Chicken Tikka  chicken, whole wheat bread, rice flour, garam ...
# 129             Idiappam              rice flour, hot water, grated coconut
# 151            Pesarattu                      green moong beans, rice flour
# 1                 Boondi                            gram flour, ghee, sugar
# 202    Sabudana Khichadi  raw peanuts, sabudana, lemon, avocado oil, cur...
# 104                 Naan           whole wheat flour, honey, butter, garlic
# 207              Surnoli  rice flakes, yogurt, raw rice, jaggery, grated...
#
#                diet  prep_time  cook_time flavor_profile       course  \
# 114      vegetarian      500.0      120.0          spicy  main course
# 155      vegetarian      495.0       40.0            NaN  main course
# 29       vegetarian      480.0       30.0          sweet      dessert
# 144      vegetarian      360.0       90.0          spicy        snack
# 130      vegetarian      360.0       90.0          spicy        snack
# 128      vegetarian      360.0       90.0          spicy        snack
# 123  non vegetarian      240.0       30.0          spicy      starter
# 122  non vegetarian      240.0       30.0          spicy  main course
# 66       vegetarian      240.0       45.0          sweet      dessert
# 48       vegetarian      240.0       60.0          sweet      dessert
# 46       vegetarian      180.0       60.0          sweet  main course
# 33       vegetarian      180.0       60.0          sweet      dessert
# 124      vegetarian      150.0       25.0          spicy        snack
# 158      vegetarian      120.0       30.0            NaN  main course
# 157      vegetarian      120.0       60.0            NaN  main course
# 81   non vegetarian      120.0       45.0          spicy      starter
# 129      vegetarian      120.0       30.0          spicy        snack
# 151      vegetarian      120.0       20.0          spicy        snack
# 1        vegetarian       80.0       30.0          sweet      dessert
# 202      vegetarian       70.0       30.0          spicy        snack
# 104      vegetarian       60.0       30.0            NaN  main course
# 207      vegetarian       60.0       10.0          spicy        snack
#
#               state      region  num_ingr
# 114          Punjab       North         5
# 155          Kerala       South         3
# 29      West Bengal        East         2
# 144             NaN       South         5
# 130             NaN       South         5
# 128             NaN       South         5
# 123          Punjab       North         5
# 122          Punjab       North         5
# 66          Manipur  North East         4
# 48   Andhra Pradesh       South         2
# 46        Karnataka       South         7
# 33      West Bengal        East         3
# 124  Andhra Pradesh       South         5
# 158             NaN       South         3
# 157       Karnataka       South         3
# 81           Punjab       North         5
# 129      Tamil Nadu       South         3
# 151  Andhra Pradesh       South         2
# 1         Rajasthan        West         3
# 202     Maharashtra        West         6
# 104          Punjab       North         4
# 207     Maharashtra        West         5

# %%
def add_col(df):
    if outlier_prep['name'] == 'Misti doi':

# %%
outlier_prep['prep_time_reason'] = 'soaking time'
# Out:
# C:\Users\keelji\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
outlier_prep
# Out:
#                     name                                        ingredients  \
# 1                 Boondi                            gram flour, ghee, sugar
# 29             Misti doi                                      milk, jaggery
# 33             Ras malai                    chhena, reduced milk, pistachio
# 46        Obbattu holige  maida flour, turmeric, coconut, chickpeas, jag...
# 48              Poornalu                                 chana dal, jaggery
# 66        Chak Hao Kheer                        rice, milk, sugar, cardamom
# 81         Chicken Tikka  chicken, whole wheat bread, rice flour, garam ...
# 104                 Naan           whole wheat flour, honey, butter, garlic
# 114          Pindi chana   fennel, tea bags, tomato, kasuri methi, cinnamon
# 122     Tandoori Chicken  greek yogurt, garam masala, kasuri methi, mari...
# 123  Tandoori Fish Tikka  chickpea flour, biryani masala powder, yogurt,...
# 124                 Attu  whole wheat flour, arhar dal, ginger, kala jee...
# 128                 Dosa  chana dal, urad dal, whole urad dal, blend ric...
# 129             Idiappam              rice flour, hot water, grated coconut
# 130                 Idli  split urad dal, urad dal, idli rice, thick poh...
# 144          Masala Dosa  chana dal, urad dal, potatoes, idli rice, thic...
# 151            Pesarattu                      green moong beans, rice flour
# 155                Puttu            brown rice flour, sugar, grated coconut
# 157              Sandige  thin rice flakes, black sesame seeds, curry le...
# 158                Sevai                     sevai, parboiled rice, steamer
# 202    Sabudana Khichadi  raw peanuts, sabudana, lemon, avocado oil, cur...
# 207              Surnoli  rice flakes, yogurt, raw rice, jaggery, grated...
#
#                diet  prep_time  cook_time flavor_profile       course  \
# 1        vegetarian       80.0       30.0          sweet      dessert
# 29       vegetarian      480.0       30.0          sweet      dessert
# 33       vegetarian      180.0       60.0          sweet      dessert
# 46       vegetarian      180.0       60.0          sweet  main course
# 48       vegetarian      240.0       60.0          sweet      dessert
# 66       vegetarian      240.0       45.0          sweet      dessert
# 81   non vegetarian      120.0       45.0          spicy      starter
# 104      vegetarian       60.0       30.0            NaN  main course
# 114      vegetarian      500.0      120.0          spicy  main course
# 122  non vegetarian      240.0       30.0          spicy  main course
# 123  non vegetarian      240.0       30.0          spicy      starter
# 124      vegetarian      150.0       25.0          spicy        snack
# 128      vegetarian      360.0       90.0          spicy        snack
# 129      vegetarian      120.0       30.0          spicy        snack
# 130      vegetarian      360.0       90.0          spicy        snack
# 144      vegetarian      360.0       90.0          spicy        snack
# 151      vegetarian      120.0       20.0          spicy        snack
# 155      vegetarian      495.0       40.0            NaN  main course
# 157      vegetarian      120.0       60.0            NaN  main course
# 158      vegetarian      120.0       30.0            NaN  main course
# 202      vegetarian       70.0       30.0          spicy        snack
# 207      vegetarian       60.0       10.0          spicy        snack
#
#               state      region  num_ingr prep_time_reason
# 1         Rajasthan        West         3     soaking time
# 29      West Bengal        East         2     soaking time
# 33      West Bengal        East         3     soaking time
# 46        Karnataka       South         7     soaking time
# 48   Andhra Pradesh       South         2     soaking time
# 66          Manipur  North East         4     soaking time
# 81           Punjab       North         5     soaking time
# 104          Punjab       North         4     soaking time
# 114          Punjab       North         5     soaking time
# 122          Punjab       North         5     soaking time
# 123          Punjab       North         5     soaking time
# 124  Andhra Pradesh       South         5     soaking time
# 128             NaN       South         5     soaking time
# 129      Tamil Nadu       South         3     soaking time
# 130             NaN       South         5     soaking time
# 144             NaN       South         5     soaking time
# 151  Andhra Pradesh       South         2     soaking time
# 155          Kerala       South         3     soaking time
# 157       Karnataka       South         3     soaking time
# 158             NaN       South         3     soaking time
# 202     Maharashtra        West         6     soaking time
# 207     Maharashtra        West         5     soaking time

# %%
outlier_prep.at[29,'prep_time_reason']='other reason'
outlier_prep.at[33,'prep_time_reason']='other reason'
outlier_prep.at[129,'prep_time_reason']='other reason'

outlier_prep.at[123,'prep_time_reason']='marinating'
outlier_prep.at[122,'prep_time_reason']='marinating'
outlier_prep.at[81,'prep_time_reason']='marinating'
outlier_prep.at[46,'prep_time_reason']='dough preparation'
outlier_prep.at[157,'prep_time_reason']='dough preparation'
outlier_prep.at[1,'prep_time_reason']='dough preparation'
outlier_prep.at[104,'prep_time_reason']='dough preparation'

# %%
outlier_prep
# Out:
#                     name                                        ingredients  \
# 1                 Boondi                            gram flour, ghee, sugar
# 29             Misti doi                                      milk, jaggery
# 33             Ras malai                    chhena, reduced milk, pistachio
# 46        Obbattu holige  maida flour, turmeric, coconut, chickpeas, jag...
# 48              Poornalu                                 chana dal, jaggery
# 66        Chak Hao Kheer                        rice, milk, sugar, cardamom
# 81         Chicken Tikka  chicken, whole wheat bread, rice flour, garam ...
# 104                 Naan           whole wheat flour, honey, butter, garlic
# 114          Pindi chana   fennel, tea bags, tomato, kasuri methi, cinnamon
# 122     Tandoori Chicken  greek yogurt, garam masala, kasuri methi, mari...
# 123  Tandoori Fish Tikka  chickpea flour, biryani masala powder, yogurt,...
# 124                 Attu  whole wheat flour, arhar dal, ginger, kala jee...
# 128                 Dosa  chana dal, urad dal, whole urad dal, blend ric...
# 129             Idiappam              rice flour, hot water, grated coconut
# 130                 Idli  split urad dal, urad dal, idli rice, thick poh...
# 144          Masala Dosa  chana dal, urad dal, potatoes, idli rice, thic...
# 151            Pesarattu                      green moong beans, rice flour
# 155                Puttu            brown rice flour, sugar, grated coconut
# 157              Sandige  thin rice flakes, black sesame seeds, curry le...
# 158                Sevai                     sevai, parboiled rice, steamer
# 202    Sabudana Khichadi  raw peanuts, sabudana, lemon, avocado oil, cur...
# 207              Surnoli  rice flakes, yogurt, raw rice, jaggery, grated...
#
#                diet  prep_time  cook_time flavor_profile       course  \
# 1        vegetarian       80.0       30.0          sweet      dessert
# 29       vegetarian      480.0       30.0          sweet      dessert
# 33       vegetarian      180.0       60.0          sweet      dessert
# 46       vegetarian      180.0       60.0          sweet  main course
# 48       vegetarian      240.0       60.0          sweet      dessert
# 66       vegetarian      240.0       45.0          sweet      dessert
# 81   non vegetarian      120.0       45.0          spicy      starter
# 104      vegetarian       60.0       30.0            NaN  main course
# 114      vegetarian      500.0      120.0          spicy  main course
# 122  non vegetarian      240.0       30.0          spicy  main course
# 123  non vegetarian      240.0       30.0          spicy      starter
# 124      vegetarian      150.0       25.0          spicy        snack
# 128      vegetarian      360.0       90.0          spicy        snack
# 129      vegetarian      120.0       30.0          spicy        snack
# 130      vegetarian      360.0       90.0          spicy        snack
# 144      vegetarian      360.0       90.0          spicy        snack
# 151      vegetarian      120.0       20.0          spicy        snack
# 155      vegetarian      495.0       40.0            NaN  main course
# 157      vegetarian      120.0       60.0            NaN  main course
# 158      vegetarian      120.0       30.0            NaN  main course
# 202      vegetarian       70.0       30.0          spicy        snack
# 207      vegetarian       60.0       10.0          spicy        snack
#
#               state      region  num_ingr   prep_time_reason
# 1         Rajasthan        West         3  dough preparation
# 29      West Bengal        East         2       other reason
# 33      West Bengal        East         3       other reason
# 46        Karnataka       South         7  dough preparation
# 48   Andhra Pradesh       South         2       soaking time
# 66          Manipur  North East         4       soaking time
# 81           Punjab       North         5         marinating
# 104          Punjab       North         4  dough preparation
# 114          Punjab       North         5       soaking time
# 122          Punjab       North         5         marinating
# 123          Punjab       North         5         marinating
# 124  Andhra Pradesh       South         5       soaking time
# 128             NaN       South         5       soaking time
# 129      Tamil Nadu       South         3       other reason
# 130             NaN       South         5       soaking time
# 144             NaN       South         5       soaking time
# 151  Andhra Pradesh       South         2       soaking time
# 155          Kerala       South         3       soaking time
# 157       Karnataka       South         3  dough preparation
# 158             NaN       South         3       soaking time
# 202     Maharashtra        West         6       soaking time
# 207     Maharashtra        West         5       soaking time

# %% [markdown]
# 29 Misti doi 10 min instead 480

# %%
indian_food[(indian_food['prep_time'] >= 240)] #overnight soaking, fermentation, marinating
# Out:
#                     name                                        ingredients  \
# 29             Misti doi                                      milk, jaggery
# 48              Poornalu                                 chana dal, jaggery
# 66        Chak Hao Kheer                        rice, milk, sugar, cardamom
# 114          Pindi chana   fennel, tea bags, tomato, kasuri methi, cinnamon
# 122     Tandoori Chicken  greek yogurt, garam masala, kasuri methi, mari...
# 123  Tandoori Fish Tikka  chickpea flour, biryani masala powder, yogurt,...
# 128                 Dosa  chana dal, urad dal, whole urad dal, blend ric...
# 130                 Idli  split urad dal, urad dal, idli rice, thick poh...
# 144          Masala Dosa  chana dal, urad dal, potatoes, idli rice, thic...
# 155                Puttu            brown rice flour, sugar, grated coconut
#
#                diet  prep_time  cook_time flavor_profile       course  \
# 29       vegetarian      480.0       30.0          sweet      dessert
# 48       vegetarian      240.0       60.0          sweet      dessert
# 66       vegetarian      240.0       45.0          sweet      dessert
# 114      vegetarian      500.0      120.0          spicy  main course
# 122  non vegetarian      240.0       30.0          spicy  main course
# 123  non vegetarian      240.0       30.0          spicy      starter
# 128      vegetarian      360.0       90.0          spicy        snack
# 130      vegetarian      360.0       90.0          spicy        snack
# 144      vegetarian      360.0       90.0          spicy        snack
# 155      vegetarian      495.0       40.0            NaN  main course
#
#               state      region  num_ingr
# 29      West Bengal        East         2
# 48   Andhra Pradesh       South         2
# 66          Manipur  North East         4
# 114          Punjab       North         5
# 122          Punjab       North         5
# 123          Punjab       North         5
# 128             NaN       South         5
# 130             NaN       South         5
# 144             NaN       South         5
# 155          Kerala       South         3
