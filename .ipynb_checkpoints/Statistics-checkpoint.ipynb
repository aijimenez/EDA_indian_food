# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd
pd.set_option('display.max_rows', 426)
indian_food = pd.read_csv("indian_food.csv")

# %% [markdown]
# ## Comentarios
# prueba.replace(-1, np.nan, inplace=True)
# prueba mean, median
# indian_food.replace(-1, np.nan, inplace=True)
# create subplots fig, (ax1, ax2, ax3) = plt.subplots(ncols=3)
# histogram prep_time, cook_time and num_ingr
# indian_food.describe(): prep_time, cook_time and num_ingr
# **describe:** count, mean, std, min, 25%, 50%, 75% max (!disminucion de decimales)
# name of columns: indian_food.columns
# indian_food['column'].value_counts(): diet, flavor_profile, state, region
# indian_food['column'].value_counts(normalize=True): state, region, **porcentajes**
# indian_food.groupby(['region'])[‘column’].describe(): 'prep_time', cook_time, num_ingr
# indian_food.columns
# count of a column and region: North column num_ingr.
# Count of a column separated by (regions, cook_time) and normalizado
# ### Filter non_vegetarian:
# Region, cook_time statisticas: mean, median
# Fish is count al non_veg: En que region esta el pescado

# %%
indian_food.shape
# Out:
# (255, 9)

# %%
indian_food['num_ingr'] = indian_food['ingredients'].apply(lambda x: len(x.split(',')))
prueba = indian_food.tail(15)

# %%
prueba.replace(-1, np.nan, inplace=True)
# Out:
# C:\Users\keelji\Anaconda3\lib\site-packages\pandas\core\frame.py:4527: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   method=method,

# %%
prueba['prep_time']
# Out:
# 240     NaN
# 241     NaN
# 242     NaN
# 243    10.0
# 244     NaN
# 245    10.0
# 246     NaN
# 247    15.0
# 248     NaN
# 249    10.0
# 250     5.0
# 251    20.0
# 252     NaN
# 253    20.0
# 254     NaN
# Name: prep_time, dtype: float64

# %%
prueba.mean()
# Out:
# prep_time    12.857143
# cook_time    36.428571
# num_ingr      4.666667
# dtype: float64

# %%
prueba.median()
# Out:
# prep_time    10.0
# cook_time    30.0
# num_ingr      5.0
# dtype: float64

# %%
indian_food.replace(-1, np.nan, inplace=True)
indian_food.replace('-1', np.nan, inplace=True)
indian_food.tail(5)
# Out:
#           name                                        ingredients        diet  \
# 250  Til Pitha            Glutinous rice, black sesame seeds, gur  vegetarian
# 251    Bebinca  Coconut milk, egg yolks, clarified butter, all...  vegetarian
# 252     Shufta  Cottage cheese, dry dates, dried rose petals, ...  vegetarian
# 253  Mawa Bati  Milk powder, dry fruits, arrowroot powder, all...  vegetarian
# 254     Pinaca  Brown rice, fennel seeds, grated coconut, blac...  vegetarian
#
#      prep_time  cook_time flavor_profile   course            state  \
# 250        5.0       30.0          sweet  dessert            Assam
# 251       20.0       60.0          sweet  dessert              Goa
# 252        NaN        NaN          sweet  dessert  Jammu & Kashmir
# 253       20.0       45.0          sweet  dessert   Madhya Pradesh
# 254        NaN        NaN          sweet  dessert              Goa
#
#          region  num_ingr
# 250  North East         3
# 251        West         4
# ...

# %%
# create subplots
fig, (ax1, ax2, ax3) = plt.subplots(ncols=3)

# plot preparation time
sns.histplot(indian_food, x="prep_time", bins=10, ax=ax1)
# plot cook time
sns.histplot(indian_food, x="cook_time", ax=ax2)
# plot number of ingredients
sns.histplot(indian_food, x="num_ingr", bins=9, ax=ax3)

plt.show()

# %%
indian_food.describe()
# Out:
#         prep_time   cook_time    num_ingr
# count  225.000000  227.000000  255.000000
# mean    35.386667   38.911894    4.454902
# std     76.241081   49.421711    1.205681
# min      5.000000    2.000000    2.000000
# 25%     10.000000   20.000000    4.000000
# 50%     10.000000   30.000000    5.000000
# 75%     20.000000   45.000000    5.000000
# max    500.000000  720.000000   10.000000

# %%
indian_food.columns
# Out:
# Index(['name', 'ingredients', 'diet', 'prep_time', 'cook_time',
#        'flavor_profile', 'course', 'state', 'region', 'num_ingr'],
#       dtype='object')

# %%
indian_food['diet'].value_counts()
# Out:
# vegetarian        226
# non vegetarian     29
# Name: diet, dtype: int64

# %%
indian_food['flavor_profile'].value_counts()
# Out:
# spicy     133
# sweet      88
# bitter      4
# sour        1
# Name: flavor_profile, dtype: int64

# %%
indian_food['state'].value_counts()
# Out:
# Gujarat            35
# Punjab             32
# Maharashtra        30
# West Bengal        24
# Assam              21
# Tamil Nadu         20
# Andhra Pradesh     10
# Uttar Pradesh       9
# Kerala              8
# Odisha              7
# Rajasthan           6
# Karnataka           6
# Telangana           5
# Bihar               3
# Goa                 3
# Manipur             2
# Jammu & Kashmir     2
# Madhya Pradesh      2
# Uttarakhand         1
# Chhattisgarh        1
# Nagaland            1
# Haryana             1
# Tripura             1
# NCT of Delhi        1
# Name: state, dtype: int64

# %%
indian_food['state'].value_counts(normalize=True)
# Out:
# Gujarat            0.151515
# Punjab             0.138528
# Maharashtra        0.129870
# West Bengal        0.103896
# Assam              0.090909
# Tamil Nadu         0.086580
# Andhra Pradesh     0.043290
# Uttar Pradesh      0.038961
# Kerala             0.034632
# Odisha             0.030303
# Rajasthan          0.025974
# Karnataka          0.025974
# Telangana          0.021645
# Bihar              0.012987
# Goa                0.012987
# Manipur            0.008658
# Jammu & Kashmir    0.008658
# Madhya Pradesh     0.008658
# Uttarakhand        0.004329
# Chhattisgarh       0.004329
# Nagaland           0.004329
# Haryana            0.004329
# Tripura            0.004329
# NCT of Delhi       0.004329
# Name: state, dtype: float64

# %%
indian_food['region'].value_counts()
# Out:
# West          74
# South         59
# North         49
# East          31
# North East    25
# Central        3
# Name: region, dtype: int64

# %%
indian_food['region'].value_counts(normalize=True)
# Out:
# West          0.307054
# South         0.244813
# North         0.203320
# East          0.128631
# North East    0.103734
# Central       0.012448
# Name: region, dtype: float64

# %%
indian_food.groupby(['region'])['prep_time'].describe()
# Out:
#             count       mean         std   min   25%   50%   75%    max
# region
# Central       3.0  13.333333    5.773503  10.0  10.0  10.0  15.0   20.0
# East         27.0  43.518519   93.210007  10.0  10.0  15.0  30.0  480.0
# North        48.0  38.020833   83.377759   5.0  10.0  15.0  20.0  500.0
# North East   13.0  28.846154   63.644646   5.0  10.0  10.0  15.0  240.0
# South        55.0  58.181818  107.812267   5.0  10.0  10.0  30.0  495.0
# West         66.0  16.924242   13.510464   5.0  10.0  10.0  20.0   80.0

# %%
indian_food.groupby(['region'])['cook_time'].describe()
# Out:
#             count       mean        std   min   25%   50%   75%    max
# region
# Central       3.0  48.333333  10.408330  40.0  42.5  45.0  52.5   60.0
# East         28.0  41.607143  16.276180  20.0  30.0  40.0  50.0   90.0
# North        48.0  41.979167  21.994670   5.0  30.0  40.0  50.0  120.0
# North East   13.0  28.461538   9.439415  15.0  20.0  30.0  35.0   45.0
# South        55.0  36.909091  24.123350   5.0  20.0  30.0  45.0  120.0
# West         67.0  41.880597  85.419557   6.0  22.5  30.0  40.0  720.0

# %%
indian_food.groupby(['region'])['num_ingr'].describe()
# Out:
#             count      mean       std  min  25%  50%  75%   max
# region
# Central       3.0  4.333333  0.577350  4.0  4.0  4.0  4.5   5.0
# East         31.0  3.935484  1.436094  2.0  3.0  4.0  5.0   8.0
# North        49.0  4.918367  0.885925  3.0  5.0  5.0  5.0   9.0
# North East   25.0  4.480000  1.084743  2.0  4.0  5.0  5.0   6.0
# South        59.0  4.322034  1.370133  2.0  3.0  5.0  5.0   8.0
# West         74.0  4.445946  1.183701  2.0  4.0  5.0  5.0  10.0

# %%
indian_food.columns
# Out:
# Index(['name', 'ingredients', 'diet', 'prep_time', 'cook_time',
#        'flavor_profile', 'course', 'state', 'region', 'num_ingr'],
#       dtype='object')

# %%
filt=indian_food['region']=='North'
indian_food[filt]['num_ingr'].value_counts()
# Out:
# 5    35
# 4     6
# 6     4
# 3     3
# 9     1
# Name: num_ingr, dtype: int64

# %%
region_grp = indian_food.groupby(['region'])

# %%
region_grp['num_ingr'].value_counts().loc['Central']
# Out:
# num_ingr
# 4    2
# 5    1
# Name: num_ingr, dtype: int64

# %%
region_grp['num_ingr'].value_counts()
# Out:
# region      num_ingr
# Central     4            2
#             5            1
# East        3            9
#             5            9
#             2            5
#             4            5
#             6            2
#             8            1
# North       5           35
#             4            6
#             6            4
#             3            3
#             9            1
# North East  5           12
#             4            6
#             6            3
#             2            2
#             3            2
# South       5           31
#             3           10
#             2            8
#             4            5
#             6            2
#             7            2
#             8            1
# West        5           43
#             4           13
#             3           10
#             2            5
#             6            2
#             10           1
# Name: num_ingr, dtype: int64

# %%
region_grp['num_ingr'].value_counts(normalize=True)
# Out:
# region      num_ingr
# Central     4           0.666667
#             5           0.333333
# East        3           0.290323
#             5           0.290323
#             2           0.161290
#             4           0.161290
#             6           0.064516
#             8           0.032258
# North       5           0.714286
#             4           0.122449
#             6           0.081633
#             3           0.061224
#             9           0.020408
# North East  5           0.480000
#             4           0.240000
#             6           0.120000
#             2           0.080000
#             3           0.080000
# South       5           0.525424
#             3           0.169492
#             2           0.135593
#             4           0.084746
#             6           0.033898
#             7           0.033898
#             8           0.016949
# West        5           0.581081
#             4           0.175676
# ...

# %%
region_grp['cook_time'].value_counts()
# Out:
# region      cook_time
# Central     40.0          1
#             45.0          1
#             60.0          1
# East        30.0          8
#             60.0          5
#             50.0          4
#             20.0          3
#             45.0          3
#             40.0          2
#             25.0          1
#             35.0          1
#             90.0          1
# North       30.0         15
#             40.0         10
#             60.0          6
#             20.0          5
#             50.0          4
#             45.0          3
#             120.0         2
#             5.0           1
#             35.0          1
#             90.0          1
# North East  20.0          4
#             30.0          3
#             40.0          2
#             15.0          1
#             25.0          1
#             35.0          1
#             45.0          1
# South       20.0         19
#             30.0         10
#             60.0          6
# ...

# %%
filt = indian_food['diet']=='non vegetarian'
non_veg = indian_food.loc[filt]
non_veg
# Out:
#                      name                                        ingredients  \
# 64             Maach Jhol      Fish, potol, tomato, chillies, ginger, garlic
# 65            Pork Bharta   Boiled pork, onions, chillies, ginger and garlic
# 67                  Galho           Rice, axone, salt, water, chillies, pork
# 75                Biryani  Chicken thighs, basmati rice, star anise, swee...
# 76         Butter chicken  Chicken, greek yogurt, cream, garam masala pow...
# 79         Chicken razala  Chicken, dahi, sesame seeds, garam masala powd...
# 80   Chicken Tikka masala  Naan bread, tomato sauce, skinless chicken bre...
# 81          Chicken Tikka  Chicken, whole wheat bread, rice flour, garam ...
# 122      Tandoori Chicken  Greek yogurt, garam masala, kasuri methi, mari...
# 123   Tandoori Fish Tikka  Chickpea flour, biryani masala powder, yogurt,...
# 137              Beef Fry  Beef, coconut, garam masala, curry leaves, gre...
# ...

# %%
non_veg['ingredients'] = non_veg['ingredients'].apply(lambda x: x.lower())
non_veg
# Out:
# C:\Users\keelji\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                      name                                        ingredients  \
# 64             Maach Jhol      fish, potol, tomato, chillies, ginger, garlic
# 65            Pork Bharta   boiled pork, onions, chillies, ginger and garlic
# 67                  Galho           rice, axone, salt, water, chillies, pork
# 75                Biryani  chicken thighs, basmati rice, star anise, swee...
# 76         Butter chicken  chicken, greek yogurt, cream, garam masala pow...
# 79         Chicken razala  chicken, dahi, sesame seeds, garam masala powd...
# ...

# %%
#non_veg['ingredients'].str.split(',', expand=True)

# %%
#non_veg[['i1', 'i2', 'i3', 'i4', 'i5', 'i6']] = non_veg['ingredients'].str.split(',', expand=True)

# %%
#non_veg

# %%
region_grp['cook_time'].agg(['median', 'mean'])
# Out:
#             median       mean
# region
# Central       45.0  48.333333
# East          40.0  41.607143
# North         40.0  41.979167
# North East    30.0  28.461538
# South         30.0  36.909091
# West          30.0  41.880597

# %%
non_veg['ingredients'].str.contains('fish').sum()
# Out:
# 7

# %%
region_grp['ingredients'].apply(lambda x: x.str.contains('pork').sum())
# Out:
# region
# Central       0
# East          0
# North         0
# North East    2
# South         0
# West          0
# Name: ingredients, dtype: int64

# %%
# Out:
# region
# Central       0
# East          0
# North         1
# North East    2
# South         0
# West          1
# Name: ingredients, dtype: int64

# %%
non_veg['region'].value_counts()
# Out:
# North East    13
# North          5
# East           5
# West           3
# South          3
# Name: region, dtype: int64

# %%
filt = non_veg['ingredients'].str.contains('fish') 
non_veg[filt]
# Out:
#                     name                                        ingredients  \
# 64            Maach Jhol      fish, potol, tomato, chillies, ginger, garlic
# 123  Tandoori Fish Tikka  chickpea flour, biryani masala powder, yogurt,...
# 167          Kolim Jawla  baingan, fish, coconut oil, fresh coconut, ginger
# 225           Alu Pitika        potatoes, mustard oil, fish, green chillies
# 226          Masor tenga    ridge gourd, fish, lemon, tomatoes, mustard oil
# 237             Kabiraji            fish fillet, besan, lemon, mint, ginger
# 242           Masor Koni  fish roe, pumpkin flowers, mustard oil, turmer...
#
#                diet  prep_time  cook_time flavor_profile       course  \
# 64   non vegetarian       10.0       40.0          spicy  main course
# 123  non vegetarian      240.0       30.0          spicy      starter
# 167  non vegetarian        NaN        NaN          spicy  main course
# 225  non vegetarian        5.0       20.0          spicy  main course
# ...

# %%
region_grp['ingredients'].apply(lambda x: x.str.contains('fish').sum())
# Out:
# region
# Central       0
# East          0
# North         1
# North East    2
# South         0
# West          1
# Name: ingredients, dtype: int64
