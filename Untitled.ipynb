# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd
pd.set_option('display.max_rows', 426)
indian_food = pd.read_csv("indian_food.csv")

# %% [markdown]
# ## Comentarios
# Indian_food dimensions (255, 9)
# Addition column num_ingr
# Histogram num_ingr
# Regplot: num_ingr and prep_time
# Regplot: num_ingr and cook_time without 720 and -1
# Lmplot: cook_time and prep_time hue: region
# Jointplot with histogram: num_ingr and prep_time
# Lineplot: cook_time and prep_time hue:region

# %%
indian_food.shape
# Out:
# (255, 9)

# %%
indian_food['num_ingr'] = indian_food['ingredients'].apply(lambda x: len(x.split(',')))
indian_food.head(2)
# Out:
#          name                      ingredients        diet  prep_time  \
# 0  Balu shahi  Maida flour, yogurt, oil, sugar  vegetarian         45
# 1      Boondi          Gram flour, ghee, sugar  vegetarian         80
#
#    cook_time flavor_profile   course        state region  num_ingr
# 0         25          sweet  dessert  West Bengal   East         4
# 1         30          sweet  dessert    Rajasthan   West         3

# %%
plt.figure()
sns.histplot(indian_food, x="num_ingr", bins=9)
plt.show()

# %%
# use the function regplot to make a scatterplot
sns.regplot(x=indian_food["num_ingr"], y=indian_food["prep_time"])
plt.show()

# %%
no_720 = (indian_food['cook_time'] == 720) | (indian_food['cook_time'] == -1) 
food = indian_food.loc[~no_720]
# use the function regplot to make a scatterplot
sns.regplot(x=food["num_ingr"], y=food["cook_time"])
plt.show()

# %%
# Use the 'hue' argument to provide a factor variable
sns.lmplot( x="cook_time", y="prep_time", data=food, fit_reg=False, hue='region', legend=True)
plt.show()

# %%
# Custom the histogram:
sns.jointplot(x=food["num_ingr"], y=food["prep_time"], kind='hex', marginal_kws=dict(bins=30, fill=True))

plt.show()

# %%
sns.lineplot(x="cook_time", y="prep_time", hue='region', data=food)
# Out:
# <AxesSubplot:xlabel='cook_time', ylabel='prep_time'>
